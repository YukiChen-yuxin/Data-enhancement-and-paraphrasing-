# %%
import random
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable


class Encoder(nn.Module):

    def __init__(self, vocab_size, embedding_size, hidden_size, n_layers=1, dropout=0.5):
        """
        Bidirectional LSTM encoder; aggregate the outputs of two directions by summation
        :param int vocab_size: size of the source language vocabulary
        :param int embedding_size: size of embedded
        :param int hidden_size: size of hidden states
        :param int n_layers: number of layers
        :param float dropout: dropout rate
        """
        super(Encoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers
        self.dropout = dropout

        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.lstm = nn.LSTM(embedding_size, hidden_size, n_layers, dropout=dropout, bidirectional=True)

    def forward(self, input_sentence, hidden=None):
        """
        forward propagation
        :param torch.Tensor input_sentence: source sentence; shape of (T, B)
        :param tuple hidden: previous hidden states, (h, c)
        :return: outputs sequence, the last hidden states include h and c
        """
        embedded = self.embedding(input_sentence)  # (T, B, E)
        outputs, hidden = self.lstm(embedded, hidden)
        # aggregate hidden states of two directions by sum
        outputs = (outputs[:, :, :self.hidden_size] + outputs[:, :, self.hidden_size:])  # (T, B, H)
        return outputs, hidden


class Attention(nn.Module):

    def __init__(self, hidden_size):
        """
        attention weights; two-layer MLP as alignment model
        :param int hidden_size: the hidden state size of encoder
        """
        super(Attention, self).__init__()
        self.hidden_size = hidden_size
        self.attn1 = nn.Linear(2*hidden_size, hidden_size)  # first fc layer
        self.attn2 = nn.Linear(hidden_size, 1)  # second fc layer

    def forward(self, encoder_outputs, hidden):
        """
        calculate attention score
        :param torch.Tensor encoder_outputs: sequence of outputs from encoder
        :param torch.Tensor hidden: the previous hidden h of decoder, shape of (1, B, H)
        :return: attention score
        """
        length = encoder_outputs.size(0)
        encoder_outputs = encoder_outputs.transpose(0, 1)  # (B, T, H)
        hidden = hidden.repeat(length, 1, 1).transpose(0, 1)  # (B, T, H)
        # calculate energies
        energies = self.attn1(torch.cat([encoder_outputs, hidden], dim=2))
        energies = F.relu(energies)  # (B, T, H)
        energies = self.attn2(energies)  # (B, T, 1)
        # calculate attention weights
        attention = F.softmax(energies.squeeze(2), dim=1).unsqueeze(1)  # (B, 1, T)
        return attention


class Decoder(nn.Module):

    def __init__(self, vocab_size, embedding_size, hidden_size, n_layers=1, dropout=0.5):
        """
        :param int vocab_size: size of the target language vocabulary
        :param int embedding_size: size of embedded
        :param int hidden_size: size of hidden states
        :param int n_layers: number of layers
        :param float dropout: dropout rate
        """
        super(Decoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers
        self.dropout = dropout

        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.lstm = nn.LSTM(embedding_size + hidden_size, hidden_size, n_layers, dropout=dropout)
        self.attention = Attention(hidden_size)  # encoder and decoder will use same hidden size for simplicity
        self.out = nn.Linear(2*hidden_size, vocab_size)

    def forward(self, input_word, hidden, encoder_outputs):
        """
        forward propagation
        :param torch.Tensor input_word: the input word tensor, shape of (B, )
        :param tuple hidden: previous hidden states
        :param torch.Tensor encoder_outputs: output from encoder
        :return: log likelihood of output words; final hidden states
        """
        # get input word embeddings
        embedded = self.embedding(input_word)  # (B, E)
        embedded = embedded.unsqueeze(0)  # (1, B, E)
        # calculate context
        attention = self.attention(encoder_outputs, hidden[0][-1:])  # hidden h uses the last layer
        context = attention.bmm(encoder_outputs.transpose(0, 1))  # (B, 1, H)
        context = context.transpose(0, 1)  # (1, B, H)
        # concatenate LSTM input
        lstm_input = torch.cat([embedded, context], dim=2)  # (1, B, E+H)
        output, hidden = self.lstm(lstm_input, hidden)
        # concatenate final layer input
        context = context.squeeze(0)  # (B, H)
        output = output.squeeze(0)  # (B, H)
        final_input = torch.cat([output, context], dim=1)  # (B, 2H)
        # final output layer
        output = self.out(final_input)  # (B, N)
        output = F.log_softmax(output, dim=1)
        return output, hidden


class Seq2Seq(nn.Module):

    def __init__(self, encoder, decoder):
        """
        the final Seq2Seq model with attention
        :param Encoder encoder: the Encoder class
        :param Decoder decoder: the Decoder class
        """
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, source, target, teacher_forcing=0.5):
        """
        forward propagation
        :param torch.Tensor source: the source sentences, shape of (T', B)
        :param torch.Tensor target: the target sentences, shape of (T, B)
        :param float teacher_forcing: the teacher forcing ratio
        :return: translated sentences
        """
        # initialize outputs
        target_len = target.size(0)
        batch_size = source.size(1)
        vocab_size = self.decoder.vocab_size
        outputs = Variable(torch.zeros(target_len, batch_size, vocab_size))  # (T, B, N)

        # encoding source sentences
        encoder_outputs, hidden = self.encoder(source)
        # initialize decoder as the final hidden states of encoder
        hidden = (hidden[0][:self.decoder.n_layers], hidden[1][:self.decoder.n_layers])

        # decoding word by word
        output = Variable(target.data[0, :])  # first output <SOS>, shape of (B,)
        for t in range(1, target_len):
            output, hidden = self.decoder(output, hidden, encoder_outputs)
            outputs[t] = output  # fill in outputs
            top1 = output.max(1)[1]  # the word index with the largest log likelihood
            # teacher forcing
            is_teacher = random.random() < teacher_forcing
            output = Variable(target.data[t] if is_teacher else top1)
        return outputs

    def translate(self, source, max_length):
        """
        translate one sentence
        :param torch.Tensor source: the source sentence, shape of (T', 1)
        :param int max_length: max translation length
        :return: translated sentence
        """
        # encoding source sentences
        encoder_outputs, hidden = self.encoder(source)
        # initialize decoder as the final hidden states of encoder
        hidden = (hidden[0][:self.decoder.n_layers], hidden[1][:self.decoder.n_layers])
        outputs = []
        # decoding word by word
        output = torch.LongTensor([2])  # first output <SOS>, shape of (1,)
        for t in range(1, max_length+1):
            output, hidden = self.decoder(output, hidden, encoder_outputs)
            top1 = output.max(1)[1]  # the word index with the largest log likelihood
            outputs.append(top1.item())  # fill in outputs
            # break if <EOS>
            if top1 == 3:
                break
            output = top1
        return outputs


if __name__ == "__main__":
    test_encoder = Encoder(20, 10, 5)
    test_decoder = Decoder(20, 10, 5)
    model = Seq2Seq(test_encoder, test_decoder)

    src = torch.randint(high=20, size=(20, 8))
    trg = torch.randint(high=20, size=(10, 8))

    res = model(src, trg)
    print(res.shape)

    test_sen = torch.randint(high=20, size=(20, 1))
    res = model.translate(test_sen, 10)
    print(res)
# Out:
# torch.Size([10, 8, 20])
# [18, 18, 6, 18, 6, 18, 18, 6, 18, 6]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
from collections import Counter


class Vocabulary(object):
    """a vocabulary for NLP corpus"""

    def __init__(self, max_vocab_size=50000, min_count=None, start_end_tokens=False, name="Vocabulary1"):
        self.name = name
        self.max_vocab_size = max_vocab_size
        self.min_count = min_count
        self.start_end_tokens = start_end_tokens  # whether include start and end tokens
        self.vocabulary_size = 2
        self.word2idx = {"<UNK>": 0, "<PAD>": 1}
        self.idx2word = ["<UNK>", "<PAD>"]
        self.idx2count = [0, 0]

    def buildVocabulary(self, data):
        """
        method to build a vocabulary
        :param list data: a list of strings, with each string being a sentence
        :return: None
        """
        # add start and end token
        if self.start_end_tokens:
            self.idx2word += ['<SOS>', '<EOS>']
            self.vocabulary_size += 2

        # count words
        counter = Counter(
            [word for sentence in data for word in sentence.split()])
        # filter words by their counts
        if self.max_vocab_size:
            counter = {word: freq for word, freq in counter.most_common(self.max_vocab_size - self.vocabulary_size)}
        # filter words with low frequency
        if self.min_count:
            counter = {word: freq for word, freq in counter.items() if freq >= self.min_count}

        # generate attributes
        self.idx2word += list(sorted(counter.keys()))
        self.idx2count = [counter.get(word, 0) for word in self.idx2word]
        self.word2idx = {word: idx for idx, word in enumerate(self.idx2word)}
        self.vocabulary_size = len(self.idx2word)

    def indexer(self, word):
        """
        return word index
        :param str word: the word to query
        :return: word index
        """
        try:
            return self.word2idx[word]
        except KeyError:
            return self.word2idx['<UNK>']

# %%
import jieba
import re
import random
import torch
import logging


# map Chinese punctuations into English punctuations
ch2en = {
    '！': '!',
    '？': '?',
    '。': '.',
    '（': '(',
    '）': ')',
    '，': ',',
    '：': ':',
    '；': ';',
    '｀': ','
}


def normalizeString(s):
    """
    lower case and trim punctuations and numbers
    :param str s: input string
    :return: normalised string
    """
    s = s.lower().strip()
    # check Chinese punctuations
    s = "".join(char if char not in ch2en.keys() else ch2en[char] for char in s)
    s = re.sub(r"([.!?])", r" \1", s)  # only keep . ! ?
    # keep alphabets, the three punctuations and Chinese characters
    s = re.sub(r"[^a-zA-Z.!?\u4e00-\u9fff]+", r" ", s)
    return s


def preprocess(data_path):
    """
    pre-process text data and return vocabularies
    :param str data_path: input data path
    :return: a list of lists of processed sentence pairs
    """
    # read data and split into pairs
    lines = open(data_path, encoding="utf-8").read().strip().split('\n')
    pairs = [[normalizeString(s) for s in line.split('\t')[:2]] for line in lines]

    # segment Chinese sentences
    # 这边会自己做分词
    for line in pairs:
        line[1] = " ".join(word for word in jieba.lcut(line[1]))

    return pairs

def Chpreprocess(data_path):
    """
    pre-process text data and return vocabularies
    :param str data_path: input data path
    :return: a list of lists of processed sentence pairs
    """
    # read data and split into pairs
    lines = open(data_path, encoding="utf-8").read().strip().split('\n')
    pairs = [[normalizeString(s) for s in line.split('\t')[:2]] for line in lines]

    # segment Chinese sentences
    # 这边会自己做分词
    for line in pairs:
        line[1] = " ".join(word for word in jieba.lcut(line[1]))
        line[0] = " ".join(word for word in jieba.lcut(line[0]))

    return pairs


def getVocabulary(pairs, input_lang, output_lang, max_vocab_size, reverse=False, start_end_tokens=True):
    """
    generate vocabularies for the pairs
    :param list pairs: language sentence pairs
    :param str input_lang: input language name
    :param str output_lang: output language name
    :param int max_vocab_size: max vocabulary size
    :param bool reverse: whether to inverse the input and output sentences
    :param bool start_end_tokens: whether to use start and end tokens
    :return: two vocabularies
    """
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]

    # initialise vocabularies
    input_vocab = Vocabulary(name=input_lang, start_end_tokens=start_end_tokens, max_vocab_size=max_vocab_size)
    output_vocab = Vocabulary(name=output_lang, start_end_tokens=start_end_tokens, max_vocab_size=max_vocab_size)
    input_sentences = []
    output_sentences = []

    # build vocabularies
    for pair in pairs:
        input_sentences.append(pair[0])
        output_sentences.append(pair[1])
    input_vocab.buildVocabulary(input_sentences)
    output_vocab.buildVocabulary(output_sentences)

    return input_vocab, output_vocab

def ChgetVocabulary(pairs, lang, max_vocab_size, reverse=False, start_end_tokens=True):
    """
    generate vocabularies for the pairs
    :param list pairs: language sentence pairs
    :param str input_lang: input language name
    :param str output_lang: output language name
    :param int max_vocab_size: max vocabulary size
    :param bool reverse: whether to inverse the input and output sentences
    :param bool start_end_tokens: whether to use start and end tokens
    :return: two vocabularies
    """
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]

    # initialise vocabularies
    vocab = Vocabulary(name=lang, start_end_tokens=start_end_tokens, max_vocab_size=max_vocab_size)
    sentences = []
    
    # build vocabularies
    for pair in pairs:
        sentences.append(pair[0])
        sentences.append(pair[1])
    vocab.buildVocabulary(sentences)

    return vocab


def sentence2index(vocabulary, sentence):
    """
    convert sentence into list of index
    :param Vocabulary vocabulary: the vocabulary of the language
    :param str sentence: input sentence
    :return: list of index
    """
    index = [vocabulary.indexer("<SOS>")]
    index += [vocabulary.indexer(word) for word in sentence.split()]
    index += [vocabulary.indexer("<EOS>")]
    return index


def train_test_split(data, test_split=0.3):
    """
    split data into train and text sets
    :param list data: text data list
    :param float test_split: text proportion
    :return: train data and test data
    """
    size = len(data)
    split = size - int(size * test_split)
    random.seed(66)
    random.shuffle(data)
    return data[:split], data[split:]


def translation(sentence, model, max_length, src_vocab, trg_vocab):
    """
    translate one source sentence
    :param str sentence: source sentence
    :param model: the Seq2Seq model
    :param int max_length: max sentence length
    :param src_vocab: source language vocabulary
    :param trg_vocab: target language vocabulary
    :return: one target sentence
    """
    sentence = normalizeString(sentence)
    index = sentence2index(src_vocab, sentence)
    source = torch.LongTensor(index).unsqueeze(1)  # (T, 1)
    model = model.cpu()
    target = model.translate(source, max_length)
    target = [trg_vocab.idx2word[idx] for idx in target]
    if target[-1] == "<EOS>":
        target = target[:-1]
    return "".join(word for word in target)


def create_logger(filename):
    """
    create a logger
    :param str filename: log file name include path
    :return: logger
    """
    logger = logging.getLogger(__name__)
    fmt = '%(message)s'
    format_str = logging.Formatter(fmt)  # formatting
    logger.setLevel(logging.INFO)  # level
    sh = logging.StreamHandler()  # output on screen
    sh.setFormatter(format_str)  
    th = logging.FileHandler(filename)
    th.setFormatter(format_str)  # output into file
    logger.addHandler(sh)  
    logger.addHandler(th)
    return logger

logger = create_logger("training.log")

'''
# Out:
# '\nif __name__ == "__main__":\n    data = preprocess(Config.data_path)\n    English, Chinese = getVocabulary(data, "English", "Chinese", 10000)\n    index = sentence2index(Chinese, data[2046][1])\n    print(data[2046][1])\n    print(index)\n    print([Chinese.idx2word[idx] for idx in index])'

# %%
if __name__ == "__main__":
    data = Chpreprocess(Config.data_path)
    Chinese = ChgetVocabulary(data, "Chinese", 10000)
    index = sentence2index(Chinese, data[2046][1])
    print(data[2046][1])
    print(data[2046][0])
    print(index)
    print([Chinese.idx2word[idx] for idx in index])
# Out:
# 郑州 在 哪个 省
# 郑州 是 哪个 省 的
# [2, 9136, 2576, 2347, 6969, 3]
# ['<SOS>', '郑州', '在', '哪个', '省', '<EOS>']

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class TranslationData(Dataset):

    def __init__(self, data, src_vocab, trg_vocab):
        """
        Dataset for translation
        :param list data: processed data
        :param src_vocab: source language vocabulary
        :param trg_vocab: target language vocabulary
        """
        super(TranslationData, self).__init__()
        self.data = data
        self.src_vocab = src_vocab
        self.trg_vocab = trg_vocab

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_sentence = self.data[idx][0]
        trg_sentence = self.data[idx][1]
        src_index = sentence2index(self.src_vocab, src_sentence)
        trg_index = sentence2index(self.trg_vocab, trg_sentence)
        src = torch.LongTensor(src_index)
        trg = torch.LongTensor(trg_index)
        return src, trg


def collate_fn(batch):
    """
    customized collate function to dynamically padding mini-batches
    :param batch: the list of samples from Dataloader
    :return: padded mini-batch
    """
    pad_index = 1  # the <PAD> index in vocabulary
    src_list = [sample[0] for sample in batch]  # list of each language sentences
    trg_list = [sample[1] for sample in batch]

    def padding(sentence_list):
        """padding each sentence to the right"""
        max_len = max([sentence.size(0) for sentence in sentence_list])
        pad_sen = [sen.tolist() + [pad_index] * max(0, max_len - len(sen))
                   for sen in sentence_list]
        return torch.LongTensor(pad_sen).transpose(0, 1)  # shape of (T, B)

    return padding(src_list), padding(trg_list)
# Out:
# 'if __name__ == "__main__":\n    data = Chpreprocess(Config.data_path)\n    src_vocab = ChgetVocabulary(data,"Chinese",10000)\n    trg_vocab = src_vocab\n    dataset = TranslationData(data, src_vocab, trg_vocab)\n    source, target = dataset[66]\n    print(source.size())\n    print(target.size())\n    loader = DataLoader(dataset, batch_size=4, collate_fn=collate_fn)\n    for i, batch in enumerate(loader):\n        source, target = batch\n        print(source.size())\n        print(target.size())\n        break'

# %%
import torch
from torch.nn.utils import clip_grad_norm_
from datetime import datetime


def train(model, dataloader, optimizer, criterion, vocab_size, grad_clip, teacher_forcing):
    """
    training over one epoch
    :param model: the Seq2Seq model
    :param dataloader: training dataloader
    :param optimizer: training optimiser
    :param criterion: loss function
    :param vocab_size: target vocabulary size
    :param grad_clip: max gradient
    :param teacher_forcing: teacher forcing ratio for training
    :return: list of losses per 100 mini-batches
    """
    model.to(Config.device)
    model.train()
    batch_losses = []
    batch_loss = 0
    n_batches = len(dataloader)
    for i, batch in enumerate(dataloader):
        source, target = batch
        source = source.to(Config.device)
        target = target.to(Config.device)
        target_len = target.size(0)
        optimizer.zero_grad()
        output = model(source, target, teacher_forcing).to(Config.device)  # forward propagation
        #output = output.to(Config.device)
        loss = criterion(output[1:].view(-1, vocab_size),
                         target[1:].contiguous().view(-1))  # calculate NLL loss, ignore first token <SOS>
        loss.backward()  # backward propagation
        clip_grad_norm_(model.parameters(), grad_clip)  # clip gradients
        optimizer.step()  # update parameters
        batch_loss += loss.data.item() / target_len

        # print results every 100 mini-batches
        if i % 100 == 0 and i != 0:
            batch_loss = batch_loss / 100  # average loss
            batch_losses.append(batch_loss)
            logger.info("%s | Finished %.1f%% | Mini-batch %d | Avg Loss: %5.2f" %
                        (datetime.now().strftime('%H:%M:%S'), (i+1) / n_batches * 100, i+1, batch_loss))
            batch_loss = 0
    return batch_losses


def evaluate(model, dataloader, criterion, vocab_size):
    """
    evaluation over one epoch
    :param model: the Seq2Seq model
    :param dataloader: training dataloader
    :param criterion: loss function
    :param vocab_size: target vocabulary size
    :return: average evaluation loss
    """
    with torch.no_grad():
        model.eval()
        eval_loss = 0
        batch_loss = 0
        n_batches = len(dataloader)
        for i, batch in enumerate(dataloader):
            source, target = batch
            source = source.to(Config.device)
            target = target.to(Config.device)
            target_len = target.size(0)
            output = model(source, target, teacher_forcing=0.0)  # forward propagation
            output = output.to(Config.device)
            loss = criterion(output[1:].view(-1, vocab_size),
                             target[1:].contiguous().view(-1))  # calculate NLL loss
            eval_loss += loss.data.item() / target_len
            batch_loss += loss.data.item() / target_len

            # print results every 100 mini-batches
            if i % 100 == 0 and i != 0:
                batch_loss = batch_loss / 100  # average loss
                logger.info("%s | Finished %.1f%% | Mini-batch %d | Avg Loss: %5.2f" %
                            (datetime.now().strftime('%H:%M:%S'), (i + 1) / n_batches * 100, i + 1, batch_loss))
                batch_loss = 0
    return eval_loss / len(dataloader)

# %%
import torch
from torch.utils.data import DataLoader
from torch.nn import NLLLoss
from torch import optim

from datetime import datetime
import pickle

# %%
import torch
from torch.utils.data import DataLoader
from torch.nn import NLLLoss
from torch import optim

from datetime import datetime
import pickle


'''# import and process data
data = preprocess(Config.data_path)
# data = data[:5000]  # test a small set
en_vocab, cn_vocab = getVocabulary(data, "English", "Chinese", Config.max_vocab_size)
train_data, eval_data = train_test_split(data, test_split=0.3)'''

# import and process data
data = Chpreprocess("/content/drive/MyDrive/all.txt")
#data = data[:5000]  # test a small set
cn_vocab = ChgetVocabulary(data, "Chinese", Config.max_vocab_size)
train_data, eval_data = train_test_split(data, test_split=0.3)

for parameter in Config.parameter_list[2:3]:
    print(parameter)
    embedding_size = parameter[0]
    hidden_size = parameter[1]
    dropout = parameter[2]
    teacher_forcing = parameter[3]
    batch_size = parameter[4]
    learning_rate = parameter[5]
    print("目前参数情况为:",embedding_size,',',hidden_size,',',dropout,',',teacher_forcing,',',batch_size,',',learning_rate)
    # get dataloader
    train_dataset = TranslationData(train_data, cn_vocab, cn_vocab)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=collate_fn)

    eval_dataset = TranslationData(eval_data, cn_vocab, cn_vocab)
    eval_loader = DataLoader(eval_dataset, batch_size=batch_size, collate_fn=collate_fn)

    # prepare training
    encoder = Encoder(cn_vocab.vocabulary_size, embedding_size, hidden_size, Config.n_layers, dropout)
    decoder = Decoder(cn_vocab.vocabulary_size, embedding_size, hidden_size, Config.n_layers, dropout)
    model2 = Seq2Seq(encoder, decoder)
    model2 = model2.to(Config.device)

    optimizer = optim.Adam(model2.parameters(), lr=learning_rate)
    criterion = NLLLoss(ignore_index=1)  # ignore padding index

    # training epochs
    training_losses = []
    best_eval_loss = 100000
    for epoch in range(Config.epochs):
        logger.info(f"\n{datetime.now().strftime('%H:%M:%S')} | Training epoch {epoch+1} ...")
        logger.info("-" * 30)
        training_losses += train(model2, train_loader, optimizer, criterion, cn_vocab.vocabulary_size,
                  Config.grad_clip, teacher_forcing)
        logger.info(f"\n{datetime.now().strftime('%H:%M:%S')} | Evaluating epoch {epoch + 1} ...")
        logger.info("-" * 30)
        eval_loss = evaluate(model2, eval_loader, criterion, cn_vocab.vocabulary_size)
        print('eval_loss',eval_loss)
        if eval_loss < best_eval_loss:
            best_eval_loss = eval_loss
            logger.info(f"\n{datetime.now().strftime('%H:%M:%S')} | Saving model2 ...")
            torch.save(model2.state_dict(), "seq2seq.bin")
            with open('training_losses.bin', 'wb') as f:
                pickle.dump(training_losses, f)
        with open('eval_loss.bin', 'wb') as f:
            pickle.dump(eval_loss, f)
        sentence = "明天 要 出来 玩 吗"
        logger.info("\n[In] " + sentence)                  
        logger.info("[Out] " + translation(sentence, model2, Config.max_sentence_length, cn_vocab, cn_vocab))

        sentence = "脸大 适合 什么 发型"
        logger.info("\n[In] " + sentence)                  
        logger.info("[Out] " + translation(sentence, model2, Config.max_sentence_length, cn_vocab, cn_vocab))

        sentence = "如何 学 好 英语"
        logger.info("\n[In] " + sentence)                  
        logger.info("[Out] " + translation(sentence, model2, Config.max_sentence_length, cn_vocab, cn_vocab))
# Out:
# 14:42:17 | Training epoch 1 ...
#
# 14:42:17 | Training epoch 1 ...
#
# 14:42:17 | Training epoch 1 ...
#
# 14:42:17 | Training epoch 1 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# [300, 256, 0.5, 0.5, 32, 0.001]
# 目前参数情况为: 300 , 256 , 0.5 , 0.5 , 32 , 0.001
# 14:42:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.50
# 14:42:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.50
# 14:42:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.50
# 14:42:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.50
# 14:42:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.44
# 14:42:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.44
# 14:42:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.44
# 14:42:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.44
# 14:42:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.39
# 14:42:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.39
# 14:42:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.39
# 14:42:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.39
# 14:42:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.37
# 14:42:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.37
# 14:42:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.37
# 14:42:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.37
# 14:43:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.34
# 14:43:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.34
# 14:43:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.34
# 14:43:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.34
# 14:43:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.32
# 14:43:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.32
# 14:43:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.32
# 14:43:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.32
# 14:43:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.31
# 14:43:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.31
# 14:43:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.31
# 14:43:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.31
# 14:43:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.30
# 14:43:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.30
# 14:43:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.30
# 14:43:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.30
# 14:43:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.28
# 14:43:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.28
# 14:43:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.28
# 14:43:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.28
#
# 14:43:48 | Evaluating epoch 1 ...
#
# 14:43:48 | Evaluating epoch 1 ...
#
# 14:43:48 | Evaluating epoch 1 ...
#
# 14:43:48 | Evaluating epoch 1 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:43:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:43:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:43:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:43:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:43:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:43:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:43:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:43:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:43:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:43:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:43:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:43:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:43:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 14:43:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 14:43:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 14:43:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
#
# 14:43:57 | Saving model2 ...
#
# 14:43:57 | Saving model2 ...
#
# 14:43:57 | Saving model2 ...
#
# 14:43:57 | Saving model2 ...
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天的<UNK>玩吗
# [Out] 明天的<UNK>玩吗
# [Out] 明天的<UNK>玩吗
# [Out] 明天的<UNK>玩吗
# eval_loss 0.282463613214085
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 适合适合适合什么发型
# [Out] 适合适合适合什么发型
# [Out] 适合适合适合什么发型
# [Out] 适合适合适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何英语英语
# [Out] 如何英语英语
# [Out] 如何英语英语
# [Out] 如何英语英语
#
# 14:43:57 | Training epoch 2 ...
#
# 14:43:57 | Training epoch 2 ...
#
# 14:43:57 | Training epoch 2 ...
#
# 14:43:57 | Training epoch 2 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:44:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.26
# 14:44:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.26
# 14:44:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.26
# 14:44:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.26
# 14:44:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.25
# 14:44:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.25
# 14:44:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.25
# 14:44:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.25
# 14:44:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.23
# 14:44:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.23
# 14:44:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.23
# 14:44:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.23
# 14:44:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.23
# 14:44:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.23
# 14:44:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.23
# 14:44:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.23
# 14:44:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.21
# 14:44:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.21
# 14:44:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.21
# 14:44:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.21
# 14:44:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.20
# 14:44:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.20
# 14:44:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.20
# 14:44:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.20
# 14:45:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.20
# 14:45:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.20
# 14:45:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.20
# 14:45:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.20
# 14:45:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.20
# 14:45:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.20
# 14:45:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.20
# 14:45:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.20
# 14:45:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.19
# 14:45:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.19
# 14:45:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.19
# 14:45:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.19
#
# 14:45:27 | Evaluating epoch 2 ...
#
# 14:45:27 | Evaluating epoch 2 ...
#
# 14:45:27 | Evaluating epoch 2 ...
#
# 14:45:27 | Evaluating epoch 2 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:45:29 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:45:29 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:45:29 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:45:29 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:45:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:45:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:45:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:45:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:45:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:45:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:45:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:45:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:45:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:45:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:45:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:45:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
#
# 14:45:36 | Saving model2 ...
#
# 14:45:36 | Saving model2 ...
#
# 14:45:36 | Saving model2 ...
#
# 14:45:36 | Saving model2 ...
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天的<UNK>吗吗
# [Out] 明天的<UNK>吗吗
# [Out] 明天的<UNK>吗吗
# [Out] 明天的<UNK>吗吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# eval_loss 0.24761443086948481
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
#
# 14:45:36 | Training epoch 3 ...
#
# 14:45:36 | Training epoch 3 ...
#
# 14:45:36 | Training epoch 3 ...
#
# 14:45:36 | Training epoch 3 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:45:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.18
# 14:45:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.18
# 14:45:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.18
# 14:45:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.18
# 14:45:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.18
# 14:45:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.18
# 14:45:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.18
# 14:45:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.18
# 14:46:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.17
# 14:46:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.17
# 14:46:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.17
# 14:46:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.17
# 14:46:14 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.17
# 14:46:14 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.17
# 14:46:14 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.17
# 14:46:14 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.17
# 14:46:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.16
# 14:46:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.16
# 14:46:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.16
# 14:46:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.16
# 14:46:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.15
# 14:46:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.15
# 14:46:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.15
# 14:46:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.15
# 14:46:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.15
# 14:46:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.15
# 14:46:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.15
# 14:46:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.15
# 14:46:54 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.16
# 14:46:54 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.16
# 14:46:54 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.16
# 14:46:54 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.16
# 14:47:04 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.15
# 14:47:04 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.15
# 14:47:04 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.15
# 14:47:04 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.15
#
# 14:47:08 | Evaluating epoch 3 ...
#
# 14:47:08 | Evaluating epoch 3 ...
#
# 14:47:08 | Evaluating epoch 3 ...
#
# 14:47:08 | Evaluating epoch 3 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:47:10 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:47:10 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:47:10 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:47:10 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:47:12 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:47:12 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:47:12 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:47:12 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:47:15 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:47:15 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:47:15 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:47:15 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:47:17 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:47:17 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:47:17 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:47:17 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
#
# 14:47:17 | Saving model2 ...
#
# 14:47:17 | Saving model2 ...
#
# 14:47:17 | Saving model2 ...
#
# 14:47:17 | Saving model2 ...
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天的吗
# [Out] 明天明天的吗
# [Out] 明天明天的吗
# [Out] 明天明天的吗
#
# [In] 脸大 适合 什么 发型
# eval_loss 0.2417379962743903
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
#
# 14:47:17 | Training epoch 4 ...
#
# 14:47:17 | Training epoch 4 ...
#
# 14:47:17 | Training epoch 4 ...
#
# 14:47:17 | Training epoch 4 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:47:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.15
# 14:47:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.15
# 14:47:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.15
# 14:47:27 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.15
# 14:47:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.15
# 14:47:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.15
# 14:47:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.15
# 14:47:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.15
# 14:47:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.15
# 14:47:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.15
# 14:47:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.15
# 14:47:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.15
# 14:47:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.14
# 14:47:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.14
# 14:47:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.14
# 14:47:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.14
# 14:48:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.14
# 14:48:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.14
# 14:48:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.14
# 14:48:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.14
# 14:48:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.13
# 14:48:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.13
# 14:48:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.13
# 14:48:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.13
# 14:48:24 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.13
# 14:48:24 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.13
# 14:48:24 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.13
# 14:48:24 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.13
# 14:48:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.13
# 14:48:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.13
# 14:48:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.13
# 14:48:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.13
# 14:48:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.13
# 14:48:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.13
# 14:48:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.13
# 14:48:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.13
#
# 14:48:47 | Evaluating epoch 4 ...
#
# 14:48:47 | Evaluating epoch 4 ...
#
# 14:48:47 | Evaluating epoch 4 ...
#
# 14:48:47 | Evaluating epoch 4 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:48:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:48:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:48:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:48:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.25
# 14:48:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:48:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:48:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:48:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:48:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:48:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:48:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:48:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.24
# 14:48:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:48:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:48:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
# 14:48:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.24
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学学
# [Out] 如何学学
# [Out] 如何学学
# [Out] 如何学学
#
# 14:48:56 | Training epoch 5 ...
#
# 14:48:56 | Training epoch 5 ...
#
# 14:48:56 | Training epoch 5 ...
#
# 14:48:56 | Training epoch 5 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.24451459009220564
# 14:49:05 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.13
# 14:49:05 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.13
# 14:49:05 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.13
# 14:49:05 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.13
# 14:49:14 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.13
# 14:49:14 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.13
# 14:49:14 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.13
# 14:49:14 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.13
# 14:49:24 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.13
# 14:49:24 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.13
# 14:49:24 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.13
# 14:49:24 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.13
# 14:49:33 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.12
# 14:49:33 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.12
# 14:49:33 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.12
# 14:49:33 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.12
# 14:49:43 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.12
# 14:49:43 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.12
# 14:49:43 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.12
# 14:49:43 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.12
# 14:49:53 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.12
# 14:49:53 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.12
# 14:49:53 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.12
# 14:49:53 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.12
# 14:50:02 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.12
# 14:50:02 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.12
# 14:50:02 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.12
# 14:50:02 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.12
# 14:50:12 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.12
# 14:50:12 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.12
# 14:50:12 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.12
# 14:50:12 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.12
# 14:50:21 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.11
# 14:50:21 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.11
# 14:50:21 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.11
# 14:50:21 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.11
#
# 14:50:25 | Evaluating epoch 5 ...
#
# 14:50:25 | Evaluating epoch 5 ...
#
# 14:50:25 | Evaluating epoch 5 ...
#
# 14:50:25 | Evaluating epoch 5 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:50:28 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:50:28 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:50:28 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:50:28 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:50:30 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:50:30 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:50:30 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:50:30 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.24
# 14:50:32 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:50:32 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:50:32 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:50:32 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.25
# 14:50:34 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:50:34 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:50:34 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
# 14:50:34 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.25
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
# [Out] 明天明天有吗吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
#
# 14:50:34 | Training epoch 6 ...
#
# 14:50:34 | Training epoch 6 ...
#
# 14:50:34 | Training epoch 6 ...
#
# 14:50:34 | Training epoch 6 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.24934410824089887
# 14:50:44 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.12
# 14:50:44 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.12
# 14:50:44 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.12
# 14:50:44 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.12
# 14:50:53 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.11
# 14:50:53 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.11
# 14:50:53 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.11
# 14:50:53 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.11
# 14:51:03 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.11
# 14:51:03 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.11
# 14:51:03 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.11
# 14:51:03 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.11
# 14:51:12 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.11
# 14:51:12 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.11
# 14:51:12 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.11
# 14:51:12 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.11
# 14:51:21 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.11
# 14:51:21 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.11
# 14:51:21 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.11
# 14:51:21 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.11
# 14:51:31 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:51:31 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:51:31 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:51:31 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:51:41 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.11
# 14:51:41 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.11
# 14:51:41 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.11
# 14:51:41 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.11
# 14:51:50 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.11
# 14:51:50 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.11
# 14:51:50 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.11
# 14:51:50 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.11
# 14:52:00 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.10
# 14:52:00 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.10
# 14:52:00 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.10
# 14:52:00 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.10
#
# 14:52:04 | Evaluating epoch 6 ...
#
# 14:52:04 | Evaluating epoch 6 ...
#
# 14:52:04 | Evaluating epoch 6 ...
#
# 14:52:04 | Evaluating epoch 6 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:52:06 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:52:06 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:52:06 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:52:06 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.26
# 14:52:09 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:52:09 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:52:09 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:52:09 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:52:11 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:52:11 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:52:11 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:52:11 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:52:13 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:52:13 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:52:13 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:52:13 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天要玩吗吗
# [Out] 明天要玩吗吗
# [Out] 明天要玩吗吗
# [Out] 明天要玩吗吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
# [Out] 脸大适合适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学好
# [Out] 如何学好
# [Out] 如何学好
# [Out] 如何学好
#
# 14:52:13 | Training epoch 7 ...
#
# 14:52:13 | Training epoch 7 ...
#
# 14:52:13 | Training epoch 7 ...
#
# 14:52:13 | Training epoch 7 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.2554868944681214
# 14:52:23 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.10
# 14:52:23 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.10
# 14:52:23 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.10
# 14:52:23 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.10
# 14:52:32 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.10
# 14:52:32 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.10
# 14:52:32 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.10
# 14:52:32 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.10
# 14:52:41 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.10
# 14:52:41 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.10
# 14:52:41 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.10
# 14:52:41 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.10
# 14:52:51 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.10
# 14:52:51 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.10
# 14:52:51 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.10
# 14:52:51 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.10
# 14:53:00 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.10
# 14:53:00 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.10
# 14:53:00 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.10
# 14:53:00 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.10
# 14:53:10 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:53:10 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:53:10 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:53:10 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.10
# 14:53:19 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:53:19 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:53:19 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:53:19 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:53:29 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.09
# 14:53:29 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.09
# 14:53:29 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.09
# 14:53:29 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.09
# 14:53:38 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.09
# 14:53:38 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.09
# 14:53:38 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.09
# 14:53:38 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.09
#
# 14:53:43 | Evaluating epoch 7 ...
#
# 14:53:43 | Evaluating epoch 7 ...
#
# 14:53:43 | Evaluating epoch 7 ...
#
# 14:53:43 | Evaluating epoch 7 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:53:45 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:53:45 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:53:45 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:53:45 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:53:47 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:53:47 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:53:47 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:53:47 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.25
# 14:53:49 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:53:49 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:53:49 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:53:49 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.26
# 14:53:51 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:53:51 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:53:51 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
# 14:53:51 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.26
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天要玩玩吗
# [Out] 明天要玩玩吗
# [Out] 明天要玩玩吗
# [Out] 明天要玩玩吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学英语好
# [Out] 如何学英语好
# [Out] 如何学英语好
# [Out] 如何学英语好
#
# 14:53:52 | Training epoch 8 ...
#
# 14:53:52 | Training epoch 8 ...
#
# 14:53:52 | Training epoch 8 ...
#
# 14:53:52 | Training epoch 8 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.2608012283280472
# 14:54:01 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.09
# 14:54:01 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.09
# 14:54:01 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.09
# 14:54:01 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.09
# 14:54:10 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.09
# 14:54:10 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.09
# 14:54:10 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.09
# 14:54:10 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.09
# 14:54:20 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.09
# 14:54:20 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.09
# 14:54:20 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.09
# 14:54:20 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.09
# 14:54:29 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.09
# 14:54:29 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.09
# 14:54:29 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.09
# 14:54:29 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.09
# 14:54:38 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.09
# 14:54:38 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.09
# 14:54:38 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.09
# 14:54:38 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.09
# 14:54:48 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:54:48 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:54:48 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:54:48 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:54:58 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:54:58 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:54:58 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:54:58 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.09
# 14:55:07 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:55:07 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:55:07 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:55:07 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:55:17 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.08
# 14:55:17 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.08
# 14:55:17 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.08
# 14:55:17 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.08
#
# 14:55:21 | Evaluating epoch 8 ...
#
# 14:55:21 | Evaluating epoch 8 ...
#
# 14:55:21 | Evaluating epoch 8 ...
#
# 14:55:21 | Evaluating epoch 8 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:55:23 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:55:23 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:55:23 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:55:23 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.27
# 14:55:25 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.26
# 14:55:25 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.26
# 14:55:25 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.26
# 14:55:25 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.26
# 14:55:28 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.27
# 14:55:28 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.27
# 14:55:28 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.27
# 14:55:28 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.27
# 14:55:30 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.27
# 14:55:30 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.27
# 14:55:30 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.27
# 14:55:30 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.27
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天有<UNK>吗
# [Out] 明天明天有<UNK>吗
# [Out] 明天明天有<UNK>吗
# [Out] 明天明天有<UNK>吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
# [Out] 如何学英语
#
# 14:55:30 | Training epoch 9 ...
#
# 14:55:30 | Training epoch 9 ...
#
# 14:55:30 | Training epoch 9 ...
#
# 14:55:30 | Training epoch 9 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.26670312200290075
# 14:55:40 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:55:40 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:55:40 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:55:40 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:55:49 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.08
# 14:55:49 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.08
# 14:55:49 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.08
# 14:55:49 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.08
# 14:55:58 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:55:58 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:55:58 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:55:58 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:56:08 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.08
# 14:56:08 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.08
# 14:56:08 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.08
# 14:56:08 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.08
# 14:56:17 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.08
# 14:56:17 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.08
# 14:56:17 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.08
# 14:56:17 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.08
# 14:56:27 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:56:27 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:56:27 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:56:27 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.08
# 14:56:37 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.08
# 14:56:37 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.08
# 14:56:37 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.08
# 14:56:37 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.08
# 14:56:46 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:56:46 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:56:46 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:56:46 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.08
# 14:56:56 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:56:56 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:56:56 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:56:56 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
#
# 14:57:00 | Evaluating epoch 9 ...
#
# 14:57:00 | Evaluating epoch 9 ...
#
# 14:57:00 | Evaluating epoch 9 ...
#
# 14:57:00 | Evaluating epoch 9 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:57:02 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.28
# 14:57:02 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.28
# 14:57:02 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.28
# 14:57:02 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.28
# 14:57:04 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:57:04 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:57:04 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:57:04 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:57:06 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:57:06 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:57:06 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:57:06 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:57:09 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:57:09 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:57:09 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:57:09 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天的黄金吗
# [Out] 明天的黄金吗
# [Out] 明天的黄金吗
# [Out] 明天的黄金吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 怎样学英语
# [Out] 怎样学英语
# [Out] 怎样学英语
# [Out] 怎样学英语
#
# 14:57:09 | Training epoch 10 ...
#
# 14:57:09 | Training epoch 10 ...
#
# 14:57:09 | Training epoch 10 ...
#
# 14:57:09 | Training epoch 10 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.2752947344399334
# 14:57:18 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:57:18 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:57:18 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:57:18 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.08
# 14:57:27 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:57:27 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:57:27 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:57:27 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:57:37 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:57:37 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:57:37 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:57:37 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.08
# 14:57:46 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:57:46 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:57:46 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:57:46 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:57:56 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:57:56 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:57:56 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:57:56 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:58:06 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.07
# 14:58:06 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.07
# 14:58:06 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.07
# 14:58:06 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.07
# 14:58:15 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:58:15 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:58:15 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:58:15 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:58:24 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 14:58:24 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 14:58:24 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 14:58:24 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 14:58:34 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:58:34 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:58:34 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
# 14:58:34 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.07
#
# 14:58:38 | Evaluating epoch 10 ...
#
# 14:58:38 | Evaluating epoch 10 ...
#
# 14:58:38 | Evaluating epoch 10 ...
#
# 14:58:38 | Evaluating epoch 10 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 14:58:40 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:58:40 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:58:40 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:58:40 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.29
# 14:58:43 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:58:43 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:58:43 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:58:43 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.27
# 14:58:45 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:58:45 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:58:45 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:58:45 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.28
# 14:58:47 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:58:47 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:58:47 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
# 14:58:47 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.28
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天玩玩吗
# [Out] 明天明天玩玩吗
# [Out] 明天明天玩玩吗
# [Out] 明天明天玩玩吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合人适合什么发型
# [Out] 脸大适合人适合什么发型
# [Out] 脸大适合人适合什么发型
# [Out] 脸大适合人适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 怎样学英语
# [Out] 怎样学英语
# [Out] 怎样学英语
# [Out] 怎样学英语
#
# 14:58:47 | Training epoch 11 ...
#
# 14:58:47 | Training epoch 11 ...
#
# 14:58:47 | Training epoch 11 ...
#
# 14:58:47 | Training epoch 11 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.2818172905786448
# 14:58:57 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.07
# 14:58:57 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.07
# 14:58:57 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.07
# 14:58:57 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.07
# 14:59:06 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:59:06 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:59:06 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:59:06 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.07
# 14:59:15 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.07
# 14:59:15 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.07
# 14:59:15 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.07
# 14:59:15 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.07
# 14:59:25 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:59:25 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:59:25 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:59:25 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.07
# 14:59:34 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:59:34 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:59:34 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:59:34 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.07
# 14:59:44 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 14:59:44 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 14:59:44 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 14:59:44 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 14:59:54 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:59:54 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:59:54 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 14:59:54 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.07
# 15:00:03 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 15:00:03 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 15:00:03 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 15:00:03 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.07
# 15:00:13 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:00:13 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:00:13 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:00:13 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
#
# 15:00:17 | Evaluating epoch 11 ...
#
# 15:00:17 | Evaluating epoch 11 ...
#
# 15:00:17 | Evaluating epoch 11 ...
#
# 15:00:17 | Evaluating epoch 11 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 15:00:19 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.30
# 15:00:19 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.30
# 15:00:19 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.30
# 15:00:19 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.30
# 15:00:21 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.28
# 15:00:21 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.28
# 15:00:21 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.28
# 15:00:21 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.28
# 15:00:23 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.29
# 15:00:23 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.29
# 15:00:23 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.29
# 15:00:23 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.29
# 15:00:26 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 15:00:26 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 15:00:26 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
# 15:00:26 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.29
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天有玩好吗
# [Out] 明天有玩好吗
# [Out] 明天有玩好吗
# [Out] 明天有玩好吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 怎样学好
# [Out] 怎样学好
# [Out] 怎样学好
# [Out] 怎样学好
#
# 15:00:26 | Training epoch 12 ...
#
# 15:00:26 | Training epoch 12 ...
#
# 15:00:26 | Training epoch 12 ...
#
# 15:00:26 | Training epoch 12 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# eval_loss 0.28989362710661337
# 15:00:35 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.06
# 15:00:35 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.06
# 15:00:35 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.06
# 15:00:35 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.06
# 15:00:44 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.06
# 15:00:44 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.06
# 15:00:44 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.06
# 15:00:44 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.06
# 15:00:54 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.06
# 15:00:54 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.06
# 15:00:54 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.06
# 15:00:54 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.06
# 15:01:03 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.06
# 15:01:03 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.06
# 15:01:03 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.06
# 15:01:03 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.06
# 15:01:13 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.06
# 15:01:13 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.06
# 15:01:13 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.06
# 15:01:13 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.06
# 15:01:23 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 15:01:23 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 15:01:23 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 15:01:23 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.06
# 15:01:32 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.06
# 15:01:32 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.06
# 15:01:32 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.06
# 15:01:32 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.06
# 15:01:41 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.06
# 15:01:41 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.06
# 15:01:41 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.06
# 15:01:41 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.06
# 15:01:51 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:01:51 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:01:51 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
# 15:01:51 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.06
#
# ...
# 17:20:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:20:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:20:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:20:36 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:20:46 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:20:46 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:20:46 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:20:46 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:20:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:20:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:20:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:20:55 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:21:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:21:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:21:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:21:05 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:21:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:21:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:21:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:21:15 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:21:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:21:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:21:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:21:25 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:21:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:21:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:21:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:21:34 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:21:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:21:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:21:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:21:44 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
#
# 17:21:48 | Evaluating epoch 97 ...
#
# 17:21:48 | Evaluating epoch 97 ...
#
# 17:21:48 | Evaluating epoch 97 ...
#
# 17:21:48 | Evaluating epoch 97 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:21:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:21:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:21:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:21:50 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:21:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:21:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:21:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:21:52 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:21:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:21:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:21:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:21:55 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:21:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:21:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:21:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:21:57 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 那明天怎么玩
# [Out] 那明天怎么玩
# [Out] 那明天怎么玩
# [Out] 那明天怎么玩
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 适合适合什么发型
# [Out] 适合适合什么发型
# [Out] 适合适合什么发型
# [Out] 适合适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# eval_loss 0.5206549898552084
# [Out] <UNK>的英语好
# [Out] <UNK>的英语好
# [Out] <UNK>的英语好
# [Out] <UNK>的英语好
#
# 17:21:57 | Training epoch 98 ...
#
# 17:21:57 | Training epoch 98 ...
#
# 17:21:57 | Training epoch 98 ...
#
# 17:21:57 | Training epoch 98 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:22:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:22:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:22:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:22:07 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:22:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:22:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:22:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:22:16 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:22:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:22:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:22:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:22:25 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:22:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:22:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:22:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:22:35 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:22:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:22:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:22:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:22:44 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:22:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:22:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:22:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:22:54 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:23:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:23:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:23:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:23:04 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:23:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:23:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:23:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:23:13 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:23:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:23:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:23:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:23:23 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
#
# 17:23:28 | Evaluating epoch 98 ...
#
# 17:23:28 | Evaluating epoch 98 ...
#
# 17:23:28 | Evaluating epoch 98 ...
#
# 17:23:28 | Evaluating epoch 98 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:23:30 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:23:30 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:23:30 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:23:30 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:23:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:23:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:23:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:23:32 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:23:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:23:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:23:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:23:34 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.52
# 17:23:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:23:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:23:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:23:36 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型发型
# [Out] 脸大适合什么发型发型
# [Out] 脸大适合什么发型发型
# [Out] 脸大适合什么发型发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# eval_loss 0.5219150860632875
# [Out] 如何学英语好
# [Out] 如何学英语好
# [Out] 如何学英语好
# [Out] 如何学英语好
#
# 17:23:37 | Training epoch 99 ...
#
# 17:23:37 | Training epoch 99 ...
#
# 17:23:37 | Training epoch 99 ...
#
# 17:23:37 | Training epoch 99 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:23:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:23:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:23:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:23:46 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:23:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:23:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:23:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:23:55 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:24:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:24:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:24:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:24:05 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:24:15 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:24:15 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:24:15 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:24:15 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:24:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:24:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:24:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:24:24 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:24:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:24:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:24:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:24:34 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:24:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:24:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:24:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:24:44 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:24:53 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:24:53 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:24:53 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:24:53 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:25:03 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:25:03 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:25:03 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:25:03 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
#
# 17:25:07 | Evaluating epoch 99 ...
#
# 17:25:07 | Evaluating epoch 99 ...
#
# 17:25:07 | Evaluating epoch 99 ...
#
# 17:25:07 | Evaluating epoch 99 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:25:09 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:25:09 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:25:09 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:25:09 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:25:11 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:25:11 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:25:11 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:25:11 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:25:14 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:25:14 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:25:14 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:25:14 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:25:16 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:25:16 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:25:16 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:25:16 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
# [Out] 明天的明天玩吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 适合适合什么发型适合什么发型
# [Out] 适合适合什么发型适合什么发型
# [Out] 适合适合什么发型适合什么发型
# [Out] 适合适合什么发型适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# eval_loss 0.521427924331078
# [Out] 好的英语好
# [Out] 好的英语好
# [Out] 好的英语好
# [Out] 好的英语好
#
# 17:25:16 | Training epoch 100 ...
#
# 17:25:16 | Training epoch 100 ...
#
# 17:25:16 | Training epoch 100 ...
#
# 17:25:16 | Training epoch 100 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:25:26 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:25:26 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:25:26 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:25:26 | Finished 10.7% | Mini-batch 101 | Avg Loss:  0.01
# 17:25:35 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:25:35 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:25:35 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:25:35 | Finished 21.2% | Mini-batch 201 | Avg Loss:  0.01
# 17:25:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:25:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:25:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:25:45 | Finished 31.8% | Mini-batch 301 | Avg Loss:  0.01
# 17:25:54 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:25:54 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:25:54 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:25:54 | Finished 42.3% | Mini-batch 401 | Avg Loss:  0.01
# 17:26:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:26:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:26:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:26:04 | Finished 52.8% | Mini-batch 501 | Avg Loss:  0.01
# 17:26:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:26:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:26:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:26:14 | Finished 63.4% | Mini-batch 601 | Avg Loss:  0.01
# 17:26:23 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:26:23 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:26:23 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:26:23 | Finished 73.9% | Mini-batch 701 | Avg Loss:  0.01
# 17:26:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:26:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:26:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:26:33 | Finished 84.5% | Mini-batch 801 | Avg Loss:  0.01
# 17:26:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:26:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:26:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
# 17:26:43 | Finished 95.0% | Mini-batch 901 | Avg Loss:  0.01
#
# 17:26:47 | Evaluating epoch 100 ...
#
# 17:26:47 | Evaluating epoch 100 ...
#
# 17:26:47 | Evaluating epoch 100 ...
#
# 17:26:47 | Evaluating epoch 100 ...
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 17:26:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:26:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:26:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:26:49 | Finished 24.9% | Mini-batch 101 | Avg Loss:  0.53
# 17:26:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:26:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:26:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:26:51 | Finished 49.5% | Mini-batch 201 | Avg Loss:  0.51
# 17:26:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:26:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:26:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:26:53 | Finished 74.1% | Mini-batch 301 | Avg Loss:  0.53
# 17:26:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:26:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:26:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
# 17:26:56 | Finished 98.8% | Mini-batch 401 | Avg Loss:  0.52
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
#
# [In] 明天 要 出来 玩 吗
# [Out] 明天明天好吗
# [Out] 明天明天好吗
# [Out] 明天明天好吗
# [Out] 明天明天好吗
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
#
# [In] 脸大 适合 什么 发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
# [Out] 脸大适合什么发型
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
#
# [In] 如何 学 好 英语
# [Out] 如何学好好
# [Out] 如何学好好
# [Out] 如何学好好
# [Out] 如何学好好
# eval_loss 0.522228732979889

# %%
model2
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(10000, 300)
#     (lstm): LSTM(300, 256, num_layers=2, dropout=0.5, bidirectional=True)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(10000, 300)
#     (lstm): LSTM(556, 256, num_layers=2, dropout=0.5)
#     (attention): Attention(
#       (attn1): Linear(in_features=512, out_features=256, bias=True)
#       (attn2): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (out): Linear(in_features=512, out_features=10000, bias=True)
#   )
# )

# %%
torch.save(model.state_dict(), "test22.bin")

# %%
f=open('/content/drive/MyDrive/测试原句子.txt','r',encoding='utf-8')
test_lst=[]
lines = f.readlines()      #读取全部内容 ，并以列表方式返回
for line in lines:
    line=line.replace('\n','')
    line=line.replace('\t','')
    test_lst.append(line)

result2=[]
count=0
for word in test_lst:
  word = " ".join(word for word in jieba.lcut(word))
  resu = translation(word, model2, Config.max_sentence_length, cn_vocab, cn_vocab)
  print(word,' ',resu)
  temp=word+' '+resu
  result2.append(temp)
  count+=1
  if count % 100 == 0:
    f=open('result2.txt','w',encoding='utf-8')
    for line in result2:
      f.write(line+'\n')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 父亲 给 我 上 的 一堂课 阅读 答案   父亲给我上的<UNK>阅读答案
# 怎么 看 淘宝 年度 账单   淘宝年度看账单怎么
# 带字 女生 头像   女生头像头像
# 性价比 较 高 的 平板 电脑   是<UNK>平板电脑电脑
# 成龙 最新 电影 叫 什么   成龙最新电影电影什么
# 奶粉 什么 牌子 比较 好 呀   什么牌子的奶粉好
# 天涯 明月刀 电视剧 好看 吗 ？ 大家   天涯明月刀到底到底有人说他
# 虎落平阳 一 ( ) 歇后语   虎落平阳歇后语
# 手机 有 什么 软件 可以 赚钱   手机有什么软件可以赚钱
# 怎么 才能 去掉 黑痣   <UNK>怎么去掉
# 怎么 查找 同名同姓 的 人   如何查找同名同姓的人
# 脸上 的 麻子 怎么 去掉   脸上有麻子怎么去掉
# 镜子 和 照片 哪个 更 真实 些   照片和照片哪个更真实
# 迅雷 继续 下载 没 资源   迅雷下载资源不足
# 孙俪 和 邓超 离婚 吗   孙俪和邓超离婚了吗
# 油烟机 哪个 牌子 好   什么牌子油烟机和好
# 能 看 下 红包 的 使用 范围 么   什么红包的红包最好
# 我 的 世界 电脑 版 如何 下载   我的世界电脑版怎么下载啊
# 亵渎 是 什么 意思   <UNK>什么意思
# 补肾 该 吃 什么 食物 啊   吃什么食物补肾
# 如何 登陆 新浪 博客   怎么登陆新浪游戏
# 呵呵 你 一脸 什么 意思   呵呵你一脸什么意思
# 如何 查询 驾驶证 真假   如何查询驾驶证真假
# 怎样 使 大腿 变瘦   怎样让让历史变瘦
# 情人节 送 什么 礼物 给 男朋友   情人节送什么礼物給男朋友
# 我 怎么 才 可以 注册 谷歌 账户   怎么才可以注册自己谷歌账户
# 天天 飞车 怎样 开挂   咋下载天天飞车
# 魔兽 世界 为什么 进不去 啊   魔兽世界为什么进不去为什么
# 最 吝啬 的 人 打 一 成语   最吝啬的人猜
# 这是 怎样 的 漫画 风格 呢   这是什么漫画风格
# 财富 值 怎么 获取   怎样获取财富值
# 全民 飞机 大战 宠物 哪个 好   全民大战飞机宠物哪个好
# 什么 时候 天气 回暖 了   天气什么时候能回暖啊?冷死了
# 女士 手表 有 哪些 品牌   品牌女士手表有哪些
# 如何 才能 删除 淘宝 帐号   淘宝如何删除才能
# 穿越 火线 为什么 老是 闪退   穿越火线穿越火线穿越火线两分钟就闪退了
# 慎 皮肤 哪个 好看   <UNK>哪个皮肤皮肤好看
# 南京 除了 莱迪 还 哪 卖 谜 尚   南京除了<UNK>哪还有卖<UNK><UNK>的
# 中通 快递 快 不快   中通快递工资的快
# 手机 谷歌 输入法 和 搜狗 输入法 哪个 更好   谷歌输入法和百度输入法和搜狗输入法哪个好
# 麦当劳 都 有些 什么 好吃 的   麦当劳有什么好吃的
# 观后感 - 那些 年 我们 一起 追过 的 女孩   给那些那些年一起追过的女孩
# 瓜子脸 适合 什么 刘海   瓜子脸适合什么刘海
# 学生证 乘车 区间 的 问题   学生证和对方的问题
# 神武 怎样 给 宠物   神武过生日怎样宠物宠物
# 手机 截屏 怎么 截 的   怎么手机截屏
# 这 衣服 配 什么 裤子 鞋子 呢   这鞋子搭什么衣服和裤子
# 有 哪些 表达 人间 真情 的 古诗   都的丰胸<UNK>那些啊
# 张智尧 版 楚留香 新传 什么 时候 播放   <UNK>版<UNK><UNK>什么时候播出啊
# 我 想 给 我 的 小侄女 起个 好听 的 名字   我想给我的<UNK>起个好听好听的名字
# 怎么 让 乳晕 变小   怎样让乳晕变小
# 怎么 找回 微信 密码   怎么找回微信密码呀
# 求 一本 都市 异能 系 小说   求一本都市异能小说
# 项链 什么 牌子 的   什么牌子项链
# 我 下载 的 游戏 玩 不了   为什么我下载下载游戏
# 安卓 手机 上 怎么 安装 两个 微信   手机手机上安装安装
# 电脑 为什么 不能 看 视频   为什么电脑电脑看不了视频
# 今年 春运 从 什么 时候 开始   今年春运从什么时候开始
# 手机 铃声 怎么 下载   怎么下载手机铃声
# 温州 有 哪里 好玩 点 的 吗   哪里有个吗
# 结婚证 在 哪里 都 能 办 吗   结婚证在哪里办手机吗
# 来自 神话故事 的 成语   神话传说时期的成语
# 买手机 分期付款   分期付款买手机请问哪里
# 求 桃子 老师 和 四个 学生 的 漫画   求桃子老师和他的漫画漫画
# 关于 传奇 单机 架设 的 问题   传奇架设架设问题
# 我 的 世界 代码 是 多少   我的世界代码大大
# 求 纯情 罗曼史 第一季 第二季   求纯情罗曼史第一季和
# 氯雷 他 定片   氯雷他
# 《 狐狸 和 葡萄 》 阅读 答案   狐狸与葡萄阅读答案
# 他 叫 我 小 心肝 是 什么 意思   别人叫我小心肝是什么意思
# 有 什么 好听 的 网络 歌曲 吗   有什么好听的网络歌曲
# 男人 什么 脸型 好看   男生什么脸型好看
# 怎么 把 余额 宝 的 钱 转入 支付宝   余额宝怎么转入支付宝
# 安徒生 被 称为 什么   安徒生被称为什么
# 贴 吧 密码 怎么 找回   怎样找回密码忘了
# 充电 宝 怎么样 才 算 充满   充电宝怎么算呀
# 金命 和 木命 在 一起 好 吗   <UNK>和<UNK>在一起吗
# 说 说 你们 心中 的 女神   女神是怎样的在你们心中
# 天津 哪里 有 卖 鞭炮 的   天津哪里可以卖
# 天然气 主要 成分 是 什么   天然气一直的主要成分是什么
# 全民 枪战 怎么 刷 钻石   全民枪战怎么得钻石
# 光宇 游戏 有 什么 好玩   有什么好玩的游戏
# 电脑 上 怎样 玩 手机 网游   电脑上怎么玩手机网游
# 用钱 折心 怎么 折 啊   在家<UNK>怎样折
# 哪里 有 射钉枪 买   哪里可以买射钉枪
# 爬书网 怎么 等 不 上   怎么去自己不<UNK>
# 大蒜 有 什么 好处   大蒜吃什么好处啊
# 苹果 手机 怎么 安装 两个 微信   苹果手机怎么安装两个微信
# 有 什么 好看 的 末世 之类 的 小说   有什么好看的末世小说
# 怎么 复制 别人 的 手机卡   怎么复制别人手机卡
# 洗衣 液 哪种 好   洗衣液哪种好啊
# 找 一部 美国 吸血鬼 的 电影   找一部吸血鬼电影的电影
# 身份证 丢失 人 在 外地 怎么 补办   身份证丢了怎么补办
# 近视眼 戴 凹透镜 还是 凸透镜   近视眼配凸透镜还是凹透镜
# 手表 在 哪里 可以 批发 到   哪里有批发手表的
# 怎么 去 黑头 和 收缩 毛孔   如何收缩毛孔和黑头
# 银行卡 可以 代办 吗 ？ 急   银行卡坏人去人吗
# 怎样 在家 做 蛋糕   怎么在家坐蛋糕
# 红绳 脚链 戴 哪 只 脚   <UNK><UNK>带哪<UNK>
# 写 一个 比喻句   <UNK>做一个比喻句
# 菊花茶 能 隔夜 吗   <UNK>可以买吗
# 电热水壶 ， 什么 牌子 好   什么牌子的电热水壶好
# 怎么 上 物流网   我怎么上
# 现在 有 什么 好 项目 可以 赚钱   现在有什么好的赚钱项目
# 谁 知道 这 女优 叫 什么 名字   谁知道这个女优的名字
# 反常 积分 的 计算   计算反常积分
# 作文 一件 令 我 感动 的 事   感动我的一件事作文
# 天天 酷跑 在 那里 下载 破解版   哪里下载天天酷跑的旺旺
# 手机号码 丢 了 ， 怎么 找回   怎么找回手机号码
# 毛衣 绣花 怎么 绣   怎么可以让超级上
# 怎样 穿 高跟鞋 走路   穿上高跟鞋怎样走路
# 这篇 课文   这篇课文是什么
# 初恋 这件 小事 所有 的 歌曲   初恋这件小事里所有歌曲
# 上海 适合 情侣 去 的 地方   上海适合情侣玩的地方
# 孕妇 吃 什么 补血 好   孕妇吃什么可以补血
# 太原 旅行社 哪家 好   太原哪家旅行社好呢
# 河南 工业 大学 贴 吧   河南工业大学
# 甲骨文 是 什么 意思   <UNK>什么意思
# 什么 牌子 的 耳机 音质 最好   什么牌子的耳机好一点啊
# 谁 知道 这是 什么 车标   谁知道这是什么的
# 谁 能 借 我 个 奥拉 星 的 号   谁有奥拉星的号
# 那些 年 我们 一起 追过 的 女孩 」 观后感   那些年我们一起追过的女孩观后感
# ‘ 复仇者 联盟 2 ’ 电影 高清 版本   复仇者联盟电影电影
# 奥 的 意思 是 什么   <UNK>什么意思
# 桃李满天下 中 的 桃李 指 的 是 什么   <UNK>的<UNK>是什么
# 问道 什么 宠物 好 啊   问道什么宠物好
# 怎样 下载 音乐 到 手机 上   手机音乐怎么下载音乐
# 前 鼻音 和 后 鼻音 是 怎么 区分 的   在天天和驱动通怎么给支付宝
# 玉兰油 化妆品 怎么样   玉兰油化妆品怎么样
# 在家 兼职 工作 有 哪些   在家有兼职工作
# 步步 惊情 剧情 大结局 是 什么   步步惊情最后结局结局什么生肖
# 打篮球 我 应该 在 什么 位置   我打篮球应该什么位置
# 什么 牌子 的 空压机 好   什么牌子的空压机好呢
# 人间 中毒 完整版 谁 有 地址   谁有人间中毒完整版完整版
# 中国象棋 的 残局   中国象棋<UNK>
# 描写 春天 的 古诗 有 哪些   有哪些描写春天的古诗
# 《 把 爱 带回家 》 主题曲   把把把主题曲主题曲
# 斗破 苍穹 漫画 怎样 下 栽   斗破苍穹漫画怎么看
# 邮政 国内 小包 快 吗   国内国内小包还最多吗
# 高血压 可以 吃 枸杞 吗   高血压能吃哪些吗
# 那些 花儿 吉他谱   那些历史的吉他谱
# 怎样 设置 新密码   <UNK>怎么设置
# 学习 英语 网站大全   英语学习学习
# 穿 的 奶罩 啥 颜色 的   穿的奶罩是什么颜色的
# 跑步机 什么 牌子 好 ， 家用   什么牌子的跑步机好
# 人间 中毒 未 删减 版   我的人间中毒无版
# 求 秋色 之空 全集 漫画   求秋色之空漫画全集
# 大学生 兼职 做 什么 赚钱 啊   大学生兼职做什么兼职赚钱啊
# 亲爱 的 你 在 哪里 原唱   亲爱的你在<UNK>原唱是谁
# 个性 霸气 的 女生 网名   给个性霸气的个性网名
# 现代 穿越 小说   穿越现代穿越小说
# 求 一个 郭德纲 的 相声   求郭德纲的一个相声
# 我 帮 您 转接 后 ， 看 一下 ， 是不是 有 其它 的 办法 帮到 您 的   我帮您转接一下是不是一下是不是有a其它的办法帮到您的
# 怎么 更新 显卡 驱动   怎么更新显卡更新
# 七年级 下 数学题   七年级网
# 怎么 查询 自己 的 身份证 号码   身份证号码怎么查询
# 本命年 戴 什么 呢   本命年戴什么好
# 我 朋友 结婚 要 送 什么 祝福语   好朋友结婚说什么祝福语
# 怎么 在 网上 报名   网上怎么网上
# 小 反刍 兽疫 疫苗 那里 有 的 卖   哪里卖小反刍兽疫<UNK>
# 手机 淘宝 怎样 秒杀 成功   怎样手机淘宝被如何打不开
# 这是 什么 字体 呢 ， 在线 等   急这是什么字体在线等
# 我 这个 配置 能 玩 热血 无赖 么   这配置能玩热血无赖吗
# 有 什么 好看 的 黑道 校园 小说   什么什么好看的黑道校园小说啊
# 这个 模特 什么 名字   求这个模特的名字
# 我 的 身份证 号码 是 什么   我的身份证号码是多少啊啊
# 这是 什么 漫画   这是什么漫画的
# 给 好 朋友 送 生日礼物   好朋友生日礼物送了
# 如何 和 小人 相处   如何和痘痘相处
# 麻烦 您 稍微 等待 一下 呢   麻烦你耐心的等待一下
# 国字 脸 适合 什么样 的 发型   女生国字脸适合什么样发型
# 如何 能 做好 生意   如何做好生意
# 三国演义 老版 全集   老版三国演义全集
# 有 谁 知道 这女 的 叫 什么 名字   我想知道这女的是谁叫什么名字
# 平板 电脑 哪个 品牌 好   平板电脑哪个品牌好
# 好玩 的 三国 游戏   那个好玩的三国游戏
# 取 服装店 名   只电视剧叫什么
# 滑膜炎 的 治疗 方法 是 什么   滑膜炎的方法都什么方法
# 把 我 的 名字 翻译成 韩文   把我的名字翻译成韩语
# 穿越 火线 怎么 窗口化 运行   穿越火线窗口化怎么设置
# 怎样 让 月经 来 快点   来月经月经来来
# 求 这 张图 完整 图片   这图片这图片在哪儿大
# 大家 看看 我 的 电脑配置 怎么样   大家大家看看我是怎么样
# 好听 的 吉他曲   好听的<UNK>
# 那里 袜子 批发 最 便宜   哪里批发袜子便宜
# 怎样 用纸 做 小 钱包   怎么用纸做小钱包
# 关于 房产交易 税 的 问题   <UNK><UNK>问题
# 桃子 老师 和 四个 学生   桃子与和四个学生发
# 关于 环保 的 图片 手抄报   就是环保的图片图片
# 笨蛋 测验 召唤兽 小说   笨蛋测验召唤兽小说
# 为什么 我 手机 不能 上网   为什么手机能不能上网
# 数学 圆 的 九年 级   数学数学哪些级
# 过期 的 可乐 能 喝 吧   可乐过期了还能喝吗
# 本事 最大 的 成语 是 什么   本事最大的成语是什么之最
# 这是 什么 蝴蝶 啊 ， 急   这是什么玄幻啊
# 现在 找 工作 怎么 就 那么 难 呢   现在工作找工作怎么找
# 湖北 农信 手机 银行 在 哪 下载   湖北农信手机银行下载下载
# 如何 编织 拖鞋   怎样编织拖鞋
# 什么 品牌 的 裤子 好 穿   什么品牌的裤子好
# 手机 淘宝 店铺 装修 怎么 设置   手机怎么装修店铺装修
# 求 一款 日本 游戏   一款日本的日本游戏
# 您 是否 操作 过 呢   您是否操作过呢
# 您 提供 一下 姓名 和 联系方式 给 您 联系 相关 人员 核实 的   这样的话您提供一下这个姓名和联系方式让相关人员给您核实处理一下
# 搞笑 的 歌曲   搞笑的歌曲
# 有 什么 好听 的 音乐 。 推荐 下   什么音乐好听.求推荐
# 现在 什么 小吃 最 赚钱   现在做什么小吃比较赚钱
# 有 什么 新 搞笑 电影 好看 的   有什么搞笑搞笑的电影搞笑好看
# 避孕套 有 大小 号 吗   避孕套有大小吗
# 求 一部 成龙 的 电影   求成龙演的一部电影
# 怎么 让 手变 嫩 又 白   如何让手变嫩
# 微积分 题求 极限   求解微积分极限
# 求 这 头像 大图   求这头像头像头像
# 明天 股市 如何   明天股市怎么走
# 苏州 明日 天气   苏州明天天气
# 小学 二年级 数学 作业   小学一些数学电影
# 薄弱 的 反义词 是 什么   <UNK>的反义词是什么么啊
# 求 圆环 的 面积   <UNK>的面积怎么
# 这边 是 客服 的 ， 请问 您 遇到 了 什么 问题   这边是在线客服的请问您遇到了什么问题
# 石家庄 哪个 驾校 好 一些   石家庄哪个驾校好
# 哪个 网站 可以 买到 好 的 书   想在什么网站买书好
# 熊出没 之 夺宝 熊兵   熊出没之之表情
# 快乐 大本营 今晚 嘉宾   快乐大本营快乐大本营的
# 求 红龙 女王 和 闪金镇 一夜   求红龙女王和闪金镇的小说
# 现在 的 热门 专业 有 哪些   现在十大专业专业有哪些
# 关于 微积分 求 极限 的 问题   微积分求极限的问题
# 有 什么 好看 搞笑 的 动漫 或 电影   有什么好看的搞笑动漫电影
# 在 网上 怎么 查 银行卡 的 开户行   银行卡的开户行怎么查
# 请问 这个 花 的 名字   请问这个花的名字叫什么
# 十七 败害 是 什么 意思   比跳是什么意思
# 二月 春风 是 什么 生肖   <UNK>虎的生肖
# 淘宝 删除 的 订单 怎么 恢复   淘宝淘宝张淘宝怎么恢复
# 支付宝 绑定 怎么 邮箱   支付宝怎么绑定支付宝
# 什么 化妆品 补水 效果 好   什么化妆品补水效果好
# 这个 图片 是 什么 电影   求这个是什么电影
# 适合 女生 的 网页 游戏   适合女生的网页游戏有什么
# 有 安徽 马鞍山 的 吗   有安徽马鞍山的人吗
# 稍 等 1 到 2 分钟   客气的<UNK>耐心
# 怎样 在 百度 上 推广   百度代理怎么做
# 淅淅沥沥 造句   用自己造句
# 如何 解决 大学 的 无聊 生活   大学生活如何做<UNK>鞋如何无聊
# 求 图片 中 植物 的 名称   求图片中植物名称
# 赞美 诗歌 怎样 下载   如何下载创建
# 自己 可以 给 自己 设定 微 信号 吗   微信号怎么设置我有qq号了自己随便弄吗
# 什么 是 妇科病 有 哪些 及 症状   妇科病有哪些症状
# 怎么样 才能 挽回 我 那 失去 的 爱情   怎么样才能看我的老婆啊
# 雷霆 战机 如何 开挂   雷霆战机怎么开挂
# 肾阳虚 吃 什么 药   肾阳虚吃什么药
# 淘宝 都 从 哪里 进货   淘宝哪里进货
# 建议您 退出 登录 重新 操作 试试 哦   建议您退出登录上传呢
# 我 把 同学 妈妈 搞 怀孕 了 怎么办   我的让妈妈老师了怎么办
# 是 谁 发明 的 足球   谁发明的上
# 天天 飞车 手 亚瑟 和 黄金 橘子 哪个 好   天天飞车亚瑟和黄金橘子哪个好
# 断蛟刺虎 是 什么 生肖   断蛟刺虎是什么生肖
# 谁 有 范冰冰 拍 的 苹果 完整版   范冰冰范冰冰完整版谁有
# a 种子 下载 地址 有 么 ？ 好人 一生 平安   种子下载地址有么?好人一生平安
# 古剑 奇谭 会 有 第二部 吗   古剑奇谭第二部有吗
# 梦幻 西游 为什么 进不去   为什么梦幻西游进不去就是淘宝
# 女生 应 如何 练 腹肌   女生怎么练腹肌
# 有 什么 好看 的 小说 关于 军婚 的   军婚的什么小说好看
# 吾爱 破解 邀请 码   ....吾爱破解邀请码
# 请问 这个 是 什么 字体 ， 急 在线 等   急这是什么字体在线等
# 怎样 生 龙凤胎   怎么生龙凤胎啊
# 陌陌 怎么 申请   怎么申请陌陌小说
# 石家庄 什么 最 好吃   石家庄什么什么好吃
# 求 大神 去 水印   求啥好么
# 这是 哪个 韩剧   这是什么韩剧
# 乌龟 最 喜欢 吃 什么   乌龟喜欢吃什么
# 我 想 给 女朋友 取个 外号   我想女朋友取个取个取个取个外号
# 李敏 镐 和 金秀贤 谁 人气 高   李敏镐金秀贤谁人气高
# 求 对角线 的 公式   求平行四边形求公式
# 给 刚出生 的 婴儿 装 枕头 用 什么 好   婴儿的枕头用什么装好
# 使徒 行者 插曲 叫 什么   使徒行者<UNK>插曲是什么
# 奥特曼 系列 的 电影 有 哪些   关于奥特曼系列得都有哪些
# 雪影 娃娃 在 哪 抓 如果 有 蛋 给 我 个   雪影娃娃在哪抓
# 君 之 记忆 伴奏   君<UNK>记忆伴奏
# 谁 有 这张 头像 的 情侣 头像   求这张头像的情侣头像
# 关于 古剑 奇谭 的 歌曲   古剑奇谭歌曲
# 全民 枪战 钻石 怎么 耍   全民枪战怎么得钻石
# 催眠 类 小说 合集   催眠小说大小说
# 什么 牌子 的 男士 袜子 好   男士袜子什么牌子好
# 怎样 折纸 飞机   如何折纸飞机
# 桂林 哪有 批发 氢气球 的   桂林批发批发<UNK>
# 你 知道 那个 动漫 叫 什么 名字 吗   谁知道这动漫叫什么名字
# 关于 宽带 移动 的 问题   移动宽带问题
# 是 谁 大闹 野猪林   大闹野猪林是谁
# 求 《 凤隐 天下 》 全文   求<UNK>天下全文
# 哪里 有 下载 来自 星星 的 你   在哪下载来自星星的你
# 关于 小额贷款   有哪些
# 女明星 谁 的 波 最大   女明星谁的胸最大
# 所有者 权益 变动表   <UNK><UNK>之<UNK>
# 怎么 下载 植物 大战 僵尸 冰雪 版   如何下载植物的植物大战僵尸
# 怎么 查询 驾驶证 有 多少 分   怎么查询驾驶证分
# 我 不会 英语   我不会说英语
# 怎么 举报 支付宝 账号   支付宝怎么举报支付宝
# 下水道 的 美人鱼 在 哪里 能 看   下水道美人鱼哪里可以在哪里美人鱼
# 一部 电视 的 名字 叫 什么   一部电视剧的名字是什么
# 怎么 参加 中国 新声 代   中国新声代中国代
# 学生票 优惠 区间 问题   学生票的优惠区间问题
# 霁月光风 ？ 猜 什么 生肖   霁月光风指什么生肖
# 我 查查 如何 下载   <UNK>怎么下载了
# 谁 知道 这是 什么 动漫   有谁知道这是什么动漫
# 电水壶 十大 品牌 排名   还有十大鞋子
# 快 过年 了 做 什么 最 挣钱   过年卖什么最挣钱
# 这是 什么 植物 ， 开花 吗   这是什么植物?在线的
# 在 网上 订 的 火车票 怎么 退票   网上买火车票怎么买机票
# 求 天使 消失 在 街角 全文 ， 谢 了   求<UNK><UNK>求<UNK>全文
# 寻 一部 欧美 老电影   一部欧美老电影
# 可以 赚钱 的 手机软件 是 什么   有什么软件可以赚钱又
# 乔振宇 跟 谢娜 是 什么 关系   乔振宇和谢娜什么关系
# 怎样 创建 个人主页 ， 在 哪里 创建 ， 在 哪里 申请   哪里可以网上申请个人主页
# 天亮 了 谁 唱 的   <UNK>谁谁唱的
# 什么 丰胸 产品 真的 有效   吃什么产品的丰胸
# 在 网上 办理 信用卡 有 真的 吗   网上办理网上信用卡是真的
# 杨 紫 和 张一山 结婚 了 吗   张一山结婚了么
# 孕妇 可以 吃 兔肉 吗   孕妇能吃兔肉吗
# 公积金 贷款 可以 买车 吗   公积金能贷款买车吗
# 一夜 惊喜 孩子 是 谁 的   一夜惊喜怀孩子谁的孩子
# 宝宝 奶粉 吃 到 几岁 好   宝宝几岁断奶粉
# 这个 密码锁 怎么 改 密码   门密码锁怎么改密码
# 包皮 红肿 瘙痒 吃 什么 药   包皮瘙痒红肿用什么药
# 朋友 结婚 有 什么 可以 说 的 祝福语 吗   我朋友结婚要送什么祝福语
# 安卓 系统 如何 升级   安卓系统如何升级
# 广州 那里 有 牛杂 批发   广州哪里有手机批发
# 手机 看 电视直播 什么 软件 好   手机有什么软件可以看电视直播
# 对 这个 看脸 的 世界 已经 绝望   妈蛋对这个<UNK>的世界绝望了
# 超 生二胎 如何 逃 罚款   生二胎怎样能喝酒
# 有 什么 免费 发短信 的 软件 吗   求免费发短信软件
# 如何 判断 一个 人 爱不爱 你   怎样判断一个人爱不爱你
# 哪里 能 买 到 吞卡 手电   哪里可以卖到哪里能看
# 如何 登陆 支付宝   怎样登陆支付宝
# 情侣 网名 不要 非主流   情侣网名不要非主流
# 这是 哪部 动漫 人物   这是哪部动漫的人物人物
# 什么 品牌 的 婴儿 理发器 好 一些 呢   什么牌子婴儿理发器好
# 搜狗 拼音输入 法   搜狗拼音输入法
# 剑灵 哪里 刷 雪花   剑灵哪里刷雪花
# 最近 哪部 电视剧 比较 好看   哪部电视剧比较好看好看
# 天天 酷跑 怎么 在 老 电脑 上 玩   电脑怎么玩天天酷跑
# 南宁 未来 几天 天气   南宁手机几天天气
# 生小孩 送 什么 礼物   生小孩送什么礼物好
# 吃 什么 食物 下奶   什么食物可以下奶一
# 苹果 手机 用 什么 播放器 好   苹果手机用什么播放器最好
# 西兰花 怎么 炒   西兰花怎么吃
# 新闺蜜 时代 在 哪里 拍 的   新闺蜜时代哪里拍的
# 帮 我 自己 名字 的 个性 签名 设计 下   我想为自己的名字设计个性签名
# 求 电影 下载 地址   下载电影下载下载地址
# 在 淘宝 上 怎么 注册 账号   淘宝怎么注册账号
# 吃 什么 食物 能 减肥   吃什么食物可以减肥
# 现在 头发 流行 什么 颜色   现在流行染什么颜色的头发
# 这是 什么 情况   这是什么情况啊
# 我 的 世界 铁 傀儡 怎么 造   我的世界手机版怎么<UNK>.<UNK>方法
# 怎么 折 小兔子   小兔子怎么折
# 鼠 妈妈 可以 生马 宝宝 吗   鼠妈妈<UNK>宝宝好吗
# 淘宝 帐号 咋 申请 了   如何申请淘宝帐号
# 小狗 满 一个月 给 它 吃 什么   一个月的小狗吃什么
# 关于 电脑配置 问题   有关问题
# 天天 飞车 凯瑟琳 和 暗影 橘子 哪个 好   天天飞车暗影橘子和凯瑟琳
# 闭月羞花 猜一 生肖   闭月羞花解生肖
# 什么 材质 的 内裤 好   内裤什么材质好
# 小狗 叫 什么 名字 好听 呢   给小狗起什么名字好听
# 方管 上 怎样 冲孔   <UNK>怎么上<UNK>
# 手机 怎样 控制 电脑   手机怎么控制电脑
# 张学友 的 全部歌曲   张学友全部歌曲名
# 给 女朋友 打电话 都 可以 说 什么   给女朋友打电话打电话什么好
# 束 腹带 什么 牌子 好   什么牌子的<UNK>腹带好
# 宫 洺 为什么 换人   <UNK>洺换人
# 我 的 世界 如何 开服 啊   我的世界怎么开服
# 一牛吼地 是 什么 生肖   一牛吼地是什么生肖
# 温州 明天 天气 怎么样   <UNK>明天怎么样
# 这个 日本 女明星 叫 什么 名字   这日本女明星叫什么名字
# 天猫 上 有 真 东西 吗   在天猫买东西靠的住吗
# 什么 播放器 可以 缓存 火影忍者   哪个播放器可以缓存火影忍者
# 舞乐 传奇 里 恶猪 王是 谁   舞乐传奇恶猪王是谁
# 腾讯 微博 如何 开通   求腾讯微博怎么开通
# 今年 春运 几号 开始   今年几号开始春运
# 这个 歌手 是 谁 啊   歌手是谁
# 怎么 去除 鸡 皮肤   鸡怎么皮肤怎么
# 微信 能 打电话   微信微信打电话吗
# 电视直播 软件 哪个 好   你软件是准
# 涨 姿势 什么 意思   涨了了是什么意思
# 人生 中 最 痛苦 的 事 是 什么   人生最痛苦的事什么
# 铠甲 勇士 第四部 有 吗   铠甲勇士出勇士
# 吃 阿莫西林 能 喝酒 么   吃吃了能喝酒吗
# 网上 订票 怎么 取票   网上订票怎么取票啊
# 怎么 在 电脑 上 玩 天天 酷跑   电脑天天电脑天天酷跑
# 为什么 古剑 奇谭 没 更新   为什么古剑奇谭还不更新
# 设计 签名 一笔 签   设计签名一笔签
# 我 知道 了 ， 韩语 怎么 说   我的了怎么知道了
# 这个 海报 是 什么 电影   求谁知道这个电影的海报
# 关于 大学 选 专业   上大学专业专业
# 现在 什么游戏 赚钱 啊   现在什么游戏赚钱
# 我家 狗狗 便秘 了 怎么办   我家的狗狗便秘怎么办求解
# 这是 什么 动漫 或者 游戏   这是什么动漫或游戏
# 求 曹查理 演 的 一部 电影   求一部曹查理演的电影名
# 广州 哪里 批发 手表   广州哪里批发手表批发
# 恶魔 总裁 ： 求 你 放过 我   恶魔总裁放过你我
# 如何 知道 自己 怀孕   怎么知道自己怀孕
# 我 是 歌手 第二季 第二轮 谁 被 淘汰   我是歌手第二季<UNK>谁被淘汰
# 小厨 宝 什么 牌子 的 好   小厨宝什么牌子好
# 哈尔滨 旅行社 哪家 好   哈尔滨旅行社哪家好呢
# “ 学霸 ” 什么 意思   学霸是什么意思
# 怀孕 有 那些 反应   怀孕有哪些反应
# 渴望 的 近义词 是 什么 词   渴望的近义词是什么呢
# 什么 牌子 的 加热棒 好   什么牌子的好
# 这件 衣服 是 什么 品牌 的   这件衣服啥衣服.哪里...<UNK>怎么
# 石进夜 的 钢琴曲 的 全集   <UNK>的钢琴曲全集
# 麻烦 您 将 您 的 完整 的 页面 的 截图 发送 一下 的 ， 辛苦 您 了   麻烦您将您的页面的完整的截图发送一下的辛苦您了
# 人教版 九年 级 化学 练习册 下册 答案   人教版九年级化学下册练习册答案
# 谁 有 下 一站 幸福 小说 版 的   谁找下一站幸福小说版小说
# 什么 软件 可以 下载 破解版 游戏   有什么软件可以下载破解版的游戏或修改或
# 请 认真 和 我 恋爱 游戏 种子   请认真和我恋爱的游戏种子
# 圣诞老人 的 坐骑 是 什么   圣诞老人的坐骑是什么
# 学习 刻苦 的 成语   刻苦学习成语
# 您 这个 账户 也 是 可以 使用 的 呀   您您的账户是可以使用
# 怎样 让 手机 和 电视 连接   怎样让手机让电视
# 胡莱 三国 如何 刷 功勋   胡莱三国怎么提高功勋
# 可以 的 这边 为 您 转接 相关 人员   帮我帮您让眼睛的眼睛相关为您转接一下
# 联想 笔记本电脑 如何 解锁   联想笔记本电脑怎么解锁
# 全民 枪战 电脑 版 怎么 玩   全民枪战怎么开到电脑黑屏
# 这个 是 僵尸 吗 第三季 何时 出   是这个是僵尸吗出
# 银行卡 怎么 存钱   银行卡怎么存钱
# 找 一本 重生 末世 小说   求一本重生小说小说
# 怎么 用 移动 手机 免费刷 超级 会员   用移动手机怎么免费刷qq超级会员
# 人 一生 最 重要 的 是 什么   人一生人最重要的是什么呢
# 孕妇 可以 喝 菊花 精 吗   孕妇能喝金银花吗
# 情人节 送 什么 给 男友 好 呢   情人节送男友什么好
# 四川 是 在 南方 还是 北方   四川是什么还是图片
# 寻 一部 香港 古装 电影   一部一部老的电影
# 变形 计杨桐 发型 是 什么   变形计杨桐发型发型什么什么
# 凤凰 传奇 为什么 不是 夫妻   凤凰传奇是不做夫妻
# 女士 买 什么 牌子 手表 好   什么牌子的女士手表好
# 这么 多 面膜 ， 哪款 好 用   哪款面膜好呢
# 怎么 设置 自己 的 电子邮箱   怎样设置自己的的电子邮箱
# 韩潮苏海 } 是 什么 生肖   韩潮苏海是什么生肖
# 三国演义 中 马超 是 怎么 死 的   三国演义中我是介绍死的
# 山寨 机 怎么 刷机 啊   <UNK>机如何刷机啊
# 兔子 尾巴 歇后语   兔子人的歇后语
# 求 这张 图片 的 无 水印 图   求这张图片的大图
# 大雾 什么 成语   什么软件可以成语
# 梦见 和 别的 男人 睡 在 一起   梦见自己和别的男人睡在一起
# 怎么 把 微信 好友 删除   微信怎么删除好友
# 有 什么 好 的 补水 面膜   什么面膜补水
# 什么 玩意   吃什么时候准
# 家里 的 旧衣服 怎么 处理   家里旧衣服怎么处理
# 懂得 ， 打一 动物   懂得是动物打一动物
# 急 ！ 我 在线 等   在线等秒赞
# 张 成泽 怎么 死 的   张成泽是怎么死的
# 兔子 请 老虎 ？ 打一 成语   兔子请老虎.打一成语
# 谁 知道 这个 电视剧 的 名字   谁知道这个电视剧的名字
# 这个 季节 去 哪 旅游   这个季节去哪旅游
# 求 会计 基础 电子书   会计基础的那个贵吗
# 领略 的 意思 是 什么   <UNK>什么意思
# 什么 东西 能 辟邪   吃什么东西可以辟邪
# 香蕉 怎么 存放 能 保存 时间 长   香蕉可以使用结婚证时间
# 萌萌 的 动漫 图片 … 如   求动漫图片里
# 快快 快快 快快 快快   快快快快快快快快急
# 嘀嘀 打车 可以 用 现金 吗   嘀嘀打车可以用现金吗
# 男人 胸前 有 痣 代表 什么   男人右边有什么代表
# 苹果 6 怎么 分辨真假   苹果手机怎么开机
# 周杰伦 为什么 那么 出名   周杰伦都这么出名
# 这个 十字架 是 什么 车 的 标志   一个十字架的标志是什么车
# 侠盗 飞车 游戏 秘籍 如何 使用   侠盗飞车如何使用秘籍
# 关于 新 三国 的 刘备   新三国游戏那些软件
# 邮件 稍后 发送 ， 对话 结束 后 您 会 收到 ， 您 收到 邮件 后 按照 提示 操作   邮件稍后发送对话结束后您会收到您收到邮件后按照提示操作上传
# 男士 洗面奶 一般 什么 牌子 好   男士用什么牌子好
# 淘宝网 上 买 东西 可以 货到付款 吗   淘宝买东西可以<UNK>再付款的
# 重庆 有 那些 好 的 化妆 学校   重庆那些好的好
# 赛尔 号 布鲁克 克 现在 怎么 得   赛尔号布鲁克克怎么样
# 怎样 去除 老年斑   怎么去除老年斑
# 有 什么 好看 的 拍照 姿势   什么什么好看的电影
# 找 一个 小游戏 ， 帮 我 下   帮我找一个小游戏
# 尊严 是 什么 意思   <UNK>什么意思
# 问 一部 旧 外国 电影   找一部的一部电影
# 可以 注销 微 信号 吗   微信号可以注销
# 如何 通过 经纬度 查询   如何已交到
# 四年级 暑假作业 数学 答案   数学<UNK>数学所有版的
# 问 郑州 旅行社 哪个 好   郑州的旅行社哪个好
# 这是 什么 狗狗 啊 ？ 是 泰迪 吗   这是什么狗狗?有毒吗
# 大无畏 是 什么 生肖   大无畏是什么生肖
# 有 想 在家 工作 的 吗   在家想做什么工作
# 英雄 联盟 怎么 快速 升级   英雄联盟怎样快速升级
# 求 时空 猎人 的 辅助   求时空猎人的表情吗
# 信用卡 怎么 还款   信用卡怎么代又
# 什么 软件 换 手机 字体 最好   手机什么软件清理手机最好
# 家装 电线 什么 牌子 好   家装电线什么牌子的好
# 跑跑 卡丁车 幸运 币 怎么 得   跑跑卡丁车的时候怎么怎么怎么
# 我 喜欢 什么 颜色   我喜欢他颜色是什么
# 怎样 写 自己 的 个性 签名   怎样写自己的个性签名
# 争先恐后 的 意思 是 什么   <UNK>什么意思
# 很 抱歉 ， 小 二 这边 没有 帮 那 您 核实 到 有 这笔 资金 的 退款 的   很抱歉小二这边没有帮您核实到有这笔资金的退款
# 玫 红色 纱裙 配 什么 颜色 外套 好看   红色红色配什么颜色的鞋好看
# 必胜客 什么 披萨 最 好吃   什么播放器什么好吃啊
# “ 月 是 故乡 明 ” 上 一句 是 什么   月是故乡明的成语上一句应该是什么
# 酒窝 是 如何 形成 的   酒窝是怎么形成的
# 水龙头 什么 牌子 好   什么牌子的水龙头好
# 魔兽争霸 有 什么 好玩 的 地图   魔兽争霸的地图有什么地图
# 女士 手表 有 哪些 牌子   品牌女士手表有哪些
# 净水器 买 什么 牌子 好   什么牌子的净水器好
# 您 有 开通 花 呗 的 吗   您是否开通花呗了呢
# 货币基金 如何 购买   <UNK>怎么购买
# 甄子丹 大闹天宫 那里 能 看   大闹天宫甄子丹那里能看
# 沉默 代表 什么   电视剧代表什么
# 马伊 琍 和 文章 是 二婚 吗   马伊马伊琍是二婚吗
# 怎么 改 行李箱 的 密码   行李箱的密码怎么开啊
# 韭菜 。 生姜 榨汁 怎么 榨   生韭菜和生姜榨汁怎么做
# 找 一部 网游 小说   找一部小时候网游小说
# 阿里 旺旺 怎么 注册   阿里旺旺怎么注册
# 孕妇 可以 吃 茄子 吗   孕妇能吃茄子么
# 求 三角形 的 面积 公式   三角形的面积公式怎么求
# 三国志 和 三国演义 有 什么 区别   三国志和三国演义有什么区别
# 求 花粉 少女 注意 报 动漫 和 漫画 全集   求花粉少女注意动漫动漫漫画全集
# 哈尔滨 俄语 四级 辅导 哪里 的 好   哈尔滨俄语四级辅导哪里的好呢
# 好评 ， 求 解释   求解释?求大神
# 三星 手机 在 哪里 买 比较 便宜   三星手机在那里可以便宜
# 在 哪里 可以 投稿 ， 小说 那种   <UNK>言情小说在哪里可以投稿有那种的那种
# 百度 文库 如何 获得 财富 值   百度文库财富值怎么获得
# 在 男人 眼里 女人 算 什么   男人<UNK>女人什么什么
# 求 完结 穿越 小说   完结的穿越小说
# 关于 描写 朋友 的 作文   好描写好的作文字
# 谁 玩 时空 猎人   谁有我的时空猎人
# 我 是 特种兵 之 火凤凰 多少 集   我是特种兵之火凤凰多少集啊
# 这个 截图 是 对方 给 您 的 是 吗   您的对方截图给我的吗
# 有关 感恩 的 歌曲   <UNK>爱或感恩的歌曲
# 豹头环眼 是 什么 生肖   豹头环眼是什么生肖
# 女人 为什么 那么 喜欢 吃 香肠   女人为什么喜欢吃香肠
# 有 什么 成功 去 斑 的 方法   有什么办法可以破解到坏处
# 鸡蛋 能 和 土豆 一起 吃 吗   鸡蛋可以和土豆一起吃吗
# 什么 慢摇 舞曲 好听   有什么好听的<UNK>
# 苹果 手机 通讯录 如何 删除   苹果手机怎么恢复通讯录
# 尼日利亚 和 波黑 哪个 强   <UNK>和尼日利亚哪个强
# 怎样 下载 搜狐 视频   我下载搜狐视频
# 什么 钢笔 好用 点   什么钢笔好好用
# 摩托车 怎么 换 机油 啊   摩托车的这个怎么怎么
# 找 一部 关于 蟒 的 电影 片名   一部一部蛇的电影求片名
# 为什么 女人 那么 容易 出轨   女人的女人为什么那么出轨
# 哪个 输入法 最好 用   用什么软件最好
# 英雄 联盟 刚 开始 打野 有 什么 用   英雄联盟为什么有什么<UNK><UNK><UNK><UNK>
# 苹果 手机 怎么 充值   苹果手机怎么开充值
# 求 推荐 好看 的 玄幻 小说   求好看的小说玄幻
# 什么 牌子 连裤袜 质量 好   什么牌子连裤袜质量好
# 多美滋 奶粉 最新 事件 ， 怎么样   <UNK>多美滋奶粉怎么样
# 最 有效 丰胸 产品 有 什么   什么有效有效最有效
# 寒假 英语 作文   英语寒假作文
# 微众 银行 怎么 贷款   要怎么才能在微众银行上贷款
# 腾讯 版 的 时空 猎人   腾讯版版的时空版
# 国际 机票 哪里 买 最 便宜   哪里买国际机票便宜
# 什么 东西 壮阳 快   吃什么东西可以补肾
# 男人 喜欢 什么样 老婆   男人喜欢什么样的老婆
# 下载 微信 怎么 下   怎么下载微信朋友圈
# 苹果 手机 中 的 照片 怎么 删除   苹果手机怎么找回照片啊
# 干 白菜 怎么 做 好吃 怎么样   白菜怎么做才好吃
# 类似 于 吞噬 星空 的 小说   吞噬星空背景类似小说
# 成龙 和 李连杰 谁 的 功夫 更 厉害   成龙和李连杰谁厉害一些
# 阿迪达斯 验 真伪   阿迪达斯辨哪个真伪
# 天气 冷 了 大家 要 多 注意 保暖 哦   分手后了!注意手机
# 想 找 一个 老电影 忘 了 叫 什么 名 了   找一个老电影
# 范冰冰 版 苹果 在 哪 可以 看   范冰冰版苹果在哪儿看
# 怎样 做 才能 结束 婚外情   如何做才能结束婚外情
# 求 秋色 之空 动画 全集   求秋色之空全集动漫
# 电视 购物 广告   电视购物广告
# 怎么 下载 爱奇艺 视频   爱奇艺的视频怎么下载
# 坐 出来 的 小肚子 怎么 减   怎么瘦腰和小肚子
# 胸肌 怎么 练 最快 图解 在家   胸肌什么软件怎么练
# 有 什么 好 的 学习 打字 的 软件   有什么好的学习用五笔打字的软件
# 王菲 为什么 和 李亚鹏 离婚   王菲为什么和李亚鹏离婚
# 烫 什么 颜色 好看   什么颜色好看好看
# 怎么 才 可以 去除 痘痘   怎么样去除痘痘
# 疯狂 猜 明星 小时候 他 是 谁   疯狂猜明星小时候明星是谁
# 天空 之城 的 完整 吉他谱   求天空之城的吉他谱
# 相爱 十年 董洁 邓超 在 第几 集   董洁邓超相爱十年吻戏第几集
# 送 长辈 的 礼物 选择 什么 好 呢   买什么礼物送长辈什么茶叶好
# 什么 网名 好听 男生 用 的   用什么网名好听呢
# 万字加 一笔 ， 是 什么 字   万字加一笔变什么
# 重庆 哪里 有 服装 批发市场   重庆哪里有服装批发市场
# 跪求 个 有 毒液 的 终极 蜘蛛侠 存档   北京西站找肌肉
# 梦幻 西游 宝宝 问题   梦幻西游宝宝攻宝宝问题
# 逆战 谁 能 送 我 飓风 之龙   逆战谁给我我给我
# 怎 怎样 做 微商 代理   如何做微商代理
# 怎么 让 手机 截屏   手机截屏怎么看
# 男士 凉鞋 团购 行 吗   男士男士团购好吗
# 火影忍者 的 作者 死 了 么   火影忍者的作者死了
# 求 各位 哥哥 姐姐 帮帮忙   各位姐姐哥哥帮帮忙
# 谢霆锋 和 张柏芝 为什么 要 离婚 啊   为什么谢霆锋和张柏芝离婚
# 有 什么 好 万能 播放器   有什么播放器最好
# 如何 去除 脸上 的 斑   如何去除脸上的斑
# 求 种子 你们 明白 的   求种子的明白
# 一边 一边 造句   用一边上造句
# 求 类似 幸福 花园 的 动漫   求类似幸福花园的各种动漫
# 怎么 做能 让 老婆 更爽   我若<UNK><UNK>是什么
# 宠物店 加盟 多少 钱   加盟宠物店大概多少钱
# 这是 什么 品种 的 兰花 啊   这是什么品种的兰花啊
# 跪求 魔法 禁书 目录 的 轻 小说   跪求魔法禁书目录的小说
# 英雄 联盟 之 谁 与 争锋 么   谁联盟这个谁与英雄
# 怎样 做 淘宝 兼职 客服   怎么兼职淘宝客服兼职
# 找 一部 电影 ， 美国 的   求一部美国电影名
# 什么 叫 吊丝   这个是什么牌子
# 时空 猎人 密码 忘记 了 怎么 找回   时空猎人密码忘记要怎么找回
# 酷跑 里 挡板 是 什么   酷跑中的是什么什么
# 这 是 南 红玛瑙 吗   是南<UNK>呢嘛
# 白醋 可以 消毒 吗   白醋能消毒吗
# 成语 玩命 猜 是 什么 成语   成语玩命猜上面.这个小字是什么成语
# 如何 让 眼睛 看起来 更 有神   如何让眼睛看起来有神
# 求 武汉 得意 社区 邀请 码   武汉最新得意哥哥人工码邀请码
# 早上 吃 什么 好   早上吃什么药
# 租车 一般 什么 价格   <UNK>卡通人物啥什么
# 厦门 哪里 有 批发市场   厦门批发市场在哪里批发市场
# 巴塞罗那 是 那个 国家   巴塞罗那是那个国家的
# 全民 枪战 飞天 挂 怎样 开   全民枪战挂怎样开
# 鳄鱼 龟 怎么 杀   <UNK>怎么刷机
# 怎么 上 国外 网站   国外网站怎么网站
# 女人 心 海底 针 啊   女人心海底针
# 如何 查 某个 人 是不是 网上 通缉犯   如何查询网上通缉犯是否网上
# 新 显卡 玩游戏 花屏   换显卡后玩游戏花屏
# 从 百度 怎么 搜 这个 图 才能 搜 到   在哪让自己在百度上<UNK>
# 怎么样 才能 让 自己 力气 变 大   如何让自己的手变大
# 珀薇 原液 怎么样   珀薇<UNK>如何呢
# 您 太 客气 了 。 这是 小二 应该 做 的   这是小二应该做的您太客气了
# 来自 星星 的 你 ， 怎样 下载   在哪下载来自星星的你
# 快 过年 了 做 什么 生意 好   过年做什么生意好做啊
# 李光洙 和 王 智慧 是 什么 关系   李光洙王智慧什么关系
# 封神 英雄榜 第二部 什么 时候 演   封神英雄榜第二部什么时候出来
# 怎么样 才能 把 梳子 卖 给 和尚   如何把<UNK>卖给和尚
# 哪个 网站 可以 免费 学习 英语   在哪个网站可以免费学英语
# 姓张 女孩 、 起 什么 名字 好听   姓张女孩.起什么名字好听
# 梅州 有 什么 好玩 的 地方 吗   梅州有什么好玩的地方
# 女包 有 那些 品牌   品牌女包有那些
# 电动 自行车 什么 牌子 的 好   什么牌子的电动自行车好
# 什么 事情 最 难忘   什么药最便宜
# 恩恩 ， 有 问题 随时 联系 我们 ， 感谢您 的 支持   好的有问题随时联系我们.随时随时为您服务
# 电脑 怎么 格式化   在电脑怎么激活系统
# 那里 批发 水果 便宜 啊   哪里批发便宜便宜
# 下水道 的 美人鱼 在 哪里 能 看   下水道美人鱼哪里可以在哪里美人鱼
# 肥佬 影音 在 哪里 下载   肥佬影音哪里知道到
# 胡萝卜 怎么 烧 好吃   胡萝卜怎么做好吃
# 怎样 下载 蚂蚁 战车 第三代   蚂蚁战车怎样下载
# 女人 用 什么 网名 好   什么网名要取什么
# 怎样 编 头发 好看 图解   头发头发头发模式好看图解
# 买 手表 去 哪个 网站 最好   买从哪个网站上便宜
# 孕妇 能 吃 消炎药 吗   孕妇能吃宝宝吗
# 您 是 要 修改 手机号码 是 吧   您是是需要修改手机号码
# 怎样 梳 简单 又 好看 的 发型   如何扎好看又简单的发型
# 这 图片 是 出自 什么 漫画   这图片是出自哪部动漫
# 用 单项式 与 多项式 相乘   <UNK>和勇士
# 小苹果 的 原唱 是 谁   小苹果是谁的原唱
# 身先士卒 猜 什么 生肖 好   身先士卒指什么生肖
# 怎么 瘦 肌肉 型 小腿   怎么瘦肌肉型小腿啊
# 怎么 下载 微信 旧版本   微信旧版本怎么下载
# “ 新年快乐 ” 日语 怎么 说   祝用日语怎么说谢谢
# 怎么 下载 视频 到 手机 上   如何下载视频到手机里
# 手机 用 什么 视频 播放器 好   手机什么视频播放器看电影最好
# 现在 什么 播放器 更新 电影 最快   什么播放器更新电影最快
# 在 中国 有 哪些 挨过 打 的 女童 星   中国有哪些女童星挨过打
# 带 游戏 穿越 类 的 小说   现在着游戏游戏穿越的小说
# 海 的 女儿 作者 是 谁   海的女儿作者是谁
# 投诉 自来水 公司   小孩的公司
# 少儿 频道 所有 动画片   查询所有动画片
# 怎么 去除 高原 红   怎样去除高原红
# 有关 兔子 的 动画片   和兔子是哪个动画片
# 动物园 有 什么 规   <UNK><UNK>什么什么
# 联想 的 手机 质量 怎么样   联想的手机质量怎么样?
# 是 成语 的 寓言故事   寓言故事的成语有哪些
# 石家庄 属于 哪个 省   石家庄属于那个省啊
# 梨花 头染 什么 颜色 好看   梨花头染什么颜色显得可爱
# 山东 建筑 大学   山东的大学
# 手机 掉 了 怎么 找回   手机怎么找回啊
# 火锅 底料 哪个 牌子 好   火锅底料哪个牌子的呢
# 同归于尽 的 尽 是 什么 意思   <UNK>的<UNK>是什么意思
# 五行 缺木 取名   五行<UNK><UNK>
# 风凌 天下 的 新书 是 什么   <UNK>天下的新书叫什么
# 怎么 可以 成为 腾讯 视频 的 会员   我想成为腾讯视频会员怎么登录啊
# 关于 流媒体 的 下载 问题   流媒体的下载问题
# 哪里 回收 硬币   哪里可以看成品
# 角色扮演 网游 哪个 好玩   好玩角色扮演网游有
# 嘴唇 上面 长 黑点   我想痣萝卜<UNK><UNK>啊
# 谁 帮 我 注册 个 竞 舞台 账号 急   帮我注册个竞舞台账号
# 找 一部 都市 小说   一部找一部小说
# 什么样 减肥药 效果 好 而且 不 反弹 呢   什么样的减肥药效果好不反弹
# 关于 が 和 を 的 用法   和<UNK>的区别
# 为什么 我 的 泰拉 瑞亚 打不开   泰拉瑞亚今天的时候打不开
# 也 谢谢 你 了 ， 朋友   谢谢了朋友朋友
# 有 什么 比较 好看 的 灵异 小说 ， 看过 的 推荐 一下   什么什么好看的小说比较小说
# 梦幻 西游 什么 职业 最 好玩   梦幻西游什么职业好玩
# 阿里 旺旺 号 怎么 申请   怎么设置阿里旺旺大号
# 百度 贴 吧 怎样 升级快   百度贴吧如何升级快
# 我 是 歌手 第二季 的 歌王 是 谁   我是歌手第二季歌王
# 小区 助手 怎么样   小区助手怎么样啊啊
# 足球 是 谁 发明 的   谁发明了足球
# 没有 银行卡 怎么 给 对方 转账   没有银行卡怎么转账
# 怎么 叠 纸盒子   是怎么折纸盒子
# 今天 星期 几 啊   今天星期几呢?
# 柳岩 和 大鹏 什么 关系   大鹏柳岩是什么关系
# 哪个 网站 下载 的 电脑系统 好 一点   那个网站可以下载好一点
# 寒假作业 全部 答案   寒假作业集
# 《 毕业 那天 一起 失恋 》 雨阳著   毕业那天一起失恋又<UNK>
# 羊奶 好 还是 牛奶 好   羊奶好还是牛奶呢
# 国字 脸 的 女生 适合 什么 发型   女生国字脸适合什么发型
# 剑灵 电脑配置 要求   这个电脑配置电脑配置有什么
# 找 工作 电焊 那里 要 人 啊   <UNK>工作怎么找
# 草船借箭 的 是 谁   草船借箭的人是谁
# 拿 不到 工资 怎么办   工资拿不到怎么办
# 我 的 古代 身份 和 名字   我在古代的身份名字什么名字
# 有 什么 好听 的 音乐 推荐 个   什么音乐好听.推荐
# 为什么 姚明 那么 高   姚明为什么这么高就那么高
# 我 想 找 一个 女朋友   我想找一个女朋友
# 我 想 给 我 女朋友 起个 外号   帮我给女朋友起个外号
# 国产汽车 有 哪些   <UNK><UNK>有哪些
# 请 把 这 几个 日文 帮 我 打 出来   请几个好几个我打打
# 零点乐队 主唱 是 谁   <UNK><UNK>叫谁
# 路虎 是 那个 国家 的   路虎是那个国家的
# 快乐 大本营 下 一期 是 谁 的   快乐大本营下一期是谁啊
# 电热水壶 怎么 维修   怎么用身份证车
# 贴 吧 要 怎么 上传 图片   贴吧里上传图片
# 求 好看 的 电视剧   求好看的电视剧
# 用 什么 比喻 老师   什么的比喻都有什么
# 世界杯 会 踢 假球 吗   世界杯会<UNK>吗
# 摸摸 渣 渣 什么 意思   摸摸什么意思
# 长沙 哪里 最 好玩   长沙哪里有好玩的
# 愤怒 的 小鸟 玩 不了   愤怒的小鸟玩不了
# 亲 具体 是 需要 解决 什么 问题 呢   亲具体是需要解决什么问题呢
# 哪个 牌子 的 指甲油 好   指甲油哪个牌子的好
# 滴滴 打车 司机 怎么 收钱   滴滴打车对司机怎么收费啊
# 女士 买 什么 牌子 手表 好   什么牌子的女士手表好
# 好 朋友 不理 我 了 怎么办   我的朋友不理不理我了我该怎么办
# 今天 农历 几号 了   今天今天农历了几号了
# 支付宝 怎么 提现   支付宝怎么提现??去
# 文章 姚笛 什么 时候 开始 的   文章什么时候上映
# 做 什么 运动 可以 瘦 肚子   什么运动瘦肚子减肥
# 微信 怎么 解冻   微信上怎么去别人的肉
# 网上 挂号 怎么样 挂   网上挂号网上挂怎么网上
# 伊贝诗 化妆品 怎么样   伊贝诗的化妆品怎么样
# 有 什么 软件 是 只 下载 单机游戏 的   什么软件可以下载单机游戏
# 天天 酷跑 怎么 投诉   怎么下载天天酷跑
# 映日 荷花 别样红 站 的 上 一句 是 什么   映日荷花别样红前一句是什么
# 相亲 什么 网站 靠 谱   相亲什么网站好
# 西安 的 二手手机 市场 在 哪儿   西安二手手机市场
# 海贼王 在 哪里 下载 啊   海贼王哪里可以下载
# 求 动漫 女生 的 头像   求动漫唯美头像
# 玩游戏 怎么 卡 呢   我的怎么玩游戏
# 怎么 下载 风行 网   风行下载怎么下载网址
# 生息 什么 什么 的 成语   成语什么什么成语
# 华硕 手机 如何   手机如何如何
# 为什么 宫 洺 换人   宫洺为什么换人了
# 乳腺 增生 早期 的 症状   乳腺增生的早期症状
# 沧州 属 哪个 省   沧州是哪个省的
# 哪里 批发 衣服 便宜   那里批发衣服便宜
# 删除 的 微信 好友 怎样 找回   微信删除的好友好友的好友
# 火命 人 适合 什么 颜色   火命人什么颜色
# 亿健 跑步机 怎么样   <UNK>跑步机怎么样好吗
# 鼻烟 怎么 玩   怎么玩<UNK>
# 网络小说 有 什么 好看 的   有什么好看的网络小说推荐一下
# 有 免费 的 小说 看 吗   看小说免费看小说吗
# 怎么样 才能 让 自己 变得 高冷   怎样让自己变得高冷
# 请 您 填写 下 您 的 账户 绑定 手机号码 ， 帮 您 恶化 时   您好请您填写下您的账户绑定手机号码
# 什么 软件 可以 自己 制作 图片   什么软件制作自己制作图片
# 开 淘宝 店 怎么 装修 呢   开淘宝店怎么装修啊
# 我 的 爹爹 是 龙族 全文   爹爹是龙族全文
# 做 什么 工作 。 钱来 的 快   做什么工作比较好
# 微信 网页 版 怎么 看 朋友圈   微信版版如何看朋友圈
# 现在 有 什么 网游 好玩   现在有什么好玩的网游吗
# 怎样 快速 消除 吻痕   怎样可以快速消除吻痕
# 这是 什么 动漫 或 游戏   这是什么动漫或游戏或游戏
# 宜昌 三峡 论坛 邀请 码   宜昌三峡论坛的邀请码
# 用 手机 看 直播 哪个 软件 好   手机手机哪个软件哪个软件好
# 高大 上 是 什么 意思   高大上是什么意思
# 中国 哪个 城市 最 适合 居住   属兔的人适合居住哪个网站
# 可爱 好听 的 女生 外号   可爱又好听又好听
# 如何 知道 一个 女孩 是否 喜欢 我   如何知道女孩是否喜欢我
# 请问 这是 什么 植物 ？ 谢谢   请问这是什么植物?谢谢
# 时间 真的 能 改变 一切 吗   时间可以改变一切是真的吗
# 四川 文理学院 如何   四川<UNK>怎么样
# 什么 牌子 的 文胸 好   什么牌子牌子好
# 京东 那些 可以 货到付款   京东可以货到付款吗
# 古代 穿越 到 现代 小说   古代穿越穿越穿越小说
# 邓紫棋林 宥 嘉 为什么 分手   林宥嘉和为什么为什么分手
# 想 设计 一个 图标   一个人一个图标
# 今天 三九 第几天   今天是三九第几天了
# 求 白熊 咖啡厅 的 主题曲   求<UNK><UNK>主题曲
# 水晶 品牌 有 哪些   水晶有哪些品牌
# 创业 开 汽车 美容店 如何 呢   开汽车美容店怎么样
# 西瓜 英语 怎么 读   西瓜英语怎么怎么读
# 头上 有角 ， 变废为宝 。 是 什么 生肖   头上有角变废为宝.是什么生肖
# 怎么样 才能 让 自己 力气 变 大   如何让自己的手变大
# 神武 怎么 赚 现金 快   神武怎样赚现金快
# 全部 位于 西半球 的 大洲   全部位于西半球的大洲
# 手机 怎么 看 大片   怎么才能让手机上看
# 求 一部 关于 恐龙 的 电影 名   找一部和的的电影
# 什么 是 乳腺癌 ， 怎样 预防   怎样预防乳腺癌的发生
# 三叶草 求 鉴定   三叶草求鉴定
# 赛尔 号 希路 达 在 哪里 抓 ， 怎么 抓   赛尔号希路达希路达哪里拿哪里
# 什么 电影 好看   有什么好看的电影
# 泰迪熊 高清 下载   高清下载高清下载
# 关于 茅山 道士 的 小说   <UNK><UNK>有关的小说
# 推荐 个 好玩 的 手机游戏 吧   推荐一些好玩的手机游戏
# 世界 上 最低 的 盆地 是   世界上<UNK>最低
# 怎么 锻炼 脸部 肌肉   国外文怎么锻炼
# 北京 的 服装 批发市场   北京有哪些服装批发市场
# 公积金 贷款 可以 买车 吗   公积金能贷款买车吗
# 跳绳 的 好处 有 哪些   跳绳哪些好处有哪些呢
# 离婚 无 住房 离婚 分户 申请书 怎么 写   离婚无住房<UNK>申请书怎么写
# 梦幻 西游 点卡 是 什么   梦幻西游什么什么贵
# 天天 酷跑 怎么 修改   天天酷跑怎么修改
# 手机 qq 里 怎么 查看 空间 我 的 收藏   手机qq空间里面收藏的文章在哪里查看
# 都 是 什么 修辞手法   我是什么修辞手法
# 印度 最好 听 的 歌曲   最好听的印度歌曲
# 谁 知道 着 是 什么 动漫   谁知道知道什么动漫
# 怎样 可以 让 胸部 变 大   怎么能让胸部变大啊
# 钢筋 翻样 方法 与 实例   行<UNK>的<UNK>和<UNK>
# 查询 驾驶证 剩余 分数 怎么 查   驾驶证查询驾驶证英语邮箱
# 请 看 图片 ， 求 解答   求看图片图片
# 唯美 的 女生 头像   唯美唯美<UNK>头像
# 穿越 火线 的 问题   穿越火线问题
# 买手机 在 哪个 网站 买 比较 好   在哪个网站买手机比较好
# 怎样 挑选 胸罩 呢   怎么听怎样感动
# 什么 办法 可以 让 男人 更 持久   有什么办法让让男人变得
# 机动车 违章 怎么 查询   怎么查询机动车违章机票
# 如何 下载 韩文 输入法   怎样下载电视剧下载
# 怎样 给 男朋友 生日 惊喜   怎样送男朋友过生日该送惊喜
# 唯品 会上 卖 的 东西 是 真的 吗   唯品会上的东西是真的吗
# 为什么 男人 和 女人 要 结婚   女人为什么要和女人结婚结婚
# 怎么 刷 人人 人气   人人如何刷来访
# 找 我 的 世界 服务器   我的世界服务器
# 陌陌 封号 怎么 解封   陌陌怎么封号怎么解封
# 推荐 网络游戏   大家推荐个网络游戏
# 年糕 怎么 炒 好吃 呢   年糕怎样做最好吃
# 怎么 取消 淘宝 快捷 支付   淘宝支付怎么支付业务
# 爱情 公寓 中 秦羽墨 跳 的 什么 舞   爱情公寓真跳什么的舞
# 英雄 联盟 的 战斗力 怎么 升 啊   英雄联盟怎么上<UNK>
# 怎么 织 宝宝 毛衣   怎么织宝宝毛衣
# 乌龟 和 王八 有 什么 区别   乌龟和乌龟有什么区别
# 如何 破解 优酷 带 密码 的 视频   怎么破解优酷的视频密码
# 哪个 牌子 面膜 便宜 又 好 用   面膜哪个牌子好用又便宜
# 日本 男优 吃 什么 药   日本男优吃什么
# 有个 韩国 男明星 叫 什么 名字   这个韩国男明星的名字叫什么
# 求 妖精 的 尾巴 在 贴 吧 中 的 同人小说   求妖精的尾巴同人小说
# 性格 很 内向 适合 做 什么 工作   我的男人适合做什么工作
# 电路 邱关源 第四版   <UNK><UNK>里<UNK>哪有
# 什么样 的 电脑配置 比较 好   现在的电脑配置比较好
# 苹果 的 手机 铃声 怎么 下载   苹果手机怎么下载铃声
# 怎么 增加 淘宝 流量   我怎么淘宝流量
# 求 东方不败 之 君子 满楼 番 外   求东方不败之君子<UNK>的番外
# 加载 主题 时 错误   加载主题时怎么找到的
# 快 过年 了 摆摊 卖 什么 赚钱   过年卖卖什么好赚钱
# 吃 苹果 能 减肥 吗   吃苹果能减肥吗
# 周杰伦 惊叹号   周杰伦<UNK>怎样
# 什么 牌子 的 干衣机 好   什么牌子的干衣机好
# 女人 怎么 才能 怀孕   怎么才能让怀孕啊
# 长沙 哪个 复读 学校 好   长沙哪个牌子的好
# 手机 怎么 静音   手机怎么手机
# 眉毛 怎么 画 的 好看   怎么画眉毛好看
# 为什么 移动 宽带 有 的 网站 打不开   为什么移动有的网站网站网站
# 有没有 哪个 网站 能 免费 阅读 VIP 小说   哪个网站可以免费看小说
# 今年 南京 会 下雪 吗   南京今年下雪吗
# 爸爸 强奸 了 我 怎么办   爸爸爸爸强奸了我
# 手机 铃声 怎么 下载   怎么下载手机铃声
# 怎样 能 治疗 老花眼 啊   怎样治疗汗臭迅雷
# 栩栩如生 ， 造句   是怎么这么造句
# 农村 养殖 什么 能 赚钱   在农村搞什么养殖能赚钱
# 求 一本 古代 的 言情小说   求一本古代言情小说
# 怎样 不用 圆规 画圆   如何不用圆规画圆
# 怎么 下载 天天 酷跑 电脑 版   天天下载怎么酷跑到电脑
# 是 需要 这边 帮 您 备注 一下 才 可以 的   这边需要这边帮您这边这边帮您备注的
# 自信 名人 事例   名人<UNK>的名人
# 腿 上长 了 个 疙瘩   我腿上长疙瘩
# 这个 配置 可以 玩逆战 么   配置的配置能玩逆战吗
# 怎么 用 身份证号 查 自己 定 的 机票   怎么用身份证号查机票
# 有没有 什么 感人 的 小说   有没有什么好听的小说
# 受伤 的 心 还 可以 爱 谁   受伤的心还可以爱谁
# 冰箱 有 哪些 品牌 好 一些   冰箱有哪些品牌好
# 手机游戏 推荐 几个   推荐几个手机游戏吧
# 老 掉头发 是 怎么回事   老<UNK>是怎么回事
# 人间 中毒 在 哪里 看   想哪里可以看到<UNK>
# 这是 那部 动漫   这是那部动漫里的呀
# 怎样 包装 花束   自己种的花
# 双重 否定句 ， 怎么 改   淘宝网怎么改否定句
# 家用 净水器 哪个 牌子 好   家用家用的牌子好好
# 口舌 痣 是 什么 意思   痣痣叫什么意思
# 给 女朋友 空间 留言 留 什么 好   给女朋友空间写什么
# 赛尔 号 达尔 在 哪 抓   赛尔号小<UNK>号
# 100 ~ 200 字 的 数学 小 故事   字的数学小词词词词词词
# 求 这张 情侣 头像 的 另 一张   求这张情侣头像的另外一张
# 好看 的 总裁 小说   有哪些好看的小说总裁
# 怎样 获得 多多 的 财富   怎样获得多多的财富分
# 如何 测试 她 是否 喜欢 我   刚交往<UNK>如何测试他是否喜欢我
# 世界 上 最 好吃 的 巧克力 叫 什么 名字   什么牌子的巧克力最好吃
# 现在 什么 手机游戏 好玩 的   现在什么手机游戏好玩的
# 浪琴表 打 一折 是 真的 吗   <UNK>一折是真的吗
# 属马 戴 什么 生肖   大年要什么生肖
# 魔兽 世界 的 电影 有 哪些   魔兽世界的电影有
# 男人 什么 药 可以 催情   什么什么药可以催情
# 如何 带 好 一个 团队   怎样让好一个团队
# 海贼王 里 谁 是 最强 的   海贼王里谁最强
# 您 的 身份 信息 方便 我 核实 一下 么   您方便提供信息核实一下您的身份吗
# 妹妹 说 喜欢 我 我 该 怎么办   我说我喜欢的我该怎么办
# 五行 缺水 戴 什么   五行缺水戴什么好呢
# 五行 缺金 女孩 取名   五行缺金女孩取名
# 陈赫 离婚 了 ， 是 真的 吗   陈赫离婚了吗是真的吗
# 苏东坡 是 哪个 朝代 的 人   诗人<UNK>哪个朝代人
# 蒸 板栗 怎么 去皮   男的怎么去皮
# 是 气血 两虚 吗   是<UNK><UNK><UNK>
# 怎么 给 图片 加 链接   怎样在图片加链接
# 有 什么 好听 的 个性 签名   有什么好听的个性签名
# 求 一部 中国 的 电影   中国一部好的一部电影
# 梦见 送 别人 旧衣服   梦见买别人的家
# 重生 之 校园 特种兵 怎么 下载   重生笔记校园特种兵怎么下载啊
# 这句 话 用 英文 读 什么 意思   这句话是什么意思意思
# 既 又 是 什么 关系 的 关联 词语   日语说什么什么产品
# 写 一篇 童话 作文   来.作文写写
# 南通 在 哪个 省   南通在哪个区
# 不 知道 哪个 网站   哪个网站的不知道
# 怎样 增加 微博 粉丝   微博怎样快速多
# 武汉 美容 整形   武汉美容时候找<UNK>快
# 哪里 有 便宜 的 避孕套 买 吗   避孕套哪里可以买到手机
# 求 这部 漫画 的 名字   求这部漫画什么名字
# 为什么 我 在 优酷 上 看 不了 视频   为什么我看不了不了优酷上的视频
# 给 我 个 单机游戏 动作 冒险类 的   动作<UNK>单机游戏
# 智能手机 如何 解锁   智能手机怎么解锁
# 粤 车辆 违章 记录 查询   <UNK><UNK>这个<UNK>违章查询
# 今年 流行 什么 发型 男 短发   今年的发型发型什么
# 这是 什么 电阻 ， 什么 用 的   这是什么电阻啊哪里有卖的
# 关于 过年 的 歌曲   过年过年的歌曲
# 女士 什么 牌子 的 手表 好   女士买什么牌子好
# 找 一本 重生 小说   求一本重生小说
# 求 这张 图片 无 水印 的   求这张图片无水印
# 求 一些 好看 的 穿越 小说   求好看的日本小说
# 麻烦 提供 一下 您 的 邮箱 账户   麻烦您提供一下您的账户账户
# 人生 若 只 如初 见   若人生只如初见
# 帮 我 设计 一个 图标   帮帮我一个一个人
# 如何 网上 查询 车辆 违章 记录   如何网上查询车辆违章
# 如何 提高 自己 的 交际 能力   如何提高自己交际能力能力
# 逆战下 一把 神器 是 什么   有谁知道<UNK><UNK>武器是什么
# 范冰冰 武则天 什么 时候 上映   范冰冰电视剧什么时候上映
# 推荐 几本 好书   推荐几本好书呗
# 为什么 人民币 一定 会 贬值   人民币有会<UNK>
# 讲 女主 重生 的 小说   求穿越重生小说
# 猪 骨头汤 怎么 熬 最 好喝   怎么做的牌子
# 有 哪些 好 的 学习 英语 的 网站   学习英语的好网站
# 有 什么 偏方 治 小孩 咳嗽   有什么药能治疗小孩咳嗽
# 一夫多妻制 的 国家 有 哪些   <UNK>的国家是哪个国家
# 这个 不 影响 的 哦   这个不不去我
# 奶茶 妹妹 是 谁   周星驰的啊是谁
# 亲 ， 您 的 卡有 绑定 过 其他 账户 吗   您的<UNK>绑定绑定的其他账户吗
# 魔兽 世界 小 问题   魔兽世界小人问题
# 什么 叫 黄标车   什么水果能
# 孕妇 能 喝 胡椒 煲 猪肚 吗   孕妇可以吃<UNK>猪肚汤吗
# 纸尿裤 那个 牌子 好 啊   纸尿裤的牌子好啊
# 张翰 郑爽 是 什么 关系 啊   郑爽张翰什么关系
# 我 的 配置 能 玩 我 的 世界 吗   这配置能玩我的世界吗
# 怎样 在 电脑 上 看 漫画 啊   电脑电脑怎样看漫画
# 微信 消息 怎么 群发   微信好友怎么还了
# 熊出没 之 过年 插曲 是 什么   熊出没之过年中插曲插曲是什么
# 我 感觉 自己 萌萌 哒 什么 意思   感觉萌萌哒什么意思
# 初音 未来 哪些 歌 好听   初音未来有哪些好听好听
# 快乐 家族 演 的 电影 叫 什么   湖南卫视快乐家族主持人近期的电影名字叫什么
# 如何 提高 自己 的 英语口语 呢   如何提高自己的英语口语
# 多久 用 一次 面膜 好   面膜多久做一次
# 要 有 谐音 的 歇后语   <UNK>是那里的
# 猪肝 怎么 炒 好吃   怎么炒曰好吃
# 气势雄伟 ， 拔地倚天 是 什么 生肖   气势雄伟拔地倚天是什么生肖
# 求 一个 老电影 名字   求一个老电影的名字
# 世界 上 最大 的 半岛 是 什么 岛   世界上最大的岛屿是什么最大的半岛
# 求 一部 法国 轻喜剧 电影 的 名字   求一部的电影电影名字
# 生日 邀请函 怎么 写   生日<UNK>怎样写
# 什么 时候 上映   什么时候上映
# 暴风 影音 网址 是 啥   影音影音的时候还什么什么
# 今天 是 几九 第几天   今天几九几九的第几天
# 怎样 升级 安卓 手机 版本   手机怎样升级手机
# 聚美 优品 有 假货 吗   聚美优品有的吗
# 有 哪些 关于 忍者 的 电影   关于忍者的电影
# 手机 怎么 注册 邮箱   如何注册手机邮箱
# 给 您 推送 银行卡 输入框 您 输入 一下 ， 查询 一下   给您需要推送银行卡<UNK>一下查询的银行卡查询一下的
# 你 的话 很 有 道理   你是什么<UNK>
# 犀利 仁师 什么 时候 更新   犀利仁师什么时候才啊
# 本兮 的 男朋友 是 谁   <UNK>的男朋友是谁啊
# 如何 在 手机 上 注册 淘宝网   手机如何注册淘宝网
# 煤气灶 早上 打不着 火   燃气灶打不着火
# 给 我家 小狗 取个 名字   给我家小狗取个名字
# 这个 韩国 料理 叫 什么   这些韩国的韩国叫什么
# 天天 酷跑 的 航哥 外挂 怎么 下载   天天酷跑的航哥外挂如何下载
# 皮鞋 买 什么 牌子 的 好 啊   皮鞋什么牌子好
# 我 的 怪癖   我的<UNK>怎样
# 东西 是 什么 意思   东西是什么意思意思
# 魔兽 世界 的 问题   魔兽世界问题
# 仇人相见 ， 分外眼红 ， 是 什么 生肖   仇人相见分外眼红是什么生肖
# 十堰 好玩 的 地方   十堰有哪些好玩的地方
# 为什么 变形 计不 更新 了 啊   为什么为什么<UNK>更新了
# 冰箱 什么 牌子 好   什么什么牌子冰箱
# 赵州桥 是 谁 修 的   <UNK>是谁的
# 女士 什么 牌子 的 手表 好   女士买什么牌子好
# 如何 用 微波炉 做 面包   怎样用微波炉做面包
# 请 推荐 一些 好玩 的 网游   推荐款好看的网游
# 最远 的 地方 是 什么 成语   <UNK>的是的成语是什么
# 三角 插 怎么 折   <UNK>纸怎么折感觉
# 三星 手机 如何 截图   三星手机怎么截图
# 《 考试 什么 的 都 去死吧 》 的 歌词   考试什么都去死吧歌词
# 为什么 百度 知道 会 被 封号   为什么我的知道被被被被
# 有 谁 知道 这部 电影 的 名字   想知道这部电影电影名字
# 青蛙 过河 怎么 过 的   小青蛙过河怎么才能
# 高血压 怎么 治疗   高血压怎么治疗吗
# 粉蒸肉 是 什么 地方 菜   粉蒸肉是什么地方的菜
# 沈阳 现在 下雨 了 吗   沈阳现在下雨吗
# 天天向上 和 快乐 大本营 那个 好看 些   天天向上和快乐大本营哪个好看
# 大学生 做 什么 兼职 好   大学生做什么兼职好啊
# 执着 是 什么 意思 啊   够执着的意思是什么意思
# 梦见 女人 裸体   梦见女人对女人
# 女人 补血 吃 什么   女人吃什么可以补血
# 本命年 为什么 会 很 倒霉 啊   本命年为什么会很倒霉
# 男士 皮带 什么 牌子 的 最好   男士皮带什么牌子最好
# 天天 酷跑 如何 解封   天天酷跑天天酷跑怎么解封
# 舒筋 健腰 丸 哪里 有 卖   哪里有舒筋<UNK><UNK>丸买
# 哪个 国家 的 国歌 最好   哪个国家生产的最好
# 蜿蜒 的 反义词 是 什么   <UNK>的反义词是什么么啊
# 玩 网页 游戏 用 什么 浏览器   什么浏览器玩网页游戏好
# 手机号码 怎么 找到 人   怎么找到手机号码找到
# 计算 下列 二重积分   二重积分的鞋子
# 怎么 才能 得 高分   怎么才能的高分
# 欲 钱 仙人 指 什么 生肖   欲前找<UNK>指什么生肖
# 现在 什么 摆地摊 最 赚钱   现在摆地摊卖什么赚钱啊
# 分手 后 还是 朋友 吗   分手了还可以做朋友吗
# 在 哪里 能 看到 范冰冰 演 的 苹果   范冰冰演的苹果在哪里能看
# 万能钥匙 怎样 下载   怎么下载万能钥匙那
# 怎么 教 孩子 画画   怎样教孩子画画
# 宝宝 吃 什么 奶粉 好   宝宝喝什么奶粉好
# 微信 怎么 转发 啊   微信怎么说
# 如何 在 麻将 上 做 记号   麻将要怎么做记号
# 请 推荐 几本 好看 的 小说   谁可以推荐几本好看小说
# 中国 好 声音 黄渤 什么 时候 播   黄渤中国好声音什么时候出来
# 多 玩 诛 仙 上 的 视频 怎么 下载   怎么上多弄视频多下载
# 腋下 有 小 的 肿块   腋下有小小<UNK>
# 什么 牌子 的 充电 宝好   什么牌子的充电宝好用
# 身份证 丢 了 怎么 挂失   身份证丢了怎么挂失
# 助理 工程师 有 什么 用   什么时候出<UNK>助理
# 姐姐 的 女儿 我 叫 她 什么   姐姐的女儿我叫什么
# 梦幻 西游 里 的 上古 灵符 有 什么 用   梦幻西游上古<UNK>有什么用
# 明星 现在 一般 用 的 什么 手机   明星手机用什么什么的
# 小米 手机 怎么 截屏 啊   小米手机怎样截屏
# 天天 酷跑 中 哪个 人物 最好   天天酷跑人物天天人物最好
# 怎样 缓解 疲劳   怎样可以缓解真假
# 如果 离婚 财产 该 如何 分配   如果的如果如何设置
# 画出 下面 各个 图形 的 对称轴   画出下面图形所有的对称轴
# 如何 使 声音 更 有 磁性   如何练磁性的人
# 关于 春节 的 作文 300 字 怎么 写   春节的作文作文怎么写
# 您 看看 红包 的 使用 范围 哦   您看下红包的使用范围
# 长时间 不 说话 系统 会 自动 断线 的 哦 亲   看到不回复下哦亲否则系统会断线的亲
# 高原 红 怎么 去除   高原红如何去除啊
# 阴茎 向 左 弯曲   阴茎的电视剧
# 甜菜 根 上海 哪里 有 卖   在上海哪里有卖甜菜根
# 求此 头像 的 情侣 头像   求这个头像的情侣头像
# 江阴 在 哪个 省   江阴是哪个省的
# 夫加 一笔 成 什么 字   夫加一笔变什么字
# 如何 提高 口才 能力   怎么才能提高自己能力
# 怎样 去 淘宝 购物   怎样用淘宝购物
# 有 什么 好听 的 手机 铃声 吗   有什么好听的手机铃声吗
# 这个 户型 怎么样   这个的网站
# 微信 买 东西 安全 吗   微信买东西靠谱吗
# 宝宝 在 哪 打预防针   宝宝去哪的
# 吃 什么 食物 能 补肾 壮阳   吃什么食物能补肾快
# 广州 哪里 好玩   广州哪里哪里好玩
# 非常 近义词 是 什么   非常的近义词是什么?了
# 求 一部 跟 少林寺 有关 的 电影   求一部少林寺的电影
# 雍正 是 怎么 死 的   <UNK>怎么死的
# 围 围巾 的 方法   系围巾的方法
# 手机 能 做 网店 吗   手机可以开网店开网店
# 支付宝 透支 消费 是 怎么回事 如何 透支   支付宝让余额是怎样啊
# 高圆圆 和 黄海波 是 什么 关系   高圆圆与黄海波什么关系
# 类似 神魔 养殖场 的 小说   类似于小说<UNK>的小说
# 房屋 维修 基金 是 怎么 算   房屋维修基金是什么
# 求 好看 的 都市 异能 小说   求好看的都市异能小说
# 梅花 脚印 是 什么 动物   什么动物是什么动物
# 三角形 怎么 算 周长   三角形怎么算周长
# 找 科幻小说 一本   求一本科幻小说
# 鲫鱼 最 喜欢 什么 味道 的 饵   鲫鱼喜欢吃什么味道
# 属狗 戴 什么 好   属狗要什么什么
# 电子 信息工程 就业 前景   电子信息工程就业问题
# 有 什么 工作 是 可以 在 家里 就 能 做 的   有什么工作可以在家做工作
# 我家 狗狗 便秘 , 没 精神 怎么办 ， 它 刚刚 到 我家   我家的狗狗便秘怎么办求解
# 司马迁 是 哪个 朝代 的 人   在哪个哪个朝代的人
# 房屋 租赁 合同 的 问题   房屋租赁合同的问题
# 如何 清洗 汽车 内饰   汽车车怎么清洗
# 如何 升 高血压   水果怎么做
# 过年 发 什么 福利   过年什么什么时候
# 牙疼 吃 什么 药 最 管用   牙疼吃什么药效果
# 辛苦 您 按照 我 给 您 的 路径 去 手机 设置 下 的 呢   您按照我给您的路径去手机怎么设置下
# 用 流量 打电话 的 软件 叫 什么 名字   有没有什么可以用流量打电话的软件
# 怎样才能 让 每天 都 保持 好 心情   如何让自己每天都心情好
# 蓝牙 如何 传 游戏   蓝牙怎么传游戏
# 请问 在 哪里 能 看到 人间 中毒 的 完整版   哪里可以看人间中毒未删减版
# 求 三国 梦想 中文 全集   求三国梦想全集中文
# 马 宝宝 起名   宝宝<UNK>的专业
# 第二季 爸爸 去 哪儿 什么 时候 放   爸爸去哪儿第二季什么时候播出
# 迎春花 什么 时候 开   迎春花什么时候开
# 如何 查询 驾驶证 是否 扣分   驾驶证查询驾驶证扣分
# 中国移动 套餐 问题   中国移动的套餐问题
# 我要 和 你 在 一起   我要我们在一起
# 找 一些 诡异 的 图片   找<UNK>的图片
# 谁 知道 这部 微 电影 名字   想知道这部微的名字
# 苦瓜 干 怎样 吃 好   苦瓜干多怎么吃
# 微信里 表情 都 是 什么 意思   火影表情表情是什么意思啊
# 电子狗 哪个 品牌 好用 又 准确   汽车电子狗哪个牌子的好用
# 增肌粉 哪个 牌子 好   增肌粉哪个牌子
# 保养 卵巢 吃 什么   吃什么卵巢卵巢
# 南京 联创 怎么样   南京<UNK>怎么样
# 时空 猎人 版本 忘 了   时空猎人时空猎人了
# 黄 字 怎么 写 好看   黄字怎么写
# 西安 是 那里 有 卖假 发 的   .西安那里有卖假发
# 手机 怎么 开 热点   手机热点怎么开
# 外婆家 哪些 菜 好吃 在 哪里   外婆家什么菜好吃在哪里
# 世界杯 的 吉祥物 叫 什么   世界杯吉祥物叫什么
# 如何 验证 邮箱   邮箱怎么验证
# 王俊凯 的 照片 哦   王俊凯照片找照片
# 好看 的 重生 穿越 小说   好看的穿越重生小说
# 这 视频 中 的 歌曲 是 什么 歌 啊   这段视频里的歌曲是什么
# 手机 屏幕 怎么 清洗   手机屏幕工资怎么清洗
# 七龙珠 谁 最 厉害   七龙珠谁最厉害
# 什么 软件 可以 改变 手机 的 字体   什么软件可以修改手机的字体
# 小狗 的 简单 衣服 怎么 做   <UNK><UNK>的衣服怎么做最简单
# 怎样 偷 生二胎 不 罚款   生二胎怎样让不可以
# 功夫 派 号 换 赛尔 号   功夫的功夫号号
# 什么 牌子 的 粉饼 比较 好   什么牌子的粉饼好用呀岁
# 义勇军 进行曲 是 谁 作曲 的   义勇军进行曲是谁的
# 那些 游戏 修改器 好用   我哪个修改器和游戏
# 遥控 飞机 飞 不 起来   遥控飞机飞不起来了
# 求 经典 的 街机 游戏   求一个街机游戏名
# 如何 安装 汽车坐垫   汽车坐垫怎么安装
# 这个 图片 是 什么 动画片   这个图片是什么动画片
# 手机 版 先锋 影音 怎么 用   手机版的版先锋怎么用
# 电音 之王 那 女 的 是 谁 啊   电音之王是谁唱的
# 减肥 晚上 不 吃饭 能 瘦 吗   晚上不吃饭可以减肥吗?急求
# 不用 圆规 可以 怎么 画圆   不用圆规怎么可以带
# 把 句子 补充 完整   补充完整句子
# 红米 玩机 手册 从 哪 下载   红米的手工镐在哪
# 动物 过冬 的 方式 有 哪些   动物过冬的方式
# 怎么 开通 网上银行   怎么开通怎么开通
# 现在 魔兽 世界 怎么 赚钱   现在玩玩得得赚钱
# 网易 新闻 和 腾讯 新闻 哪个 强   网易于网易的新闻全集
# 得不到 的 就 毁掉   得不到的电影都
# 杭州 的 特产 是 什么   杭州哪里有什么特产
# 说 一个 人 很 被动 是 什么 意思   一个生肖一个一个是什么意思
# 怎么样 戒烟   我想找到
# 包皮 过长 的 图片   包皮过长图片
# 什么 牌子 的 指甲油 质量 好 一点   什么牌子的指甲油干的快质量好价格也<UNK>
# 情人节 送 老婆 什么 礼物   情人节送什么礼物給老婆
# 您 说 的 是 多少 钱 呢   亲是多少钱的呢
# 时尚 羽绒服 品牌   那个手机好多少钱
# 这个 是 哪个 动漫 里 的 妹子   这个妹子是哪个动漫里的
# 您好 ， 这种 情况 ， 需要 到 学校 的 圈存 机上 进行 圈存 ， 辛苦 您 了   您好这种情况是需要您到学校的圈存操作圈存的麻烦您了
# 手表 戴 在 手腕 什么 位置   手表戴在什么位置
# 电脑 怎么 调 闹钟   电脑怎么设闹钟
# 天天 酷跑 什么 挂 最好   天天酷跑用什么软件最好
# 积分 兑换 都 有 什么 礼品   中国移动网上营业厅兑换什么礼品
# 跪求 郭德纲 一段 相声   求说的相声
# 怎么 查询 驾驶证 真假   驾驶证查询驾驶证真假
# 手机 被 锁 了 怎么 解锁   <UNK>手机怎么解锁
# 什么样 的 手机 性能 比较 好   现在应该有什么样的手机
# 酷狗 音乐 播放器 下载 的 歌曲 在 哪里   酷狗不<UNK>下载来的<UNK>存放在哪里了
# 百度 老总 是 谁   百度谁是老总
# 暴风 影音 的 问题   暴风影音问题问题
# 邮政 快递 怎样 查询   我重新查询快递怎么查询
# 校园 黑道 小说   从校园黑道小说
# 求 天天 酷跑 内购   天天酷跑可以天天酷跑
# 谁 可以 告诉 我 这 首歌 的 名字   谁能告诉我这首歌的名字
# 惩罚 的 反义词 是 什么   惩罚的什么版本的
# 新 倚天 屠龙记 邓超版   邓超版的倚天屠龙记的小<UNK>怎么修改
# 如何 提高 自己 的 理解力   如何提高自己的
# 找 一张 搞笑 图片   求一张搞笑的图片
# 大学生 适合 做 什么 兼职   大学生适合什么兼职的
# 哪里 有 硬币 回收   哪里有回收可以看
# 我 的 牙齿 经常 一块 一块 的 往下掉 怎么办   我我家的小说只有孕妇做<UNK>
# 广州 至 珠海 轻轨 什么 时候 开通   广州到珠海轻轨什么时候开通
# 石家庄 驾校 哪个 好   石家庄好哪个好一点啊
# 男人 吃 什么 食物 增加 雄性激素   什么药可以食物
# 哪个 品牌 保暖 内衣 最好   大那个牌子的手机
# 淘宝 电脑 客户端 怎么 下载   电脑版怎么下载<UNK>
# 斗 战神 罗刹 带 什么 宝宝 好   斗战神冰罗刹带什么宝宝好
# 这种 配置 能 玩 看门狗 吗   这种配置能玩看门狗玩吗
# 苏州 衣服 去 哪里 买   苏州衣服哪里可以买
# 有 什么 听歌 的 好 软件   用什么软件听歌好
# 为什么 电脑 总是 无故 死机   电脑为什么无故<UNK>
# 手机 怎么 扫描 二维码   手机手机上怎么扫描
# 求 一些 四叶草 的 图片   求<UNK>的图片
# 苹果 手机 有 什么 好玩 的 单机游戏   苹果手机有什么好玩的单机游戏
# 人人 如何 强制 加 好友   人人网怎么强制加好友
# 为什么 女人 那么 爱 吃醋   为什么女人之爱<UNK>
# 关于 火影忍者 主题曲   火影忍者主题曲
# 求 可爱 的 韩国 短信铃声   求韩国卡通图片的
# 把 钱 放 余额 宝 安全 吗   余额宝怎么样安全吗
# 新 桑塔纳 贵 还是 新 捷达 贵 ， 哪个 好   捷达和新桑塔纳好
# 今年过年 流行 什么 衣服   今年过年流行什么衣服呢
# 什么 面膜 最好   什么面膜面膜好
# 英语 四级 什么 时候 可以 查 成绩   英语<UNK>什么时候<UNK>
# 福建 辣椒 王 哪里 买 才 最 正宗   哪里有卖辣椒王
# 九朵 云 和 马油   九朵云和马油哪个好
# 妹 买车 要 写 我 的 名字   <UNK>买车该叫名字
# 重庆 黑 山谷 旅游   重庆旅游黑<UNK>
# 钓 鲤鱼 喜欢 爱 吃 什么 饵料   请问要用什么鱼饵鱼饵钓鲤鱼
# 蚊子 最 怕 什么 味道   女人谁什么味道
# 最近 有 什么 好看 的 神话 电视剧   最近有什么好看的电视剧
# 时空 猎人 这是 哪个 版本   这是时空猎人那个版本
# 一朵 玫瑰花 代表 什么   一朵玫瑰花代表什么什么
# 排卵期 有 什么 明显 症状   <UNK>水果是什么症状
# 鸽子 几天 下蛋   鸽子<UNK>真人工通知呢
# 好多 电影 找 不到 链接   找不到电影资源
# 手机短信 内容 怎么 查   手机短信怎么怎么查
# 加减乘除 少 一点 。 打一字   加减乘除少一点打一字
# 怎么 手机 订票   手机怎么手机订票
# 百度 账号 如何 申请   百度账号怎么网上
# 如何 开通 手机 银行   手机银行怎么银行
# 苹果 手机 怎么 删除 通讯录   苹果手机怎么恢复删除
# 填 关联词 并 造句   用酸奶无论也用什么
# 什么样 的 数码相机 好   数码相机买什么样的好
# 为什么 耳朵 里面 总是 有 响声   为什么<UNK>女人为什么<UNK>就医生
# 钟汉良 现在 在 忙 什么   现在现在现在什么什么
# 怎么 在 淘宝 开 网店   淘宝上开网店上开网店
# 怎样 在 手机 贴 吧 取消 关注 的 贴 吧   手机贴吧关注贴吧贴吧
# 爸爸 去 哪儿 台湾   爸爸去哪儿去哪儿
# 怎样 让 人家 看到 自己 的 微店   如何让别人看到我的微店
# 称呼 男朋友 的 昵称   男朋友的男朋友起
# 烟台 有 什么 好玩 的 地方   烟台都有什么好玩的地方
# 传销 举报 的 电话 是 哪个   举报呀是哪找
# 飞哥 与 小佛 怪物 猎人 怎么 玩   <UNK><UNK>怪物猎人怎么玩
# 怎样 查询 车辆 违章 记录   如何查询曰查询车辆违章
# 淘宝 怎么 下载   怎样下载明哥
# 手机 版 我 的 世界 可以 去 地狱 吗   我的世界手机版怎么去地狱
# 发 卡通图片 吧   发发的
# 三个 和尚 没水 喝 呀 为 呀 为什么   为什么三个和尚没水吃
# 情人节 送 男友 什么   情人节送什么给男友啊
# 什么 职业 最 赚钱   什么职业靠多
# 电影 三枪 拍案惊奇   电影<UNK>啥电影
# 求 这张 图片 高清 版   谁图片这张图片
# 终于 等到 你 ， 还好 我 没 放弃 。 什么 歌 的 歌词   终于<UNK>你还好我没<UNK>.是什么歌
# 大家 怎么 看 宏源证券   <UNK>怎么样
# 关于 公主 的 小说   有关公主的小说
# 枸杞 红枣 泡 有 什么 功效   大枣枸杞泡水有什么作用作用
# 微信 头像 怎么 更换   微信怎么头像头像
# 女人 为什么 肚子 大   女人为什么肚子大捏
# 有 什么 好看 战争 的 电影   有什么好看的电影电影战争
# 祸害 成患 妖 成灾 广播剧   <UNK><UNK>穿<UNK><UNK>
# 淘宝 没 发货 可以 退款 吗   淘宝发货了还能退款吗
# 怎样 让 脚 变小   怎么让脚变小
# 如何 去除 脸上 的 黑头   如何去除脸上的黑头
# 如何 创建 微信 公众 平台   如何免费免费公众公众号
# 有 什么 好玩 的 双人 小游戏   有什么好玩的双人游戏
# 如何 注册 支付宝 帐号   如何注册支付宝帐号
# 现在 除了 苹果 还有 什么 手机 比较 好 阿   现在除了手机还有什么手机比较好
# 丁桂儿 脐 贴 怎么 用   <UNK>用怎么用啊
# 网上 定 火车票 怎么 取票   网上订火车票怎样取票
# 天天 快递 怎么 投诉   如何下载天天快递
# 全民 斩仙 的 激活码 是 什么   全民<UNK>没激活码
# 老公 过生日 做 什么 菜 在 哪里   老公过生日什么菜都在他吗
# 什么 行业 有 前途 些 啊   什么行业有前途
# 首尾呼应 猜 什么 生肖   首尾呼应打什么生肖生肖
# 淘宝 的 支付 密码 怎样 找回   淘宝的支付密码忘找回怎么找回
# 怎么 到 微店 买 东西   在在买微店买东西
# 求 做 创世 中文网 小说 封面   创世中文网写小说封面
# 奥奇 传说 的 号 和 密码   奥奇传说送号和密码
# 霸气 的 女生 头像   女生霸气头像
# 怎么弄 这种 头发   这种头发是怎么弄发
# 孕妇 可以 吃 兔子 肉 吗   孕妇吃兔子肉好吗
# 有钱 就是 任性 ， 英语 怎么 说   有钱就任性英语怎么写
# 哪里 批发 服装 便宜   那里批发哪里便宜
# 我国 四个 直辖市   我国四个直辖市词
# 天酷 跑 外挂   <UNK>跑外挂
# 这样 的 帽子 如何 编织   如何编织帽子上的豆
# 怎样 瘦小 腿 上 的 肌肉   怎样瘦小腿肌肉或者是腰
# 杜甫 是 怎么 死 的   杜甫怎样死的
# 怎样 用 积分 求 体积   积分积分求体积
# 苹果 手机 怎么 拒绝 来电 啊   苹果手机来电怎么拒绝
# 现在 农村 种 什么 最 赚钱   现在农村做什么赚钱
# 求 类似 爱情 电影   求这个电影的爱情
# 眼皮跳 是 有 什么 原因 造成 的   这几天总是眼皮跳是什么原因
# 岳飞 是 怎么 死 的   岳飞是怎样死的
# 下 嘴唇 上长 刺 瘊子 怎么 才能 更好 的 去掉   奥比会员心的怎么进
# 年终总结 怎么 写   说说说说怎么写
# 到 韩国 买 什么 化妆品   韩国化妆品什么牌子
# 为什么 打牌 老是 输   有些为什么有些手机黑屏
# 这个 鞋子 是 什么 牌子   鞋子鞋子是什么牌子
# 学生 适合 什么 发型 最好 带图   适合中学生最流行什么发型
# 我 这 电脑配置 可以 玩剑 灵 不   我的电脑配置能玩剑灵吗
# 赵奕欢 的 头发 是 什么 颜色 的   <UNK>的头发是什么颜色的
# 这样 配置 能 玩 什么游戏   这样配置能玩什么游戏
# 都市 小说 求 推荐   求推荐都市小说
# 喝 红酒 加 什么 容易 醉   红酒<UNK>什么容易醉
# 夏天 穿 棉袄 是 哪个 城市 名   夏天穿棉袄是哪个城市
# 若 是 您 无法 领取 的 ， 这个 是 72 小时 后 自动 的 退款 的   是的在小时没有领取的是自动的退款的
# 这 配置 能 玩逆战 吗   这样配置可以玩逆战吗
# 西游记 是 什么 体 小说   西游记是什么体小说
# 这个 视频 背景音乐 是 什么 啊   这个视频的背景音乐是什么啊
# 逗 女孩子 开心 的 笑话   哄女孩子开心的笑话
# 奥拉 星源 神 怎么 打   奥拉<UNK>怎么打
# 农业 银行卡 怎么 注销   <UNK>怎么注销农业
# 手机 增值 业务费 如何 取消   如何清理联通增值<UNK><UNK>短信<UNK>
# 买 手表 什么 网站   是什么网站买网站
# 江浙 一带 最 流行 的 地方 戏曲 是   <UNK><UNK>的最地方的地方
# 梦幻 西游 卖 物品 店   梦幻西游物品店
# 帮 宝宝 取个 名   帮宝宝取个图片
# 穿越 成 皇帝 的 小说   皇帝小说
# 华为 升级包 在 哪儿 下载   华为哪里下载搜狗
# 佛山 那里 好玩   <UNK>那里好玩
# 我 想 兼职 英语翻译   帮什么好里的
# 这双 鞋配 什么 衣服   这双鞋配什么衣服图片
# 借物 喻人 的 文章   有哪些借物喻人的文章
# 这张 图片 的 情侣 照   谁图片情侣图片的
# 如何 做 工资表   工资表怎么做
# 海绵 宝宝 的 笑声   宝宝宝宝写
# 小尾巴 怎么弄   贴吧小尾巴
# 如何 去除 鼻子 上 的 黑头   怎么去除鼻子上黑头
# 新浪 微博 的 问题   新浪微博问题
# 北京 石油化工 学院 有 什么 好 专业   北京<UNK>有什么好处
# 春晚 相亲相爱 伴奏   春晚<UNK>伴奏伴奏
# 驾校 报名 需要 本人 去 吗   驾校报名需要本人吗
# 为什么 浏览器 都 打不开   我的浏览器打不开
# 联通 积分 怎么 兑换 话费   联通网上营业厅怎么用积分
# 如何 开 淘宝 店   怎样开淘宝店
# 大 飞机 有 什么 好处   打飞机有什么好处好处
# 求 推荐 好看 的 韩国 电影   求推荐韩国好看的电影
# 火影忍者 的 结局 是 什么   火影忍者的大结局是什么
# 艾灰是 什么   <UNK>什么时候<UNK>的
# 怎么 用 手机 看 湖南卫视 直播   用手机怎么看湖南卫视直播
# 成语 微 什么 什么 微   什么什么什么微的成语
# 为什么 世界杯 没有 中国   世界杯为什么没有中国中国
# 海贼王 什么 播放器 可以 缓存   用什么播放器可以缓存海贼王
# 求 这 张图 的 情侣 头像 男 的   找这张图情侣头像
# 馒头 怎么 做 好吃   怎么做坐做好吃
# 这是 什么 木头 手串   这是什么木头写手串
# 怎样 去 黑头 粉刺 最 有效   怎样去黑头粉刺我给下问下
# 一般 女生 打 几个 耳洞 好看   女生打几个耳洞打几个
# 您 的 余额 支付 功能 是 关闭 的 呢   您的余额支付功能是关闭的吗
# 求 《 今天 开始 恋爱 吧 》 漫画 全集   求找今天开始恋爱吧全集
# 怎么 写 试用期 工作 总结   <UNK>工作怎么写
# 青睐 什么 意思   青睐是什么意思
# 刘海 怎么 绑 好看   齐刘海怎么扎好看
# 烧饼 修改器 怎么 用 天天 飞车 刷 金币   天天飞车怎么刷金币
# 从前 有个 太监   <UNK>有个<UNK>
# 天猫 京东 哪个 好   京东是那个好的
# 微微一笑 很 倾城 全文   微微一笑全文相遇全文
# 什么 电影 好看 又 搞笑   什么搞笑电影好看比如好看的电影
# 您好 ， 您 的 余额 支付 功能 被 关闭 了 ， 请问 是 您 本人 关闭 的 吗   亲您当前余额支付功能是关闭的请问是您本人关闭的吗
# 穿越 火线 的 挂 怎么 下载   穿越火线怎么下载穿越火线
# 跪求 好看 的 热血 动漫   好看好看的动漫
# 男生 脸小 适合 什么 发型   男生<UNK>的男生适合什么发型
# 怎么 将 公用 网络 改为 家庭网络   怎么把家庭网络改为公用网络
# 神奇 宝贝 最 厉害 的 是 哪个   又萌宝贝厉害
# 煮 鸡蛋 能 隔夜 吃 吗   熟鸡蛋能吃吃吗
# 要 这个 字 怎么 写 连笔 字 好看 点 就 行   <UNK>的<UNK>字怎么写才好看
# 赛尔 号 怎么 得 螳螂   赛尔号怎么卡螳螂
# 魔兽 世界 现在 什么 职业 好玩   魔兽世界现在玩什么职业比较好玩
# 最近 有 什么 好看 的 动画片   最近有什么好看的动画片啊
# 三星 手机 垃圾   三星手机垃圾
# 水浒传 里 谁 的 武功 最高   水浒传里武功最高的人是谁
# 阴囊 湿疹 如何 该 怎么 治疗 , 该用 什么 药   湿疹该有些身份证该怎么<UNK>
# 英雄 联盟 什么 时候 更新   英雄联盟什么时候更新啊
# 怎样 快速 提高 视力   如何快速提高
# 吉吉 影音 手机 上 怎么 下载   手机版的吉吉影音如何下载
# 医院 怎么 取精   医院是怎么取精
# 看 电影 什么 播放器 好   看什么播放器看电影好
# 爸爸 去 哪儿 游戏 下载   爸爸去哪儿游戏下载
# 女孩子 取 什么 名字 好听   女孩子叫什么名字好听
# 兔子 肉 怎么 做 好吃   兔子肉怎么烧好吃
# 内马尔 那 是 什么 发型   内马尔是什么发型
# 青岛 属于 哪里 的   青岛属于哪里哪里
# 有 哪些 床戏 激烈 的 电影   有哪些床戏的电影有哪些
# 请问 这 双 鞋子 怎么 搭配 衣服   看这<UNK>怎么搭配衣服呢
# 自己 的 胎盘 自己 能 吃 吗   自己可以吃自己可以吃吗
# 现在 做 什么 行业 最 挣钱   现在什么行业最挣钱
# 什么 方法 可以 让 头发 长得 快 一点 呀   什么方法能让头发长得快一点
# 有 什么 搞笑 的 动画片 啊   有什么动画片搞笑搞笑的
# 哪里 有 手机 版 我 的 世界 中文   <UNK>世界手机版的哪里有
# 谁 有 好看 的 小说 介绍 一本   谁小说好看的小说推荐
# 怎么 制作 个人简历 封面   怎么制作制作
# 烫伤 后 怎么 处理   水烫伤后怎么处理
# 关联词 有 哪些   关联词有哪些树啊
# 谁 能 告诉 我 这 是 什么 成语   谁能告诉我这个是什么什么成语
# 如何 下载 广场 舞 视频   广场舞视频怎样下载
# 孕妇 服用 钙片 , 一天 中 什么 时间 吃 最好 ？ 谢谢   钙片一天中什么时候吃最好
# 富士康 怎么样   只要怎么坐啊
# 成都 现在 穿 什么   老现在好找什么裤子
# 为什么 说 桂林山水 甲天下   桂林山水为什么甲天下
# 求 情侣 头像 高清 的   求情侣头像的高清头像
# 如何 跳 广场 舞   如何跳好舞
# 大 小三阳 是 指 什么   小三阳是什么歌名
# 给 我 一首 伤感 歌曲 吧   我想找一首电视剧
# 这是 什么 动画   这是什么动画里
# 恐怖电影 都 有 哪些 ， 新 的   里哪些新恐怖电影
# 业精于勤 下 一句   <UNK>下下一句
# 谢娜 有没有 跟 张杰 离婚   张杰和谢娜有没有离婚
# 怎么 下载 天天 酷跑 电脑 版   天天下载怎么酷跑到电脑
# 傲世 九重天 的 txt 全集 下载 地址   傲世九重天txt全集下载地址
# 怎样 头发 长得 快   怎么头发长长得最好
# 溜冰 后 的 女人 有 什么 反应   女人喝什么反应
# 真实 的 灵异 事件   我的真实灵异事件
# 可以 的 ， 但是 您 需要 可以 登录 这个 账户   是的哈需要登录那个账户才可以的
# 剑灵 会员 咋 弄 啊   剑灵会员怎么开
# 怎样 向 意林 投稿   <UNK>怎么说投稿
# 现在 在 网上 如何 络 怎么 赚点 小钱   在网上如何能赚点小钱
# 怎么 去除 磁盘 被 写 保护   <UNK>被写保护怎么写
# 头发 怎样 护理   头发怎么进
# 梦幻 西游 孩子 怎么 快速 升级   梦幻西游怎么让宝宝快速升级
# 石家庄 的 技校 哪个 好   石家庄好的技校哪个
# 为什么 我 一 看到 女神 就 说不出 话   我看到她她脸红有点<UNK>话来.啥<UNK>
# 什么 泡水 喝 可以 补气血   什么泡水<UNK>可补气血
# 我 怀疑 老婆 出轨 了   我怀疑我老婆出轨了
# 苹果 种子 范冰冰   苹果范冰冰种子
# 熊出没 电影 什么 时候 上映   电影熊出没什么时候上映
# 莫名其妙 是 什么 意思   <UNK>是什么意思
# 选词 填空 、 扩句   选词填空的
# 怎么 激活 移动 手机卡 了   移动手机卡怎么激活
# 有 什么 好看 的 桌面壁纸   有什么好看的单机游戏
# 帮 您 转接 查看 一下 ， 可以 吗   帮您转接一下一下可以吗
# 深圳 的 简称 是 什么   深圳简称是什么?是深吗
# 一 什么 什么 的 稻子   什么的稻子
# 求 去 水印 谢谢   求去水印谢谢
# 哪里 电动车 以旧换新   哪里可以得手表
# 中通 快递 太 垃圾   中通快递真<UNK>
# 怎么 可以 做好 淘宝   淘宝怎么才能做好
# 英雄 联盟 的 问题   一个联盟问题
# 我 的 世界 这是 什么   这是什么世界的世界怎么挖
# 《 一桶 水 》 的 阅读 答案   <UNK>水的阅读答案
# 如何 训练 狗狗   如何训练狗狗发
# 吴恙 在 天天向上 唱 的 什么 歌曲   天天向上吴恙唱的歌曲歌曲
# 关于 局域网 建设   <UNK>说建设
# 开 网店 怎样 做 宣传   开网店开网店啊
# 各路 神仙 帮帮忙   各路神仙帮帮忙吗
# 怎么 才 可以 成为 网络红人   怎么样可以成为网络红人
# 家庭教师 同 人文   家庭教师<UNK>版
# 英语 句型 转换   英语的句型转换
# 拿 什么 拯救 你 我 的 爱人 讲 的 是 拯救 谁   新版拿什么拯救你我的爱人经典台词
# 哪个 网站 比较 好 下载 小说   哪个网站下载比较小说网站
# 结婚证 上 的 照片 有 什么 要求   照结婚证的照片有什么要求吗
# 中国 重工 还 能 涨 吗   中国<UNK>能买跌吗
# 这 是 啥 类型 图片   这两个电影是什么
# 联想 手机 怎样 刷机   联想手机知道手机怎么刷机
# 天天 跑酷 跑 破解版 怎么 下载   天天跑酷破解版怎样下载的
# 就是 可以 这么 任性   就是可以这么任性吗
# 哪里 能 看 完整版 人间 中毒   哪里有人间中毒的完整版
# 电脑 声音 突然 没 了   电脑突然没了没声音
# 深圳 有 什么 好玩 的 地方   深圳有什么好玩的地方
# 你 是 干什么 工作 的   你是干什么工作的工作
# 腾讯 微信 随手 记到 国外 发消息 往 国内 能用 么   国外能用微信吗
# 深海鱼 油 什么 牌子 好   什么牌子的<UNK>的
# 当爱已 成 往事 我该 怎么 做   当爱已怎么解除结婚证
# 有 什么 好听 的 绰号   什么绰号好听
# 谁 知道 这是 什么 软件   想知道这是什么软件啊
# 多 吃 玉米 会长 胖 吗   吃煮玉米会长胖吗
# 微乐 怎么 加 粉丝   <UNK>怎么加加贵
# 求 好玩 的 手机 网页 游戏   求几款好玩的网页游戏
# 怎么 才能 让 鼻子 变高   怎样让鼻子变高
# 有 什么 比较 好 的 制作 音乐 伴奏 的 软件   用什么软件制作伴奏乐
# 香港 有 什么 是 必买 的   香港<UNK>对什么什么
# 看图 写 话 一年级   看图写话一年级
# 为什么 在 国内 不能 访问 国外 的 网站   为什么我的电脑在国外能用的网站
# 谁 有 时空 猎人 破解版   谁懂下时空猎人破解版的
# 找 一部 搞笑 电影   求一部搞笑的电视剧电影
# 最好 的 上海 骨科 医院   上海的骨科医院哪个最好
# 身上 长 小红点   身上.有些小红点
# 银行卡 怎么样 冲 话费   银行卡怎么交模式
# 德高望重 是 什么 意思   德高望重是什么意思
# 淘宝网 怎么 加 别人 好友   淘宝网怎么做好友吗
# 麻烦 您 登录 您 的 QQ 邮箱 支付宝 查询 一下 的 呢   麻烦您登录一下qq邮箱支付宝查询一下
# 香菇 可以 和 牛肉 一起 炒 吗   <UNK>与<UNK>一起可以吗
# 谁 有 日本 动作 爱情片 啊   日本动作谁有<UNK>
# 迎春花 是 什么 颜色   迎春花是什么颜色的
# 皇家 马德里 属于 哪个 国家   皇家马德里是哪个国家
# 右 眼角 有 痣 代表 什么   左喝的痣代表什么
# 手机 版吉吉 影音 怎么 下载   吉吉版版怎么怎么下载
# 手机套 这么 脏 ， 怎么 给 弄 干净 啊   皮手机套怎样洗干净
# 怎么 用 绳子 编 手链   如何用手链
# 图片 出自 那个 动漫   求图片出自哪部动漫
# 怎样 才 让 老婆 更爽   怎样舔<UNK>老婆什么
# 女人 如何 保养 好 卵巢   女人的卵巢怎么保养
# 怎样 查询 学历证书   如何查询档案
# 为什么 现在 的 人 都 这么 自私 了   现在的人为什么都那么自私
# 世界 最长 的 城墙 是   世界上最长的<UNK>
# 暴风 影音 的 网址 是 什么   暴风影音的问题急什么
# 猪八戒 探路 是 什么 生肖   猪八戒探路是指什么生肖
# 乌龟 请客 打一 成语   乌龟后打一成语
# 手机号码 删除 ， 想 找回   现在的手机号码怎么找回
# 用 引人注目 来 造句   引人注目造句
# 今年 世界杯 冠军 是 谁   今年的世界杯是谁是冠军
# 淘宝 如何 取消 实名 认证   淘宝实名认证怎么实名认证
# 权志龙 这个 发型 叫 什么 啊   权志龙发型叫什么
# 稍 等 ， 为 您 查看 下   您稍等我您稍等下
# 重庆 到 福州 动车 什么 时候 开通   福州重庆重庆动车动车时候开通
# 在 微信 上 怎么 做 代理   微信上怎么做
# 比较 好 的 减肥 产品 有 哪些   减肥产品哪个好有哪些减肥网站
# 开 网店 有 哪些 流程   开网店的所有流程
# 屌丝 女 什么 意思   屌丝<UNK>什么意思
# 套套 什么 牌子 的 好 呢   什么牌子牌子的
# 天天 酷跑 下 一期 的 坐骑 是 什么   天天酷跑下一只坐骑是什么
# 如何 用 哑铃 练 胸肌   用什么软件最好
# 中国 传统 文化 还有 哪些   中国传统文化有哪些
# 深蓝色 的 裙子 配 什么 颜色 的 鞋子 好看   <UNK>裙子配什么颜色的鞋子
# 我爱你 你 爱我吗   <UNK>.这么<UNK>
# 韩语 大叔 怎么 说   大叔韩语怎么说
# 怎么 把 手机 的 业务 取消   手机怎么取消业务的业务
# 四大名著 读后感   <UNK>的读后感
# 支付宝 主 账户 怎么 注销   支付宝账户怎么注销
# 初一 数学 ， 解方程 ， 谢 了   初一数学解方程
# 怎样 下载 天天 飞车 外挂   怎么下载天天飞车外挂
# 紫薇 命盘 怎么 看   建议您查退款到手机吗
# 唐僧 是 什么 佛   <UNK>是什么<UNK>
# 在 哪里 买 诛 仙 漫画书   哪里有卖漫画书的
# 天天 酷跑 如何 修改   天天酷跑天天酷跑
# 海贼王 这 周 为什么 没 更新   为什么这周海贼王没更新
# 中国 惊奇 先生 全集 漫画   中国惊奇先生全集漫画
# 找 家庭教师 的 图片   求家庭教师的图片
# 吸烟 有 多 大 危害   吸烟的危害有那些危害
# 陈羽 凡 和 白 百合 离婚 了 吗   陈羽凡和白百合离婚了吗
# 辛苦 您 再 看 下   辛苦您您看一下
# 查询 别人 手机 话费 余额   手机查询别人的手机话费余额
# 哪些 银行 的 信用卡 好 申请   那个银行的信用卡好申请
# 男生 有 个性 的 网名   男生<UNK>的男生网名.<UNK>的
# 离婚 的 女人 会 后悔 吗   离婚后有<UNK>的吗
# 你们 都 用 什么 牌子 的 卫生巾   什么牌子卫生巾好
# 求 《 个人 取向 》 所有 歌曲   求个人取向里的歌曲
# 地税 发票 盖 的 是 什么 章   <UNK>发票盖什么<UNK>
# 怎么 看 我 是 歌手 第二季 直播   我是歌手第二季会看吗大家直播
# 我 的 世界 手机 版 怎么 做 附魔台   我的世界手机版附魔台怎么做
# 大家 谁 知道 这个 小说 的 名字   谁知道这小说什么名字
# 天天 飞车 怎么 才能 拿 高分 ， 跑 更 远   天天飞车怎么才能刷高分
# 您 的 扣款 金额 是 多少 呢   亲的还款您金额是多少呢
# 如何 提高 自己 的 能力   该如何提高自己的口才能力
# 您 需要 权限 来 执行 此 操作   您需要权限来执行此操作
# 我们 都 是 好人   我是什么关系
# 丑女 变 美女 的 小说   <UNK>美女变的小说
# 英雄 联盟 怎么 快速 挣 金币   英雄联盟怎么打才能快速刷金币
# 我 的 配置 能 玩 热血 无赖 吗   我的配置能玩热血无赖么
# 大家 快 帮 我 猜猜 成语   猜猜这个网络红人
# 求 男生 短发 发型   求这个男生短发的什么发型
# 深圳 的 天气 最近 怎样   深圳的天气怎么样
# 怎么 下载 智能 会 对话 的 汤姆 猫   会说话的汤姆猫手机版下载怎么下载
# 我 的 配置 能 玩 御龙 在 天 吗   我的配置能玩神魔配置能玩吗
# 求 香港 一部 恐怖片   求一部香港的香港
# 淘宝网 可以 买 火车票 吗   淘宝网买买火车票吗
# 爱心 不 打烊 的 意思 是 什么   不不更新什么意思
# 腋下 总是 出汗 有 异味 怎么办   腋下大量出汗有异味怎么办
# 自己 的 私家车 怎么 出租   <UNK>怎么<UNK>自己的
# 贴 吧 怎么 能 快速 升级   怎样快速贴吧升级
# 妒忌 的 近义词 是 是 什么   <UNK>的近义词是什么词
# 有 什么 电影 好看   什么什么电影好看好看
# 怎么 投诉 淘宝 卖家 卖 假货   怎样投诉淘宝卖家卖假货
# 哪个 视频 软件 下载 最快   下载视频软件那个软件
# 刀塔 传奇 我 的 阵容   刀塔传奇<UNK>
# 同桌 的 你 什么 视频 软件 可以 免费 看 了   同桌的你电影哪一个视频网站可以免费观看
# 黄河 民谣 有 哪些   与黄河有关的<UNK>
# 不能 使用 有 什么 提示 呢   不能使用不能是什么
# 什么 软件 送 流量   有什么软件可以领流量
# 现在 的 人 最 需要 什么   现在人们需要什么什么
# 长春 在 哪个 省   长春在那个省
# 陈永馨 你 不 知道 的 事 伴奏   你不知道的事陈永馨伴奏
# 考试 什么 的 都 去死吧 伴奏   考试什么都去死吧伴奏
# 脱胎换骨 的 意思 是 什么   脱胎换骨是什么意思
# 怎么 看出 自己 是不是 一个 备胎   如何判断自己是否是她的备胎
# 为什么 手机 天天 酷跑 玩 不了   为什么酷派手机玩不了天天酷跑
# 关于 夏天 的 成语   夏天的的成语
# 这图 是 什么 电影 的   这图是什么电影里的啊
# 脱脂奶 可以 做 酸奶 吗   <UNK>怎样能开酸奶
# 怎么 做 更 舒服   如何做驾校
# 宇宙 之外 有 什么   宇宙是什么什么
# 今天 的 财神 在 哪个 方位   今天财神方位是哪
# 谁能给 我 一个 天天 酷跑 号   谁能给我一个好的天天酷跑号
# 熊出没 之雪岭 熊风   <UNK><UNK>是<UNK><UNK>
# 百度 贴 吧 如何 快速 升级   求百度贴吧如何快速升级
# 三国演义 谁 最强   三国演义中谁最强
# 破折号 什么 作用   这个是什么作用
# 这是 什么 ， 谢谢   这是什么树?谢谢
# 沐浴 在 阳光 下 什么 意思   <UNK>的什么意思
# 什么 好看 的 电影 推荐 一下   有什么好看的电影推荐一下
# 微信 怎么 卖东西   怎么在微信上卖东西啊
# 如何 给 好 声音 投票   怎样把好声音
# 吹泡泡 的 水 怎么 调   吹泡泡的水怎么<UNK>呀
# 凝视 的 意思 是 什么   <UNK>什么意思
# 本 机号码   本机号码
# 晕车药 吃 多 了 会 怎样   <UNK>吃多了会怎样
# 我 的 世界 编辑器 怎么 用   我的世界编辑器怎样用不了
# 微信 怎么 转发 啊   微信怎么说
# 我家 的 狗狗 是 什么 品种 啊   我家的狗狗是什么品种的
# 叶一茜 和 田亮 有 几个 孩子   跟二和几个有孩子
# 奥奇 传说 极品 号   奥奇传说上传说号
# 哪些 软件 下载 网站 比较 好   去哪些网站下载软件比较靠谱
# 补血 喝 什么 好   吃什么什么好
# 知道 是 什么 东西   经常知道是什么东西
# 怎样 使用 京东 礼品 卡   如何使用京东礼品卡
# 我 的 世界 怎么 做 活塞 门   我的世界里的世界怎么写
# 求 百日 蔷薇 漫画   求百日蔷薇漫画漫画
# 求 罗百吉 吹喇叭 完整版   求罗百吉的吹喇叭
# 感人 又 好看 的 电影   谁有啥好看的电影
# 四个 字 的 好听 名字   四个字好听的名字
# 微会 怎么 打电话   微会打电话怎么打电话?
# 仓库 管理 表格   我管理详细的文章表格
# 行李箱 密码 打不开   亲密码密码密码
# 怎么 注册 陌陌 账号   陌陌怎么注册账号
# 有 什么 软件 可以 做 头像   有没有什么软件可以免费头像
# 黄牛票 在 哪 买   在哪可以买黄牛票
# 翻译 一个 英语 句子   翻译能否翻译
# 电脑 怎么 看 电视直播   电脑用怎么看看电视直播
# 在 哪里 可以 申请 免费 个人主页   哪里可以免费申请个人主页
# 葫芦 侠 修改器 怎么 刷 钻 啊   葫芦侠修改器怎么刷金币
# 什么 牌子 的 纯牛奶 好   什么牌子纯牛奶好
# 异地 领 结婚证 都 需要 什么 证件   在异地领结婚证<UNK>需要什么证件
# 新春 祝福 的话   <UNK>可以自己这部的
# 月加 一笔 成 什么 字   <UNK>一笔什么什么字
# 老鼠 喜欢 吃 什么   白喜欢吃什么意思
# 领 结婚证 需要 带 什么   领结婚证需要带什么证件
# 御宅 伴侣 修改器   工作人员伴侣有修改器
# 月亮 从 哪边 升起 ， 哪边 落下   月亮从哪儿<UNK><UNK>吗
# 求 问道 单机版   求问道上的表情
# 天天 酷跑 白金 小帅配 什么 坐骑 好   天天酷跑的白金小帅配坐骑最好
# 微 信号 的 怎么 可以 修改   微信号怎么修改
# 四年级 语文 下册 书   四年级下册语文书
# 美食 代购 店 的 货源 都 是 哪里 的   那里开始的店最哪里
# 求 范冰冰 的 苹果 完整版   求范冰冰苹果什么高清
# 妈妈 爱 吃 什么 菜 阅读 答案   妈妈爱吃什么菜阅读题答案
# 如何 让 自己 快速 生病   怎么让自己快速生病
# 寻 一篇 杰娜 小说   一篇杰娜小说
# 如何 设置 支付宝 快捷 支付 限额   支付宝设置限额怎么设置的
# 手机 酷狗 和 天天 动听 哪个 好   手机天天动听和酷狗哪个好
# 找 吉祥 言情小说 集   找吉祥的言情小说集
# 感叹号 什么 意思   这感叹号是什么意思?哪里意思
# 经常 手脚 酸 是 为什么   经常<UNK>酸为什么
# 喜闻乐见 什么 意思   <UNK>是什么意思
# 什么 牌子 的 笔记本电脑 玩游戏 好   玩游戏什么牌子的笔记本电脑好
# 什么 是 专用 播放器   什么专用播放器最好
# 一刻千金 猜一 生肖   <UNK>猜一生肖
# 为什么 没 人理 我 呢   为什么没人理我
# 磨粉机 什么 牌子 好   什么牌子的<UNK>好
# 怎样 养狗 家里 不臭   如何在家里不臭
# 怎么 让 脸 变长   怎么才能让脸变长
# 是 不 收费 的 啊   是不收费的
# 求此 漫画 人物 名称 以及 出处 ~ 谢谢   求此图中动漫人物的名字及出处
# 有没有 电影 网站   有没有什么网站搞笑的
# 三心二意 的 生肖   三心二意是那个生肖
# 穿 什么 文胸 比较 好   什么文胸比较好
# 求 鉴定 阿迪达斯 鞋标   阿迪达斯鞋标求鉴定
# 坚持不懈 是 什么 意思 耶   <UNK>是什么意思
# 如何 用 流量 打电话   用怎么打电话打电话
# 推荐 好看 的 言情小说   好看的言情小说推荐
# 怎样 做好 淘宝 客及 推广   淘宝如何做推广客
# 寻找 男女 对唱 的 一首歌   找对唱的一首歌
# 什么 是 邮政编码   <UNK>什么是什么
# 奥比 岛 甩 白雪公主 城堡 ， 要 的 来   奥比岛甩白雪公主城堡
# 怎么 练 三角肌   <UNK>怎么<UNK>
# 爱管闲事 惹 的 一身 骚 的 生肖   爱管闲事惹的一身骚的生肖
# 我 的 野蛮女友   我的<UNK>怎样
# 汽车票 能 提前 几天 买 啊   汽车票可以提前几天买
# 跪 求爱 如生 论坛 的 邀请 码   急求爱如生论坛的邀请码
# 什么 牌子 的 小 电饭锅 好   电饭锅什么牌子好
# 全自动 洗衣机   全自动洗衣机怎么
# 最 荒凉 的 地方 打一 成语   最荒凉的地方.打一成语
# 有 什么 好 的 可以 赚钱 的 网站   有什么好的赚钱网站啥的吗
# 求 一部 美国 黑帮 电影   找美国美国一部电影
# 家里 有台 电脑 怎么 赚钱 啊   一台电脑在家里怎么赚钱
# 恩 那个 账户 登录 密码 记得 吗   亲您好记得那个账户登录登录密码么亲
# 母亲节 是 什么 时候   母亲节什么时候
# 纸 青蛙 怎么 折   艺术青蛙怎么折
# 什么 手机游戏 可以 赚钱   有什么可以赚钱的手机游戏
# 净水器 生产厂家   净水器有哪些
# 怎么 把 头发 变软   头发头发怎么头发
# 刘恺威 怎么 认识 杨幂 的   刘恺威和杨幂怎么认识的
# 姓朱 女孩子 起 什么 名字 好听   朱姓女孩起什么名字好听
# 求 一部 特种部队 电影   求一部有关的电影有关的
# 带 着 孩子 在家 能 做 什么 工作   在家带孩子能做什么工作
# 玩 不了 愤怒 的 小鸟   愤怒的小鸟玩不了
# 为什么 我 的 手机 玩 不了 天天 飞车   我的手机怎么玩不了
# 我 这 配置 可以 玩 洛奇 英雄传 吗   我的配置能玩吗
# 怎么样 才能 让 自己 成为 网络红人   怎么样才能成为自己
# 一部 关于 异形 电影 不知 叫 什么 名字   一部美国的一部电影名字
# 怎样 注册 微信 公众 平台   如何注册微信公众平台
# 老 农民 电视剧   老电视剧老农民
# 脸上 的 小黑点 怎么 去除   脸上的<UNK>小黑点怎么去掉
# 朋友 结婚 有 什么 可以 说 的 祝福语 吗   我朋友结婚要送什么祝福语
# 时空 猎人 怎么 刷 金币   时空猎人怎么赚金币
# 怎么 去除 脸上 的 小黑点   脸上的小黑点怎么去除
# 坐 客车 白酒 可以 带 吗   做什么可以做白酒吗
# 谁 给 刘德华 喝 忘情水   谁给刘德华喝忘情水
# 一个 人 在家 很 无聊 ， 怎么办   一个人在家无聊怎么办
# 恩恩 ， 马上 就 可以 的 哦   我可以知道是可以的
# 为什么 我 下载 的 问道 怎么 不能 用 啊   为什么我的问道下载了怎么不能了
# 什么 电影 的 海报   这个海报是什么电影
# 现在 哪里 可以 免费 下载 歌曲   现在可以免费下载歌曲
# 现在 最 流行 的 电影 是 什么   现在流行什么电影呢
# 有没有 什么 好看 的 头像   有没有什么好看的头像男
# 那里 有 鸡婆 多   哪里有鸡婆店
# 什么 什么 地问   什么人才
# 孕妇 吃 火龙果 好 吗   孕妇可以吃吗
# 用 什么 软件 看 电影 最好   什么软件看电影最好
# 好看 的 玄幻 小说 推荐   点点小说求推荐好看
# 童星 香奈儿 的 照片   童星香奈儿的照片
# 肺 气虚 吃 什么 中成药   肺气虚吃什么中成药
# 感冒 头疼 吃 什么 药   感冒吃什么药好得快
# 剃须刀 什么 牌子 好   什么牌子可以订<UNK>的
# 怎么 查 交通违章   <UNK>查怎么查
# 吃 什么 东西 利尿   吃什么东西可以利尿
# 上海 的 亚历山大 是 个 什么样 的 会 所   上海的个<UNK>
# 青岛 童装 批发市场 在 哪里   青岛<UNK>批发市场哪里在
# 世界 第一 美女 是 谁   世界第一美女是谁啊
# 求 一部 奥特曼 电影   求一部奥特曼电影
# 时空 猎人 这是 什么 版   帮现在版时空猎人的
# 有 什么 好玩 的 网页 游戏 吗   有没有什么好玩的网页游戏
# 深圳 有 哪些 物流 公司   深圳物流公司有哪些
# 求 小说 ， 有 什么 小说 好看   小说什么好看的小说
# 国产 手表 哪个 牌子 比较 好   国产手表手表哪个牌子的
# 哪里 旅游 好玩   哪里有老好玩的
# 徐若瑄 天使 三部曲   天使三部曲测试天使
# 百雀羚 和 韩束 哪个 好   韩束和百雀羚哪个好
# 京东 商城 买 的 东西 怎么 退货   京东商城买京东东西如何退货
# 被 买家 恶意 差评 我 该 怎么办   我的淘宝店被买家恶意买家了
# 自拍 的 动作 怎么 好看 图   自拍的时候怎么比好看的动作
# 语文 ： 选词 填空   语文选词怎么
# 补水 套装 什么 好   什么牌子的补水
# 用 什么 软件 下载 电影 好 啊   用什么软件下载电影好
# 诚恳 的 反义词 是 什么   <UNK>的反义词是什么么啊
# 对于 女生 初吻 有 什么 意义   <UNK>的女生有什么什么
# 怎样 学 唱歌 不 跑调   怎么唱歌真不不跑调
# 手机 淘宝 要 怎么 注册   如何在手机上淘宝
# 您 提供 一下 您 的 姓名 和 联系电话 ， 和 可用 的 邮箱 ， 辛苦 您 了   您提供一下您的可用邮箱姓名和您的联系电话辛苦您了
# 电动车 充电器 哪个 牌子 好   电动车的电池充电器哪个品牌好
# 奇葩 是 什么 意思   说人是什么意思
# 地下城 与 勇士 怎么 可以 转 区   地下城与勇士模式怎么转
# 什么样 的 丰胸 精油 好   好看的精油怎么样
# 千里之堤 的 下 一句 是 什么   <UNK>下一句是什么
# 新疆 什么 宽带 好   新疆什么什么好
# ...
# 怎样 可以 让 头发 快速 生长   怎么让头发快速让头发
# 什么 牌子 的 裤子 好   裤子什么牌子好
# 怎么 才能 让 老婆 喷水   可以让老婆让老婆啊
# 发生 交通事故 后处理 的 程序 怎样 走   发生交通事故<UNK>怎样处理
# 请 大师 帮 我 看看 面相 ， 谢谢 啦   请会看面相的大师帮我看看
# 洛杉矶 在 哪里   去洛杉矶住了
# 高山流水 是 什么 生肖   经常是什么生肖
# 我 是 歌手 第二季 直播 在 哪里 看   我是歌手第二季大家哪里可以看
# 喜剧 性 爱情 电影   喜剧的爱情电影
# 脚黑 穿 什么 颜色 的 凉鞋   脚黑的人穿什么颜色凉鞋
# 我 这 是 巴西 亚鱼 吗   这是条巴西<UNK>吗
# 斗 战神 火 罗刹 带 什么 宝宝   斗战神冰罗刹带什么宝宝好
# 头上 长 了 虱子 怎么 去除   头上长了虱子怎么去掉
# 分手 大师 好看 吗   分手大师好看吗
# 求 一部 九十年代 电视剧 名   找一部<UNK>的电视剧
# 今年 春运 几号 开始   今年几号开始春运
# 炸鸡 与 啤酒 什么 意思   这个配置谁被意思意思
# 哈尔滨 红肠 怎么 吃   哈尔滨怎样怎样<UNK>
# 造句 ， 倍感 亲切   用好更好
# 这是 时空 猎人 的 哪个 版本   这是时空猎人那个版本的
# 怎么 查 通话记录   怎么查别人的通话记录
# 怎么 在 电脑 上 拍照片   电脑怎么怎么找
# 我 喜欢 你 ， 你 喜欢 我 吗   我喜欢睡你喜欢吗
# 小米 盒子 都 装 什么 软件   小米盒子用什么软件
# 穿越 火线 刷枪   穿越火线怎么火线
# 求个 天龙八部 免费 脚本   免费免费快递免费
# 电信 与 网通 哪个 好   网通和网通哪个好
# 是 的 ， 请 您 以 页面 的 显示 为准 的   请您到页面页面显示为准的
# 杨幂 和 胡歌 什么 关系   杨幂和胡歌什么关系吗
# 孕前 检查 挂 什么 科   孕前检查挂什么号
# 关于 春天 的 诗句 有   与春天有关的
# 孙金龙 到 哪里 去 了   哪里去哪里去了
# 地产 招商 怎么 做   招商<UNK>怎么样
# 歌曲 女人 花 的 原唱 是 谁   女人女人花这原唱是谁
# 什么 软件 下载 最快   什么软件下载下载软件
# 时空 猎人 怎样 找回 密码   时空猎人如何找回密码
# 石家庄 的 快递 公司 哪个 好   石家庄哪个快递比较好啊
# 打 四川 麻将 怎样 才会赢   打四川打更赢
# 胡萝卜 怎么 烧 好吃   胡萝卜怎么做好吃
# 天天 酷跑 叉叉 助手 怎么 刷 金币   怎么用叉叉助手刷天天酷跑的积分
# 中国 结 怎么 打   怎么解中国结
# 广东 工业 大学 怎么样   电子技术大学怎么样啊
# 周杰伦 的 发型 我要 怎么 剪   周杰伦发型发型剪发型
# 哪个 ， 天气预报 软件 准确   哪个软件哪个准
# 北京西站 可以 过夜 吗   可以可以制作吗的
# 坏蛋 是 怎样 炼成 的 电视剧   电视剧坏蛋是怎样炼成的
# 关于 诗海 拾贝 的 手抄报   <UNK><UNK>手抄报
# 微微一笑 很 倾城 的 全文   微微一笑很倾城全文
# 电磁感应 现象 是 谁 最先 发现 的   谁走了是是谁
# 梨花 什么 什么 颜色   今年帮什么什么颜色的
# 微信 上 如何 抢红包   微信怎么抢红包
# 悦诗 风吟 的 面膜 怎么样   <UNK>风吟面膜代理怎么样
# 怎么 下载 切 西瓜 游戏   切西瓜的下载下载
# 鱼竿 怎么 绑 鱼线   怎么绑到手机上
# 中国 哪里 的 地方 最美   中国哪里有最美地方
# 铠甲 勇士 里面 谁 最 厉害   铠甲勇士拿瓦谁最厉害
# 什么 卡 打电话 便宜 啊   打电话什么什么便宜
# 怎么样 才能 得 厌食症   怎样<UNK>怎样
# 新年 春节 给 领导 送礼 送 什么 , 纠结 啊   春节给领导送礼送什么
# 小孩 几岁 学 轮滑 合适   小孩几岁可以学轮滑
# 我 的 梦 中国 梦 演讲稿 急求   中国梦我的梦演讲稿
# 我们 中国 在 哪个 地方 最 多 美女   中国哪个地方的美女最多
# 工作人员 将 在 您 提交 之后 的 48 个 小时 之内 帮 您 审核 ， 建议您 耐心 关注 一下   工作人员将在您提交之后的个小时之内帮您审核麻烦耐心等待
# 祷告 是 什么 意思   <UNK>什么意思
# 怎么 把 粗心 的 毛病 改掉   怎么才能改掉粗心的毛病
# 徒手 写 一千 行 代码 调试 没 bug 什么 意思   徒手写<UNK>行代码<UNK>没<UNK>是什么意思
# 快乐 大本营 下期 谁 来   下期快乐大本营是是谁啊
# 怎样 查找 同名同姓 的 人   如何查找同名同姓的人
# 网上 买 书 哪里 最 便宜 最全   网上哪里买书最全最便宜啊
# 请问 这个 手串 是 什么 木头   请问这手串是多少木头值多少钱
# 春节 一个 人 怎么 过 呀   一个人的春节怎么过
# 怎样 注册 电子邮箱   如何注册电子邮箱
# 愤怒 的 小鸟 怎么 下载   愤怒的小鸟怎么下载
# 用 手机 看 直播 ， 哪个 软件 好   手机手机哪个软件哪个软件好
# 为什么 我 看 不了 新浪 视频   为什么只有视频只有不了视频
# 逆战 名字 空格 怎么 打   逆战怎么名字名字怎么打
# 您 可以 联系 一下 银行 客服 核实 一下 银行卡 的 明细   您是联系一下您银行卡账户一下您的吗
# 这是 什么游戏 或者 动漫 里 的 吗   这是什么游戏漫画的动漫里的
# 义乌 哪里 批发 便宜 的 袜子 啊   义乌哪里批发便宜袜子
# 三星 手机 怎么 恢复 出厂 设置   三星手机上的设置设置
# 广西 话 癞 得 久 盲 什么 意思   广西话中的<UNK>大意思
# 亲 ， 花 呗 还款 是 确认 收货 的 下个月 10 号 再 还款 的   花呗还款是确认收货的下个月还款前还款
# 空气 能 热水器 好 吗 ， 什么 牌子 好   空气能热水器什么牌子好
# 找 一个 好听 的 男生 网名   找一个好听的男生网名
# 求个 好听 的 游戏 名字   找个好听的游戏名字
# 你 是 我 的 眼 原唱 是 谁   我是歌手里的原唱是谁啊
# 现在 有 什么 好玩 的 回合制 游戏   有没有什么好玩的回合制游戏
# 超 好看 校园 言情小说   有哪些好看的校园言情小说
# 各位 有 在 车管所 上班 的 吗   有在<UNK>上班的吗
# 求 五十 度 灰 电影   哪里能下载苹果电影
# 采菊 东篱 下 的 下 一句 是 什么   <UNK><UNK>下的下一句是什么
# 跪求 , 英雄 联盟 好玩 还是 梦 三国 好玩 ? 坐等 呢   跪求这个联盟还是梦三国好玩的价格
# 鸭蛋 怎么 做 好吃   长<UNK>怎样做好吃
# 这 配置 可以 玩 蜘蛛侠 ： 破碎 维度 吗   我的配置能玩蜘蛛侠破碎维度吗
# 五行 缺水 戴 什么   五行缺水戴什么好呢
# 稻子 熟 了 像 什么   稻子对了什么什么
# 投笔从戎 是 什么 意思   投笔从戎的意思是什么意思
# 僵尸 叔叔 僵尸 谁 演 的   求僵尸的僵尸求
# 刘备 用 什么 武器   用什么武器冲
# 百年大计 ， 教育为本 指 什么 生肖   百年大计教育为本是什么生肖
# 酷跑 里 有效 下滑 是 什么 意思   酷跑有效下滑什么意思
# 静则 思已 ， 乱世 称雄 的 动物 是 什么   静则思已乱世称雄的动物是什么
# 我 是 歌手 冠军 是 谁   我是歌手的总冠军是谁
# 我 自己 感觉 有点 说话 含糊 或 有点 结巴 , 怎样 克服 啊   我自己手机和<UNK><UNK>的<UNK>输入法
# 含 比喻 词 的 成语   含含的成语成语
# 励志 的 个性 签名   给自己的的签名签名
# 广州 那里 好玩   广州哪里好玩
# 怎样 用 毛线 织 帽子   毛线怎么考帽子
# 女人 为什么 都 这么 现实   女人老女人怎么这么现实
# 城南 旧事 作者   <UNK><UNK>对哪里
# 这个 图片 出自 哪部 动漫   求图片出自哪部动漫
# 帮忙 给 宝宝 起个 名   帮忙给姓<UNK>的宝宝<UNK>名
# 这个 女主播 叫 什么 ？ 韩国 的   韩国女主播这个是什么什么
# 金正恩 为什么 要 搞 张 成泽   金正恩为什么要抓张成泽
# 微信 理财 通 收益 怎么 算   微信理财通收益怎么计算
# 剑网 三 怎么 去 五毒   剑网三<UNK>怎么入
# 这 图片 是 什么 动画   这个图片是什么大
# 孕妇 能 用 什么 补水 面膜   孕妇该用什么补水面膜
# 这个 动画人物 叫 什么   这个是谁动画人物
# 为什么 叫 英雄 联盟   英雄联盟是英雄联盟
# 怎样 做个 好人 啊   怎样做个好人
# 求 类似 重生 之 我 能 升级 的 小说   类似类似于重生之我能升级的小说
# 在线 宝宝 起名   宝宝在线等
# 女包 品牌 有 哪些   品牌女包有哪些品牌
# 格子 间 女人 什么 时候 上映   格子间女人什么播放器可以看
# 今年 流行 什么 短发 发型   今年流行什么发型好看
# 怎么 查 通话记录   怎么查别人的通话记录
# 如何 办理 大额 信用卡   怎么申请网上
# 韭菜 和 生姜 怎样 榨汁   韭菜和生姜榨汁怎么榨
# 腊肉 怎么 做 好吃   腊肉怎么做好吃
# 动漫 的 姐妹 头像   开动漫的头像
# 今晚 的 中国 好 声音 几点 开始   今晚几点中国好声音
# 为什么 我 发现 我 从来 没 真正 爱过 一个 人   为什么我<UNK>都没有爱过一个人
# 做 什么 生意 有 前途 呢   什么生意有前途
# 分数 乘 整数 的 计算 法则 是 什么   分数乘分数和分数乘整数的计算法则是什么
# 柯震东 发型 怎么 剪   柯震东的发型怎么剪了
# 那个 网站 能 免费 下载 小说   能免费下载电影网站
# 古剑 奇谭 好看 吗 有 看 的   古剑奇谭什么可以看到
# 请问 今天 是 农历 几号   请问今天什么是什么几号
# 水垢 怎么 去除   怎么能告诉双面胶的呀
# 描写 人物 的 最 短 句子   描写人物的句子
# 杭州 哪里 可以 读 夜校   杭州哪里有个<UNK>
# 高考 名著 考 哪些   高考都有哪些名著
# 坐飞机 什么 东西 不能 带   坐飞机的时候有什么东西不能带的
# 十亩 竹园 一根 笋 是 什么 生肖   <UNK><UNK>一根<UNK>.是什么生肖
# 马赛克 怎么 用 在 视频 上   用视频打马赛克下载
# 汽车 可以 带 宠物 吗   坐汽车可以带宠物吗
# 在 哪里 可以 有 步步 惊心 全集   步步惊心全集哪里有
# 为什么 微信 朋友圈 图片 不 显示   为什么微信朋友圈的图片显示<UNK>
# 苹果 手机 怎么 把 搜狗 输入法 设置 成 默认 输入法   怎么在苹果手机上设置搜狗输入法
# 又 加 什么 偏旁 可以 组字   我加偏旁大什么<UNK>
# 您好 ， 麻烦 您 在 其他 的 浏览器 操作 一下 ， 辛苦 您 了   建议您更换浏览器操作一下抱歉给您带来不便
# 我 的 世界 秘籍   我的世界秘籍怎么得
# 怎么 追 天秤 女   <UNK>女怎么追啊
# 米黄色 裤子 配 什么 衣服   米黄色裤子配什么上衣还有鞋子
# 为什么 下 隧 水道 的 井盖 是 圆 的   <UNK>盖的的井盖为什么是圆的
# 怎么 在 网上 赚点 小钱   网上怎么短赚点
# 来自 星星 的 你 第二部 什么 时候 播出   来自星星的你第二部什么时候拍有什么时候上映
# 最 搞笑 的 小品   找个搞笑的男生
# 如何 点亮 英雄 杀 图标   英雄杀的图标怎么点亮
# 圆脸 男生 适合 什么 发型   圆脸的男生适合什么发型
# 有 什么 制作 图片 的 软件   制作图片的软件是什么软件
# 熊出没 之 过年 的 插曲 叫 什么   熊出没之过年三插曲都有些什么
# 民族团结 的 手抄报   民族团结的手抄报头
# 怎样 快速 长 头发   如何快速长头发
# 水 快速 结冰 怎么 做   <UNK>怎么快速开<UNK>
# 花 裤子 配 什么 上衣 图   花裤子配配什么
# 济南 有 什么 市花   济南有什么市花
# 语重心长 是 什么 意思   什么意思意思
# 火车票 图片 制作   制作火车票的火车票
# 甘油 哪里 有 卖 的   在哪里能买到甘油
# 广州 碎 布料 市场 在 哪   广州<UNK>市场
# 男神 ， 女神 分别 是 谁   男友的男神和女神是谁
# 奥比 岛 怎样 帮 精灵 升级   奥比岛怎样能让小精灵升级
# 过年 的 时候 北京 有 什么 好玩 的 吗   过年的时候有什么好玩的
# 有 哪些 好看 的 青春校园 小说   青春校园小说好看的
# 我 的 世界 光影 哪 一个 好   我的世界我的世界数字哪
# 在 那些 网站 购物 好   网站买手机网站
# 谁 送 我 美食 大战 老鼠 号   谁把美食大战老鼠的号号
# 公子 歌 心上人   公子歌的心上人
# 过年 了 卖点 什么 好 卖 呢   过年卖点什么好
# 孕妇 用 的 护肤品 哪个 牌子 好   孕妇用哪个牌子好
# 在 百度 如何 提问   百度怎么提问
# 哪个 网站 可以 下载 到 漫画 全集   哪个网站下载下载<UNK>网站
# 山西 籍 著名 女歌星 有 谁   山西著名著名都都谁
# 网上 兼职 是 真的 吗   网上刷钻兼职是真的么
# 求 末世 类 完本 小说   求末世完本小说
# 您 是否 有 开通 短信 校验 服务 的 呢   您好请问您有开通短信校验服务吗?每个月.元.元<UNK>的这个服务
# 谁 有 武林 外传 体验 区 激活码 啊   谁有武林外传体验区
# 什么 是 发票 抬头   什么是发票的
# 爸爸 去 哪儿 电影 完整版   爸爸去哪儿大电影完整版
# 求 福利 吧 论坛 邀请 码   找福利论坛吧码邀请码
# 兰岛 物语 ( 少女 的 约定 ) 下载   兰岛物语少女的约定下载
# 苹果 手机 图标 怎么 隐藏   苹果手机怎么删除漫画
# 这个 纹身 图案 是 什么 意思   这是什么纹身图案
# 小漠 冬阳 什么 关系   <UNK><UNK>什么什么
# 微信 为什么 发 不 出去 信息   微信信息为什么发不出去
# 怎么 卡 会员 永久   怎样会员怎么<UNK>
# 什么 牌子 的 空压机 好   什么牌子的空压机好呢
# 如何 在 微信 上 增加 粉丝   怎么让微信粉丝量
# 求 男生 的 动漫 头像   求男生头像头像头像
# 去 美容院 护肤 好 吗   去美容护肤到底好不好做
# 吃 什么 药能 让 月经 推迟   喝什么<UNK>让<UNK><UNK>
# 男 的 精子 是 什么 颜色 的   精子什么颜色
# 请 你 吃 麻辣烫 是 什么 意思   <UNK>吃麻辣烫什么意思
# 郑州 鞋 批发市场   郑州鞋有
# 把 心 给 我 情侣 网名 配对   给我的情侣网名励志<UNK>
# 藏文 翻译 在线   翻译一下在线
# 怎样 让 台式 电脑 连接 无线网   怎么让电脑说话别人得
# 热血 江湖 披风   热血江湖有问题
# 这个 女 的 叫 什么 韩国 的 网络红人   这个韩国网络红人叫什么
# 情人节 送 男朋友 什么 礼物 啊   情人节送什么給給男朋友
# 《 三国演义 》 中 的 武圣 是 谁   三国演义中<UNK>是谁
# 我 去年 买 了 个表 ， 什么 意思   我的时候打什么意思
# 何以 笙箫 默 电视剧 在 哪个 台 播出   何以笙箫<UNK>哪个台<UNK>放
# 北京 哪里 逛街   北京哪里有伴奏
# 什么 网站 下载 电影 好   什么什么网站下载好
# 宫 洺 为什么 换人   <UNK>洺换人
# 豆花 文 断裂 的 翅膀   断裂的翅膀豆花
# 王晶 电影 有 那些   <UNK>电影的电影
# 长春 百脑汇 在 那   百脑汇长春在哪啊
# 晚上 怎么 抓 野鸡   晚上怎么打怎么啊
# 世界杯 进球 最多 的 是 谁   世界杯进球最多的是谁
# 什么 是 政治面貌   经常是什么时候好看
# 作文 怎么 下载   <UNK>下载怎么下载
# 时空 猎人 电脑 版 怎么 下载   时空版怎么版怎么版
# 创世 兵魂 如何 刷枪 有 小 技巧 吗   创世兵魂如何刷枪
# 谁 能 告诉 我 这个 图片 里 的 人 是 谁   谁能告诉我图片里的人的
# 格力空调 与 美的 空调 哪个 好   美的和美的哪个哪个好
# 苹果 5s 外壳 可以 换 吗   苹果c外壳可以换吗
# 求 《 鬼畜 眼镜 》 的 漫画 全集   求鬼畜眼镜漫画全集
# 只有 面粉 和 鸡蛋 做 什么 吃 啊   鸡蛋和面粉能做什么
# 我 想 制作 自己 的 个性 签名   怎么可以制作自己的个性签名
# 这个 是 什么 颜色   这个包包是什么颜色的
# 那些 品牌 的 手表 比较 好   那些品牌手表品牌好
# 泰坦 之旅 不朽 王座   泰坦之旅不朽王座
# 世界 最远 的 地方 在 哪里   世界的的的地方在哪里
# 怎样 入侵 别人 的 手机   怎样入侵手机别人的手机信号
# 找 一首歌 的 歌名 ， 急   求一首歌名
# 做 寿司 用 的 工具 有 哪些   自己做<UNK>需要哪些材料
# 什么 牌子 的 电炒锅 好   电炒锅什么牌子的
# 面膜 可以 天天 敷 吗   可以可以天天做的面膜
# 为什么 联通 信号 不好   为什么联通信号不好不好
# 说 说 动物 过冬 的 各种 方式   动物过冬的方式有哪些
# 怎样 让 手机 通过 电脑 上网   手机用手机通过电脑上网
# 但是 这边 为 您 核实 到 申请 代付 的 交易 是 退款 是 退回 申请 代付 的 账户 的   您好这边的飞机核实到您的到已经是没有退回到的账户的的
# 吴亦凡 这 是 什么 发型   吴亦凡的发型什么什么
# 微信 怎么 下载   微信怎么下载地图
# 足球赛事 怎样 注册 才能 开户 啊   足球赛事可以注册吗?怎么开户的
# 有声 小说 在 哪里 可以 免费 下载   在哪里可以下载那种有声小说
# 求 一个 腾讯 微博 邀请 码   求一个腾讯视频的邀请码
# 中国 最美 的 大学   中国最美大学最美
# 巴比 馒头 加盟 多少 钱   巴比馒头加盟要多少钱
# 错误 的 反义词 是 什么   错误的反义词是什么呢
# 求 模拟 人生 的 动作 盒子   求模拟人生动作盒子
# 关于 我 的 爸爸妈妈 的 作文   关于我和我的爸爸妈妈的英文的文章
# 辛苦 您 填写 下 您 的 账户 绑定 的 手机号   辛苦您填写下您的账户绑定的手机号
# 拖把 什么 牌子 好   拖把什么牌子好
# 老舍 的 原名 是 什么 了 啊   老舍原名是什么
# 有 什么 好看 的 总裁 小说   有什么好看的激情总裁小说
# 男人 和 女人 的 区别 是 什么 捏   女人和男人有什么区别
# 作文 ： 不 一样 的 父爱   作文不一样一样<UNK>
# 照相机 什么 牌子 好   什么牌子的裤子好
# 京东 满 多少 免 运费   京东商城的钱免运费
# 怎么 查看 自己 百度 的 财富 值   如何查看自己的百度财富值
# 我爱你 日语 怎么 说   我爱你宝怎么说
# 这个 手机套 好看 吗   这个钱啥好看吗
# 先 联系 淘宝 给 您 修改 成 普通 账户 哦   联系淘宝给您修改成普通账户
# 为什么 赛尔 号 玩 不了   为什么赛尔号玩不了
# 找 女生 ， 聊天   这个想找一个聊天
# 亲 ， 您 尝试 换 一个 浏览器 试试   您更换一个浏览器试试看哦
# 我 怎么 和 情人 相处 啊   情人怎么相处
# 这个 小人 表情 叫 什么   这个表情表情叫什么啊
# 这个 表情 包叫 什么   这个表情包叫什么啊啊
# 百度 知道 在 哪里 转 幸运 大转盘   百度知道幸运大转盘在哪里帮我
# 斗罗 大陆 全集 漫画 ！ 急   漫画斗罗大陆漫画全集
# 如何 破解 别人 权限 空间   如何破解别人的空间空间访问权限
# 一笑千金 的 续集   <UNK>则<UNK>续集
# 求 重装机兵 ： 梦想 起飞 修改器   求<UNK>梦想<UNK>修改器
# 柬埔寨 为什么 叫 柬埔寨   为什么柬埔寨叫柬埔寨
# 那个 银行 好 小额贷款   哪个银行有小额贷款
# 谁 知道 有 什么 好看 的 电视剧 ， 谢 了   知道什么电视剧能好看吗
# 亲 稍 等 我 帮 您 查询 下   好的您稍等我帮您查询一下
# 鸡翅 尖 怎么 做 好吃 些   鸡翅怎么做好吃
# 怎么 成为 一个 网络红人   我想成为网络红人需要怎么做呢
# 什么 叫 互联网 思维   什么是互联网<UNK>
# 图片 里 的 小 动物 是 什么   这个图片上的动物是什么
# 电脑 上 怎么 玩 部落 冲突   部落冲突怎么玩穿越冲突
# 怎么样 让 电表 不转   怎样使电表<UNK>
# 有 什么 好看 的 三国 小说   我什么好看的三国小说
# 冬天 摆地摊 卖 什么 赚钱   冬天摆地摊卖啥最赚钱
# 对 我 说谎 试试 的 插曲 我 全部 要 啊   对我说谎试试插曲
# 怎么 扎 马尾辫 好看   怎样绑到好看好看
# 时空 猎人 怎么 刷 金币 和 魔晶   时空猎人怎么刷金币和金币
# 肺炎 吃 什么 会 好   肺炎吃什么好
# 上海市 是 什么 市花   <UNK>什么是的花的花
# 谁 知道 这是 什么 动漫   有谁知道这是什么动漫
# 手机 用 什么 软件 才能 看片   手机看片用什么软件
# 吃 什么 食物 能 补肾 壮阳   吃什么食物能补肾快
# 问道 怎么 下载   怎么下载问道
# 守护 甜心 ( 工 。 口 ) 小说   守护甜心小说
# 这个 狗狗 是 什么 品种 呢   这个狗狗是什么品种
# 水果 之王 是   水果之王是什么
# 新 倚天 屠龙记 邓超版   邓超版的倚天屠龙记的小<UNK>怎么修改
# 印章 上刻 的 什么 字   这印章上刻的电影什么
# 如何 利用 淘宝 客等 辅助 自己 的 淘宝 店 迅速 增加 人气   如何提高淘宝店的人气
# 苹果 用 什么 跑 分 软件   苹果手机能软件
# 用 书信 交往 的 人 叫 什么 友   用<UNK>交往的人叫什么
# 海贼王 过场 音乐   海贼王是哪些国家的
# 求 东京 喰 种 这 张 高清 的 图   求东京喰种的高清图
# 什么 时候 吃水果 好 呢   在什么时候吃水果好
# 快 过年 了 卖点 什么 好 呢   过年卖点什么好
# 多样 反义词   多样的
# 内存卡 格式化 后 怎么 恢复   内存卡的内存卡内存卡怎么恢复
# 老板 拖欠工资 ， 我该 怎么 呢   老板怎么比吃<UNK>
# 穿越 到 唐朝 的 小说   唐朝穿越到唐朝的小说
# 有关 草原 的 歌曲 有 哪些   有关草原上的歌曲
# 这个 是 韩国 网络红人 吧 ？ 叫 什么   这个韩国网络红人男的是谁
# 这个 狗狗 是 什么 品种 啊   这个狗狗是什么品种
# 有 什么 特别 的 意思   <UNK>什么意思?
# 怎么 打理 斜 刘海   斜斜斜刘海
# 世界杯 怎么 没有 中国队   世界杯没有了怎么<UNK>
# 都市 异能 小 说完 本 的   都市时小本本
# 就业 失业 登记证 办理   下载黄河的人
# 这个 日本 女演员 的 名字   这个日本的女演员名字什么名字
# 我 想 把 头发 剪短 怎样 发型 好看   我想剪短头发却不知道什么发型好看
# 百度 贴 吧 怎么 刷 粉丝   百度贴吧如何刷粉丝
# 包皮 瘙痒 红肿 用 什么 药   包皮红肿瘙痒用什么药
# 全职 猎人 什么 时候 更新 啊   全职猎人漫画什么时候更新
# 爱情 这 杯酒 谁 喝 都 得罪 歌词   爱情这杯酒不喝也得醉歌词谁有
# 恋恋 不 忘 在 哪里 看 全集   哪里可以看恋恋不忘全集
# 拜托 了 ！ 哥哥 姐姐 们   姐姐哥哥拜托了
# 双子座 的 女生 最 喜欢 什么样 的 男生   双子座的男生的女生的女生
# 纸尿裤 哪个 牌子 的 好 用 又 便宜 呢   要买纸尿裤哪个品牌好呢
# 吃 西餐 怎么 拿 刀叉   西餐中刀叉怎么用
# 梦幻 西游 转服 的 问题   梦幻西游转服的问题
# 哪个 牌子 手机 移动 电源 好   手机电源手机的的手机好
# 怎么 远程 控制 自己 电脑   如何远程控制自己的电脑
# 这个 动漫 女孩 是 谁   这个动漫女的是谁
# 类似 万 妖 之祖 的 小说   类似于穿越<UNK>类似小说
# 张杰 和 谢娜 什么 关系   张杰和谢娜什么关系
# 高兴 得 像 什么   像杨什么像什么
# 头上 长 了 虱子 该 怎么 去掉   头上长了虱子怎么才能
# 生日快乐 我 对 自己 说 这 是 什么 歌   我对我的微我什么歌
# 这个 头发 帘 是 怎么弄 的 叫 什么 烫   这个怎么弄头发
# 鸟语花香 的 什么   <UNK>的<UNK>什么什么
# 快快 游戏 盒 怎么 下载   怎么下载一个游戏游戏
# 过年 送 领导 什么 礼物 好   过年送什么礼物给领导
# 李玉刚 是 男 的 还是 女 的   黑是还是还是女
# 我 提 的 问题 在 哪里 看 答案   我问问题问题查看答案
# 给 个 种子 谢谢   给个种子种子谢谢
# 山西 籍 著名 女歌手 有 谁   山西籍著名都都是谁
# 如何 正确 使用 跑步机   如何的这个头像
# 怎么样 锻炼 肱 二头肌   怎么锻炼二头肌
# 天天 酷跑 如何 快速 赚 钻石   天天酷跑如何快速刷钻石
# 最近 有 什么 好听 的 音乐 歌   最近流行什么好听音乐
# 中国移动 免费 流量 怎么 获取   中国移动的流量怎么流量
# 香港 翡翠台 直播 软件   tvb翡翠台直播软件
# 最近 什么 股票 比较 好 啊   最近有什么股票比较好
# 帝王 欢 朕 的 废后 谁 敢动 、 求 全文 啊   帝王欢朕的废后谁敢动求全文
# 现在 女生 做 什么 职业 比较 有 前途   现在做什么工作有前途
# 高德 导航 和 百度 导航 哪个 好   <UNK>导航和导航模式哪个好
# 动力火车 的 一首歌 名   动力火车写的一首歌
# 苹果 手机 的 电池   苹果的世界工资是哪大
# 圆脸 适合 什么 发型   圆脸适合什么发型发型
# 中国 梦 我 的 梦 演讲稿   我的梦中国梦演讲稿
# 怎么样 才能 用 找回 淘宝 密码   淘宝怎么样找回密码
# 西瓜 用 英文 怎么 读   西瓜的英文怎么读
# 国产手机 哪个 好   国产手机那个好
# 中国 哪些 城市 工资 高   中国那个城市工资高
# 显示 的 是 处理 成功 的   是显示处理成功的哦
# 最 霸气 得 情侣 网名   哪个霸气的情侣网名
# 运气 不好 如何 转运   运气不好怎么转运
# 什么 牌子 的 月饼 好吃   什么牌子的月饼好吃呢
# 微信 的 收藏 怎样 删除   微信的收藏怎么删除
# 贴 吧 怎么 升级 啊 啊   贴吧怎么升级
# 飞机票 怎样 买 便宜   怎样能买买到便宜
# 怎样才能 提高 自己 的 情商   该如何提高自己的<UNK>
# 什么 牌子 的 电脑包 比较 好 呢   电脑包什么牌子的什么牌子好
# 快乐 与否 是 什么 意思   意思是我的意思什么意思
# 主角 一 开始 就 无敌 的 小说   主角无敌小说
# 想 给 我 女儿 取个 小名   帮我女儿取个小名吧
# 求 男主是 外国人 的 小说   找<UNK>外国人的小说
# 老婆 出轨 了 ， 我该 怎么办   自己的老婆出轨我该怎么办
# 吃 生姜 能 减肥 吗   生姜可以减肥吗
# 电脑 单机游戏 怎么 下载   怎么下载单机游戏到电脑上
# 怎么 下载 电影 ， 用 什么 软件 好   什么软件下载电影好
# 怎么 下载 天天 酷跑 到 电脑   天天酷跑怎样下载到电脑
# 今年 春晚 有 赵本山 吗   今年赵本山上吗
# 如何 下载 肥佬 影音   怎么下载怎么下载
# 求 天空 之 城 前奏 吉他谱   求天空之城吉他谱
# 现在 女孩子 用 什么 手机 最好   现在什么什么比较适合最好
# 帮忙 给 宝宝 起名   请帮忙取个宝宝
# 星座 是 阳历 还是 阴历   星座是按阴历还是阴历
# 世界 第一 的 公主 殿下   世界第一公主公主<UNK>
# 玫瑰 和 月季 有 什么 区别 ， 我 看着 很 像   玫瑰花和月季花有什么区别
# 什么 软件 可以 下载 电脑 单机游戏   可以软件可以下载电脑下载
# 这个 叫 什么 螺丝 ？ 哪里 有 的 买   这什么是什么牌子的
# 这边 需要 给 您 转接 处理 下   这个问题我帮您转接帮您转接帮您详细核实下
# 六年级 作文 ， 要 全部   作文<UNK>作文
# 遥不可及 什么 意思   <UNK>是什么意思
# 如何 测量 胸围   怎样测量胸围
# 求 这部 电视剧 名字   求这部电视剧名字
# 手机 淘宝 要 怎么 注册   如何在手机上淘宝
# 六年级 寒假作业 本 答案   本寒假作业答案答案
# 董卿 现在 干什么 啊   董卿现在干什么
# 怎么 清理 手机 运行 内存空间   手机正在运行内存
# 我 的 世界 中 牛奶 有 什么 用   我的世界和<UNK>什么用
# 落花 时节 又 逢 君   <UNK>的又逢的上上上上句
# 虚拟机 的 问题   种子一些问题
# 怎么 在 网上 购买 打折 机票   网上怎么查机票
# 重庆 哪里 的 火锅 好吃 呢   重庆哪里的火锅好吃呢
# 需要 看 转接 后 排队 情况   需要的您后<UNK>哦
# 感冒 吃 什么 药 好得快   感冒要吃才好得快啊
# 初一 思想品德   初一上有
# 山东 最 好玩 的 地方   山东的地方好玩
# 有 哪些 好看 的 校园 打架 电影   好看的点学校帮派打架的电影
# 怎么 在 微信 上 制作 连接   如何在微信上制作别人的
# 网上 购物 网站 有 哪些   网上购物网站网站
# 一部 足球 的 动画片   一部足球的动画片
# 怎样 给 别人 发短信 可以 隐藏 自己 的 号码   如何可以隐藏自己的的打电话
# 孕妇 能 喝 方便面 吗   孕妇能吃方便面吗
# 为什么 男人 比 女人 强壮   男人为什么比女人强壮
# 帮 我 找 一下 另 一个 情侣 头像   帮我找一下这个情侣头像
# 人有 三急 哪三急   <UNK><UNK>之<UNK>
# 我 的 美丽 日记   美丽的美丽的对比
# 怎么 在 网盘 里 搜索   怎么用手机
# 天天 飞车 求 破解版   天天飞车要破解版吗
# 什么样 的 婴儿 推车 好   什么样的婴儿推车好
# 我 想 知道 这 条 裤子 是 什么 牌子   谁知道这条裤子是什么牌子的
# 寻 一部 美国 老电影   问一部漂亮的
# 阿莫西林 喝酒 能 吃 吗   吃了能能喝酒吗
# 菊花 的 花瓣 展开 像 什么   菊花花瓣展开像什么
# 热力 环流 的 图 怎么 画   怎么<UNK><UNK>出
# 寒心 什么 意思   说什么意思啊
# 五个 月 的 宝宝 能 吃 什么   五个月的宝宝都应该<UNK>什么好呢
# 我 最 喜欢 的 水果 是 什么   我最喜欢的水果是什么
# 百度 知道 被 封号 了 会 被 封 多久 啊   百度知道封号封多久
# 我 的 世界 存档 怎么 用   我的世界存档怎么存档
# 什么 解酒 方法 最快 最 有效   什么什么解酒最快最有效
# 这是 什么 手表 品牌   这是什么牌子的手表
# 男生 进去 什么 感觉   男生进去是什么感觉
# 我 的 世界 怎么 入 地狱   我的世界怎么去地狱
# 求 一款 类似 愤怒 的 小鸟 的 游戏   一款类似愤怒的小鸟的游戏
# 徐帆 和 冯小刚 有 孩子 吗   冯小刚与徐帆有孩子吗
# 亲 ， 新年快乐 哦   亲喝酒通
# 汽车 可以 带 宠物 吗   坐汽车可以带宠物吗
# 三星 手机 在 哪 买 便宜   三星手机在哪买便宜
# 中国 副 主席 是 谁   中国主席是谁谁
# 好玩 的 回合制 网游   好玩的回合制有哪些
# 有 什么 好看 的 电视剧 啊 ， 求 介绍   有什么好看电视剧介绍么
# 查询 驾驶证 扣分 怎么 查   驾驶证扣分查询分
# 现在 做 什么 工作 工资 高   现在做什么工作工资高一点
# 有 信用卡 欠款 还 能 房贷 吗   信用卡<UNK>可以贷房贷吗
# 怎么 追 女孩子 ， 有 什么 技巧   我该怎么做才是什么啊
# 什么 鱼 可以 和 罗汉 一起 养   罗汉<UNK>和什么<UNK>在一起
# 如何 扫描 微信 二维码   微信扫描二维码
# 佳木斯 是 哪个 省 的   <UNK>在哪个省
# 晚上 怎么 打 野鸡   晚上怎么捉野鸡
# 送 快递 的 工资 怎么 算 的   快递员的工资怎么算
# 人工 审核 是 需要 上传 证件 信息 进行 操作 的   您需要上传证件证件人工人工审核
# 快乐 大本营 下期 谁 来   下期快乐大本营是是谁啊
# 你 不 知道 的 事 伴奏 陈永馨   你不知道的事伴奏
# 生存 战争 语言 中文版   生存的这个电影
# 怎么 上传 音乐 到 酷狗   如何上传到自己的音乐
# 现在 手机 上 哪里 可以 买 彩票   手机上哪里可以买彩票
# 课文 是 小桥流水 人家   小桥流水人家的课文
# 厦门 属于 哪个 省   厦门属于哪个省省
# 怎么 破解 小米 主题   怎样破解小米的
# 交 医保 有 什么 好处   医保有什么好处啊
# 我 是 歌手 第三季 踢 馆赛 什么 时候 播   我是歌手第三季<UNK>已时候播
# 吃螃蟹 后 不能 吃 什么 水果   <UNK>不能不能吃什么
# 天天 酷跑 现在 的 刷 分用 什么 软件 ， 求 大神   天天酷跑用什么软件刷分刷的多
# 怎么 挽回 一个 不爱 你 的 男人   如何挽回一个<UNK>喜欢你的男人
# 盘锦 在 哪   <UNK>在哪
# 使用 谷歌 试试 呢   使用谷歌的
# 姓名 设计 个性 签名   姓名签名设计一个签名
# 别人 用 我 的 手机号 绑定 微信 ， 怎么 解除   微信怎么解除绑定的手机号
# 元宵 和 汤圆 有 什么 区别   汤圆和元宵有什么区别
# 求 天空 之 城 吉他谱   求天空之城吉他谱
# 谁 有 好看 的 手机 壁纸   我好看的手机壁纸
# 怎样 下载 禁播 视频   怎么下载搜狐视频
# 苹果 手机 通讯录 被 误删 了 该 怎么 恢复   苹果手机通讯录删了怎么恢复
# 怎样 把 淘宝 下载 到 手机 上   怎么样下载手机淘宝
# 万字加 一笔 ， 是 什么 字   万字加一笔变什么
# 我 想 买 套 沙发 ， 买 什么 牌子 的 好 呢   什么网站的手表好
# 天涯 论坛 里 怎么 发帖 啊   天涯论坛该者怎么发啊
# 这 公仔 叫 什么 名字   谁知道这个公仔叫什么名字
# 找 一本 小说 。 古言   找小说一本古言
# 篮球 怎么 过人 啊   篮球怎样手机篮球
# 魔兽 世界 新手 卡 哪里 有   魔兽世界新手卡哪里好玩
# 使用 谷歌 浏览器 下   使用谷歌浏览器浏览器浏览器
# 海贼王 的 高清 壁纸   海贼王的这个高清壁纸
# 我 是 特种兵 之 火凤凰 全集   我是特种兵之火凤凰集全集
# 微星 笔记本 的 质量 怎么样   <UNK>的笔记本怎么样怎么样吗
# 江淮 汽车 瑞风 S3 好不好   江淮汽车瑞风汽车怎么样
# 我 的 世界 手机 版 存档   我的世界手机版怎么存档
# 武汉 哪里 的 烧烤 好吃 啊   武汉哪里有好吃的烧烤
# 两个 儿子 是 什么 生肖   两个是什么生肖生肖
# 在 那里 可以 免费 观看 同桌 的 你 电影   哪里可以在免费玩电影最大的电影
# 网络 怎么 赚钱   网络怎么样才能赚钱
# 呆 而 结巴 的 说 是 什么 成语   <UNK>的这个生活的坐骑
# 多 看书 有 什么 好处   什么水果有什么好处
# 关于 苹果 手机 分期付款   苹果手机的开机
# 亲爱 滴 是 什么 意思   <UNK>的<UNK>是什么意思
# 正常 血压 范围   <UNK><UNK>有什么
# 好多 电影 找 不到 链接   找不到电影资源
# 买 零食 去 哪个 网站 好   零食在哪个网站好
# 求 这个 图 的 游戏 下载 地址   求这个下载游戏下载高清地址
# 有 什么 网页 游戏 好玩   什么网页游戏最好玩
# 第三个 是 什么   第三个叫什么
# 今天 我 有 财运 吗   今天有真的有吗
# 自然 乐园 芦荟胶 怎么样   自然的一件怎么样
# 怎么 写 ， 简便 运算   人怎么做的
# 关于 寓言故事 的 成语   <UNK>的成语有哪些
# 那个 牌子 笔记本电脑 好   笔记本电脑里的笔记本电脑好
# 川菜 厨师 招聘   <UNK>签名怎么
# 电压表 测 谁 的 电压 ， 为什么   谁知道这版的人为什么
# 运城 是 哪   <UNK>是哪哪
# 看图 猜 成语 请 大家 猜 一个 成语   成语猜成语猜成语
# 火影忍者 用 什么 软件 可以 下载   火影忍者什么软件可以下载火影忍者
# 匆匆 那年 完整版   匆匆那年电影完整版
# 谁 有 初中 女生 内衣 的 图片   谁一些漂亮的招图片
# 怎么 删除 微信 自己 朋友圈 的 内容   微信微信微信删的内容如何删除
# 内衣店 取 什么 名字 好   <UNK>的什么什么名字
# 积木 什么 牌子 好   什么牌子积木好
# 酷狗 音乐 怎么 往 上传 歌 呀   酷狗音乐是酷狗
# 孕妇 可以 吃 莲藕 吗   孕妇能吃阿胶吗
# 什么 是 科技 小 论文 , 该 怎么 写   .是什么时候创业
# 电脑 有时 有 个别 网页 打不开   电脑上<UNK>有网页打不开
# 求 家庭教师 的 漫画   求家庭教师的漫画
# 剑灵 如何 双开   剑灵怎么才能双开
# 什么 手机游戏 可以 联机   有什么手机游戏可以联机
# 关 於 广州 购书 中心   歌手<UNK><UNK>小小中心
# 什么 牌子 的 床 和 沙发 好   什么牌子的手机好还有
# 谁 有 这 张图 的 大图 ， 高清 的   谁有这张图的高清
# 怎么 叠 百合花   这个怎么折
# 山西 的 省会 是 哪   山西的省会是
# 关于 北京四中 网校   <UNK>怎么<UNK>
# 请问 这个 是 什么 字体 ， 急 在线 等   急这是什么字体在线等
# 圣诞老人 的 坐骑 是 什么   圣诞老人的坐骑是什么
# 这是 什么游戏 里 的 人物 叫 什么   这是什么游戏的什么人物
# 女人 如何 控制 自己 的 脾气   <UNK>怎样自己自己的<UNK>
# 用 手机 怎样才能 看 黄   怎么手机看看高铁
# 李 玹 雨 蘑菇 头 怎么 剪 李 玹 雨   蘑菇头怎么理
# 求亚丝娜 本子   求亚丝娜的这个图
# 有 什么 经典 好玩 的 手机 小游戏   有什么好玩的手机小游戏
# 怎么 让 女孩 喜欢 你   怎么让女孩喜欢喜欢你
# 如何 让 电脑 恢复 出厂 设置   怎么恢复电脑设置
# 反映 了 我国 哪些 基本国情   <UNK>我国我国<UNK>
# 如何 清除 苹果 手机 内存   苹果手机如何清理
# 补水 化妆品 什么 好   什么医院补水好
# 近墨者黑 的 上 一句 是   <UNK>上一句
# 电脑 上 看 电视直播 用 什么 软件   用什么软件看看电视直播
